# %%
#!/usr/bin/env python
# coding: utf-8
from __future__ import print_function

__source__ = "topicClassificationLDAv2-visualize.ipynb"
__author__ = "Frank J. Greco"
__copyright__ = "Copyright 2015-2018, Frank J. Greco"
__credits__ = []
__license__ = "Apache"
__version__ = "1.0.1"
__email__ = ""
__status__ = "Development"

#
# Perform LDA topic analysis on set of transcript testfiles
#
# Adapted from script found at
# https://rstudio-pubs-static.s3.amazonaws.com/79360_850b2a69980c4488b1db95987a24867a.html
#

# %%
# %load_ext autoreload
# %autoreload 2
#%reload_ext autoreload
import sys
sys.path.append('/Users/fjgreco/Dev-Atlas')

# %%
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from nltk.stem.porter import PorterStemmer
from gensim import corpora, models
import gensim
import os
from collections import Counter
import pyLDAvis.gensim as gensimvis
import pyLDAvis

# %%
def tokenize_transcripts(transcript_dir):
    
    from preprocess import read_documents

    print (transcript_dir)

    tokenizer = RegexpTokenizer(r'\w+')

    # create English stop words list
    en_stop = get_stop_words('en')

    # eliminate the most frequently used words from the dictionary
    en_stop=[u'okay',u'go',u'like',u'one',u'think',u'right',u'can',u'yeah',u'just']+en_stop
    print (en_stop)

    # create p_stemmer of class PorterStemmer

    p_stemmer = PorterStemmer()

    doc_set, doc_index=read_documents(transcript_dir)

    #doc_set = [line.rstrip('\n') for line in open(testfile)]

    # tokenized documents in loop
    texts = []

    megalist=[]

    # loop through document list
    for i in doc_set:
        # clean and tokenize document string
        raw = i.lower()

        raw2=raw.replace("'", "")

        #print ('\n'+raw2)

        tokens = tokenizer.tokenize(raw2)

        # remove stop words from tokens
        stopped_tokens = [i for i in tokens if not i in en_stop]
        #print (' '.join(stopped_tokens))

        # stem tokens
        stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
        #print (' '.join(stemmed_tokens))

        # add tokens to list
        texts.append(stemmed_tokens)

        megalist=megalist+stemmed_tokens


    counts = Counter(megalist)
 

    print('len(texts:', len(texts), 'len(megalist)', len(megalist))

    print(counts)

    print (type(counts))
 
    
    for itm in sorted(counts.items(), key=lambda x: -x[-1]):
        print (itm)

    # convert tokenized documents into a id <-> term dictionary
    dictionary = corpora.Dictionary(texts)
    dictionary.filter_extremes(no_below=2, no_above=0.5)  # , keep_n=1

    # convert tokenized documents into a document-term matrix
    corpus = [dictionary.doc2bow(text) for text in texts[1:]]
    
    bow = [dictionary.doc2bow(text) for text in texts[:1]]
    
    return corpus, bow, dictionary

# %%
def visualize_lda_model(ldamodel, corpus, dictionary): 
    vis_data = gensimvis.prepare(ldamodel, corpus, dictionary)
    #pyLDAvis.display(vis_data)
    pyLDAvis.show(vis_data)

# %%
ldamodel=gensim.models.LdaModel.load('ldamodel.mm')

# %%
corpus, bow, dictionary= tokenize_transcripts('../CC_TRANSCRIPTS3')
# Out:
# ../CC_TRANSCRIPTS3
# [u'okay', u'go', u'like', u'one', u'think', u'right', u'can', u'yeah', u'just', u'a', u'about', u'above', u'after', u'again', u'against', u'all', u'am', u'an', u'and', u'any', u'are', u"aren't", u'as', u'at', u'be', u'because', u'been', u'before', u'being', u'below', u'between', u'both', u'but', u'by', u"can't", u'cannot', u'could', u"couldn't", u'did', u"didn't", u'do', u'does', u"doesn't", u'doing', u"don't", u'down', u'during', u'each', u'few', u'for', u'from', u'further', u'had', u"hadn't", u'has', u"hasn't", u'have', u"haven't", u'having', u'he', u"he'd", u"he'll", u"he's", u'her', u'here', u"here's", u'hers', u'herself', u'him', u'himself', u'his', u'how', u"how's", u'i', u"i'd", u"i'll", u"i'm", u"i've", u'if', u'in', u'into', u'is', u"isn't", u'it', u"it's", u'its', u'itself', u"let's", u'me', u'more', u'most', u"mustn't", u'my', u'myself', u'no', u'nor', u'not', u'of', u'off', u'on', u'once', u'only', u'or', u'other', u'ought', u'our', u'ours', u'ourselves', u'out', u'over', u'own', u'same', u"shan't", u'she', u"she'd", u"she'll", u"she's", u'should', u"shouldn't", u'so', u'some', u'such', u'than', u'that', u"that's", u'the', u'their', u'theirs', u'them', u'themselves', u'then', u'there', u"there's", u'these', u'they', u"they'd", u"they'll", u"they're", u"they've", u'this', u'those', u'through', u'to', u'too', u'under', u'until', u'up', u'very', u'was', u"wasn't", u'we', u"we'd", u"we'll", u"we're", u"we've", u'were', u"weren't", u'what', u"what's", u'when', u"when's", u'where', u"where's", u'which', u'while', u'who', u"who's", u'whom', u'why', u"why's", u'with', u"won't", u'would', u"wouldn't", u'you', u"you'd", u"you'll", u"you're", u"you've", u'your', u'yours', u'yourself', u'yourselves']
# len(texts: 243 len(megalist) 202394
# Counter({u'go': 2272, u'that': 1879, u'get': 1870, u'good': 1841, u'your': 1763, u'say': 1696, u'want': 1664, u'know': 1656, u'make': 1469, u'see': 1439, u'look': 1437, u'dont': 1433, u'let': 1428, u'now': 1400, u'well': 1191, u'gonna': 1182, u'two': 1171, u'im': 1123, u'put': 1118, u'thing': 1113, u'time': 1065, u'peopl': 1036, u'guy': 1035, u'got': 985, u'realli': 959, u'use': 941, u'oh': 940, u'someth': 912, u'need': 876, u'water': 872, u'differ': 849, u'kind': 846, u'littl': 839, u'back': 838, u'theyr': 823, u'come': 811, u'talk': 801, u'said': 796, u'take': 766, u'three': 765, u'ye': 765, u'way': 754, u'mean': 738, u'tri': 722, u'will': 713, u'there': 701, u'start': 700, u'alright': 697, u'what': 690, u'number': 684, u'work': 682, u'question': 681, u'mayb': 651, u'tell': 647, u'first': 601, u'happen': 596, u'chang': 582, u'lot': 553, u'didnt': 535, u'might': 528, u'group': 521, u'turn': 519, u'much': 502, u'us': 492, u'give': 478, u'still': 475, u'help': 474, u'actual': 473, u'job': 468, u'color': 468, u'four': 450, u'hand': 449, u'caus': 448, u'els': 444, u'move': 443, u'also': 442, u'write': 423, u'keep': 421, u'part': 420, u'word': 418, u'idea': 418, u'agre': 404, u'doesnt': 391, u'point': 390, u'even': 389, u'energi': 387, u'he': 384, u'anoth': 379, u'second': 376, u'sure': 375, u'show': 374, u'read': 371, u'around': 369, u'bit': 365, u'five': 364, u'find': 364, u'rememb': 354, u'measur': 350, u'cant': 347, u'thought': 346, u'stuff': 338, u'readi': 334, u'mani': 326, u'person': 325, u'think': 325, u'line': 318, u'ahead': 314, u'next': 313, u'side': 309, u'six': 308, u'went': 306, u'air': 306, u'half': 303, u'goe': 302, u'feel': 299, u'hold': 294, u'anyth': 294, u'wait': 290, u'probabl': 285, u'ball': 281, u'one': 276, u'ask': 274, u'step': 270, u'minut': 269, u'great': 267, u'ok': 267, u'togeth': 264, u'add': 259, u'ill': 258, u'neg': 258, u'y': 258, u'end': 258, u'big': 257, u'better': 256, u'hear': 256, u'zero': 255, u'play': 255, u'light': 250, u'um': 249, u'whole': 248, u'everybodi': 248, u'stay': 245, u'day': 245, u'made': 244, u'x': 241, u'thank': 240, u'figur': 239, u'far': 238, u'sun': 236, u'long': 236, u'last': 235, u'someon': 235, u'youv': 235, u'answer': 234, u'equal': 231, u'stop': 230, u'paper': 228, u'problem': 226, u'abl': 226, u'top': 222, u'pull': 219, u'call': 215, u'though': 215, u'done': 214, u'eye': 213, u'squar': 211, u'pictur': 211, u'exampl': 210, u'pretti': 209, u'wouldnt': 207, u'listen': 206, u'plant': 206, u'real': 202, u'pick': 202, u'mass': 201, u'tabl': 201, u'today': 201, u'eight': 200, u'nice': 198, u'que': 198, u'alreadi': 198, u'definit': 197, u'everyth': 197, u'away': 192, u'pleas': 192, u'weve': 191, u'notic': 190, u'amount': 190, u'wanna': 189, u'book': 188, u'anybodi': 188, u'graph': 186, u'less': 183, u'stick': 183, u'base': 182, u'seven': 181, u'temperatur': 181, u'note': 180, u'learn': 180, u'parent': 180, u'share': 180, u'blue': 179, u'push': 178, u'data': 178, u'live': 178, u'faster': 178, u'sort': 177, u'sit': 174, u'heat': 173, u'life': 172, u'draw': 172, u'die': 172, u'may': 172, u'wind': 170, u'bigger': 169, u'she': 168, u'experi': 167, u'class': 167, u'somebodi': 166, u'guess': 166, u'check': 165, u'here': 164, u'friend': 164, u'sometim': 164, u'hard': 164, u'set': 163, u'angl': 163, u'type': 163, u'place': 161, u'piec': 159, u'middl': 159, u'money': 159, u'everi': 159, u'red': 158, u'isnt': 158, u'food': 157, u'grow': 157, u'everyon': 157, u'saw': 156, u'nine': 156, u'interest': 156, u'alway': 156, u'la': 155, u'uh': 154, u'sound': 153, u'leav': 153, u'countri': 152, u'high': 152, u'test': 152, u'exactli': 152, u'forc': 152, u'new': 151, u'10': 150, u'sinc': 149, u'close': 149, u'bodi': 149, u'discuss': 148, u'hot': 147, u'bottom': 147, u'found': 146, u'area': 145, u'partner': 145, u'stori': 145, u'matter': 144, u'understand': 144, u'car': 142, u'sorri': 142, u'yet': 142, u'kinda': 141, u'bring': 140, u'watch': 140, u'enough': 139, u'white': 139, u'explain': 138, u'st ...
# <class 'collections.Counter'>
# (u'go', 2272)
# (u'that', 1879)
# (u'get', 1870)
# (u'good', 1841)
# (u'your', 1763)
# (u'say', 1696)
# (u'want', 1664)
# (u'know', 1656)
# (u'make', 1469)
# (u'see', 1439)
# (u'look', 1437)
# (u'dont', 1433)
# (u'let', 1428)
# (u'now', 1400)
# (u'well', 1191)
# (u'gonna', 1182)
# (u'two', 1171)
# (u'im', 1123)
# (u'put', 1118)
# (u'thing', 1113)
# (u'time', 1065)
# (u'peopl', 1036)
# (u'guy', 1035)
# (u'got', 985)
# (u'realli', 959)
# (u'use', 941)
# (u'oh', 940)
# (u'someth', 912)
# (u'need', 876)
# (u'water', 872)
# (u'differ', 849)
# (u'kind', 846)
# (u'littl', 839)
# (u'back', 838)
# (u'theyr', 823)
# (u'come', 811)
# (u'talk', 801)
# (u'said', 796)
# (u'take', 766)
# (u'three', 765)
# (u'ye', 765)
# (u'way', 754)
# (u'mean', 738)
# (u'tri', 722)
# (u'will', 713)
# (u'there', 701)
# (u'start', 700)
# (u'alright', 697)
# (u'what', 690)
# (u'number', 684)
# (u'work', 682)
# (u'question', 681)
# (u'mayb', 651)
# (u'tell', 647)
# (u'first', 601)
# (u'happen', 596)
# (u'chang', 582)
# (u'lot', 553)
# (u'didnt', 535)
# (u'might', 528)
# (u'group', 521)
# (u'turn', 519)
# (u'much', 502)
# (u'us', 492)
# (u'give', 478)
# (u'still', 475)
# (u'help', 474)
# (u'actual', 473)
# (u'job', 468)
# (u'color', 468)
# (u'four', 450)
# (u'hand', 449)
# (u'caus', 448)
# (u'els', 444)
# (u'move', 443)
# (u'also', 442)
# (u'write', 423)
# (u'keep', 421)
# (u'part', 420)
# (u'word', 418)
# (u'idea', 418)
# (u'agre', 404)
# (u'doesnt', 391)
# (u'point', 390)
# (u'even', 389)
# (u'energi', 387)
# (u'he', 384)
# (u'anoth', 379)
# (u'second', 376)
# (u'sure', 375)
# (u'show', 374)
# (u'read', 371)
# (u'around', 369)
# (u'bit', 365)
# (u'five', 364)
# (u'find', 364)
# (u'rememb', 354)
# (u'measur', 350)
# (u'cant', 347)
# (u'thought', 346)
# (u'stuff', 338)
# (u'readi', 334)
# (u'mani', 326)
# (u'person', 325)
# (u'think', 325)
# (u'line', 318)
# (u'ahead', 314)
# (u'next', 313)
# (u'side', 309)
# (u'six', 308)
# (u'went', 306)
# (u'air', 306)
# (u'half', 303)
# (u'goe', 302)
# (u'feel', 299)
# (u'hold', 294)
# (u'anyth', 294)
# (u'wait', 290)
# (u'probabl', 285)
# (u'ball', 281)
# (u'one', 276)
# (u'ask', 274)
# (u'step', 270)
# (u'minut', 269)
# (u'great', 267)
# (u'ok', 267)
# (u'togeth', 264)
# (u'add', 259)
# (u'ill', 258)
# (u'neg', 258)
# (u'y', 258)
# (u'end', 258)
# (u'big', 257)
# (u'better', 256)
# (u'hear', 256)
# (u'zero', 255)
# (u'play', 255)
# (u'light', 250)
# (u'um', 249)
# (u'whole', 248)
# (u'everybodi', 248)
# (u'stay', 245)
# (u'day', 245)
# (u'made', 244)
# (u'x', 241)
# (u'thank', 240)
# (u'figur', 239)
# (u'far', 238)
# (u'sun', 236)
# (u'long', 236)
# (u'last', 235)
# (u'someon', 235)
# (u'youv', 235)
# (u'answer', 234)
# (u'equal', 231)
# (u'stop', 230)
# (u'paper', 228)
# (u'problem', 226)
# (u'abl', 226)
# (u'top', 222)
# (u'pull', 219)
# (u'call', 215)
# (u'though', 215)
# (u'done', 214)
# (u'eye', 213)
# (u'squar', 211)
# (u'pictur', 211)
# (u'exampl', 210)
# (u'pretti', 209)
# (u'wouldnt', 207)
# (u'listen', 206)
# (u'plant', 206)
# (u'real', 202)
# (u'pick', 202)
# (u'mass', 201)
# (u'tabl', 201)
# (u'today', 201)
# (u'eight', 200)
# (u'nice', 198)
# (u'que', 198)
# (u'alreadi', 198)
# (u'definit', 197)
# (u'everyth', 197)
# (u'away', 192)
# (u'pleas', 192)
# (u'weve', 191)
# (u'notic', 190)
# (u'amount', 190)
# (u'wanna', 189)
# (u'book', 188)
# (u'anybodi', 188)
# (u'graph', 186)
# (u'less', 183)
# (u'stick', 183)
# (u'base', 182)
# (u'seven', 181)
# (u'temperatur', 181)
# (u'note', 180)
# (u'learn', 180)
# (u'parent', 180)
# (u'share', 180)
# (u'blue', 179)
# (u'push', 178)
# (u'data', 178)
# (u'live', 178)
# (u'faster', 178)
# (u'sort', 177)
# (u'sit', 174)
# (u'heat', 173)
# (u'life', 172)
# (u'draw', 172)
# (u'die', 172)
# (u'may', 172)
# (u'wind', 170)
# (u'bigger', 169)
# (u'she', 168)
# (u'experi', 167)
# (u'class', 167)
# (u'somebodi', 166)
# (u'guess', 166)
# (u'check', 165)
# (u'here', 164)
# (u'friend', 164)
# (u'sometim', 164)
# (u'hard', 164)
# (u'set', 163)
# (u'angl', 163)
# (u'type', 163)
# (u'place', 161)
# (u'piec', 159)
# (u'middl', 159)
# (u'money', 159)
# (u'everi', 159)
# (u'red', 158)
# (u'isnt', 158)
# (u'food', 157)
# (u'grow', 157)
# (u'everyon', 157)
# (u'saw', 156)
# (u'nine', 156)
# (u'interest', 156)
# (u'alway', 156)
# (u'la', 155)
# (u'uh', 154)
# (u'sound', 153)
# (u'leav', 153)
# (u'countri', 152)
# (u'high', 152)
# (u'test', 152)
# (u'exactli', 152)
# (u'forc', 152)
# (u'new', 151)
# (u'10', 150)
# (u'sinc', 149)
# (u'close', 149)
# (u'bodi', 149)
# (u'discuss', 148)
# (u'hot', 147)
# (u'bottom', 147)
# (u'found', 146)
# (u'area', 145)
# (u'partner', 145)
# (u'stori', 145)
# (u'matter', 144)
# (u'understand', 144)
# (u'car', 142)
# (u'sorri', 142)
# (u'yet', 142)
# (u'kinda', 141)
# (u'bring', 140)
# (u'watch', 140)
# (u'enough', 139)
# (u'white', 139)
# (u'explain', 138)
# (u'stand', 137)
# (u'posit', 137)
# (u'reason', 136)
# (u'bad', 136)
# (u'came', 135)
# (u'left', 135)
# (u'heard', 133)
# (u'school', 133)
# (u'sens', 132)
# (u'rais', 132)
# (u'year', 132)
# (u'creat', 131)
# (u'rock', 131)
# (u'earth', 131)
# (u'import', 130)
# (u'hous', 130)
# (u'de', 129)
# (u'run', 129)
# (u'predict', 129)
# (u'girl', 129)
# (u'who', 128)
# (u'ive', 127)
# (u'plu', 127)
# (u'anim', 127)
# (u'form', 127)
# (u'wrong', 125)
# (u'centimet', 125)
# (u'insid', 125)
# (u'eat', 125)
# (u'youll', 124)
# (u'id', 124)
# (u'space', 123)
# (u'room', 123)
# (u'yall', 123)
# (u'eighth', 123)
# (u'match', 122)
# (u'float', 121)
# (u'increas', 121)
# (u'vote', 120)
# (u'rate', 120)
# (u'begin', 120)
# (u'foot', 120)
# (u'page', 120)
# (u'build', 120)
# (u'moon', 120)
# (u'hit', 120)
# (u'higher', 120)
# (u'excel', 119)
# (u'instead', 119)
# (u'natur', 118)
# (u'shape', 118)
# (u'heart', 117)
# (u't', 117)
# (u'circl', 117)
# (u'ad', 116)
# (u'face', 116)
# (u'speed', 116)
# (u'green', 115)
# (u'ga', 115)
# (u'cut', 114)
# (u'sing', 114)
# (u'follow', 114)
# (u'wasnt', 112)
# (u'graviti', 112)
# (u'choic', 112)
# (u'weight', 112)
# (u'cold', 111)
# (u'took', 111)
# (u'cool', 111)
# (u'pressur', 111)
# (u'love', 110)
# (u'basic', 110)
# (u'best', 109)
# (u'power', 109)
# (u'bubbl', 109)
# (u'havent', 109)
# (u'count', 108)
# (u'front', 108)
# (u'inch', 108)
# (u'outsid', 107)
# (u'black', 107)
# (u'pay', 107)
# (u'compar', 107)
# (u'miss', 106)
# (u'paint', 106)
# (u'coupl', 106)
# (u'whatev', 105)
# (u'never', 104)
# (u'fast', 104)
# (u'12', 104)
# (u'hmm', 104)
# (u'correct', 103)
# (u'connect', 103)
# (u's', 101)
# (u'board', 101)
# (u'finish', 101)
# (u'affect', 101)
# (u'least', 101)
# (u'decid', 100)
# (u'break', 100)
# (u'speak', 100)
# (u'wont', 100)
# (u'ground', 100)
# (u'either', 100)
# (u'ten', 100)
# (u'itll', 100)
# (u'le', 99)
# (u'student', 99)
# (u'rest', 98)
# (u'care', 98)
# (u'kid', 98)
# (u'mark', 98)
# (u'intercept', 98)
# (u'rule', 97)
# (u'volum', 97)
# (u'1', 97)
# (u'fourth', 97)
# (u'divid', 97)
# (u'dark', 96)
# (u'suppos', 96)
# (u'home', 96)
# (u'present', 96)
# (u'direct', 95)
# (u'alex', 95)
# (u'observ', 95)
# (u'unit', 94)
# (u'world', 94)
# (u'believ', 94)
# (u'height', 94)
# (u'equat', 94)
# (u'possibl', 94)
# (u'head', 94)
# (u'20', 93)
# (u'pop', 93)
# (u'noel', 92)
# (u'drop', 92)
# (u'substanc', 92)
# (u'oil', 92)
# (u'inform', 92)
# (u'ti', 91)
# (u'organ', 91)
# (u'almost', 91)
# (u'fall', 91)
# (u'huh', 91)
# (u'famili', 90)
# (u'depend', 90)
# (u'quick', 90)
# (u'without', 90)
# (u'roll', 89)
# (u'throw', 89)
# (u'bag', 89)
# (u'dad', 89)
# (u'balloon', 89)
# (u'third', 88)
# (u'50', 88)
# (u'walk', 88)
# (u'bien', 87)
# (u'e', 87)
# (u'blood', 87)
# (u'small', 86)
# (u'true', 86)
# (u'repeat', 86)
# (u'seed', 86)
# (u'tilt', 86)
# (u'c', 86)
# (u'cube', 86)
# (u'touch', 85)
# (u'b', 85)
# (u'longer', 85)
# (u'tu', 84)
# (u'tape', 84)
# (u'teacher', 84)
# (u'awesom', 84)
# (u'mind', 84)
# (u'mom', 84)
# (u'chart', 84)
# (u'2', 83)
# (u'sand', 83)
# (u'opinion', 83)
# (u'govern', 83)
# (u'bone', 83)
# (u'anyon', 83)
# (u'cost', 82)
# (u'box', 82)
# (u'becom', 82)
# (u'fraction', 82)
# (u'per', 82)
# (u'trait', 82)
# (u'level', 82)
# (u'state', 82)
# (u'old', 81)
# (u'open', 81)
# (u'choos', 81)
# (u'seen', 81)
# (u'fine', 81)
# (u'30', 81)
# (u'r', 81)
# (u'shirt', 81)
# (u'root', 80)
# (u'je', 80)
# (u'art', 80)
# (u'shadow', 79)
# (u'happi', 79)
# (u'pass', 79)
# (u'order', 79)
# (u'low', 79)
# (u'toward', 79)
# (u'ice', 79)
# (u'liquid', 79)
# (u'gener', 78)
# (u'size', 78)
# (u'sentenc', 78)
# (u'couldnt', 78)
# (u'100', 78)
# (u'warm', 78)
# (u'pink', 78)
# (u'disagre', 78)
# (u'mm', 78)
# (u'acid', 78)
# (u'40', 77)
# (u'noth', 77)
# (u'cloud', 77)
# (u'singl', 77)
# (u'repres', 77)
# (u'center', 77)
# (u'buy', 77)
# (u'name', 77)
# (u'friction', 76)
# (u'factor', 76)
# (u'perfect', 76)
# (u'3', 76)
# (u'boy', 76)
# (u'wonder', 76)
# (u'told', 75)
# (u'log', 75)
# (u'absorb', 75)
# (u'normal', 75)
# (u'specif', 74)
# (u'fact', 74)
# (u'control', 74)
# (u'distanc', 74)
# (u'minu', 74)
# (u'dollar', 74)
# (u'flap', 74)
# (u'yellow', 73)
# (u'easier', 73)
# (u'doubl', 73)
# (u'farther', 73)
# (u'seem', 73)
# (u'slope', 73)
# (u'object', 72)
# (u'domin', 72)
# (u'11', 72)
# (u'potenti', 72)
# (u'feet', 72)
# (u'record', 72)
# (u'activ', 71)
# (u'straight', 71)
# (u'card', 71)
# (u'arent', 71)
# (u'mine', 71)
# (u'f', 71)
# (u'behind', 70)
# (u'ever', 70)
# (u'14', 70)
# (u'term', 70)
# (u'pen', 69)
# (u'cover', 69)
# (u'pencil', 69)
# (u'trial', 69)
# (u'averag', 69)
# (u'flower', 69)
# (u'goal', 69)
# (u'plate', 68)
# (u'sheet', 68)
# (u'chanc', 68)
# (u'dog', 68)
# (u'multipli', 68)
# (u'opposit', 67)
# (u'hypothesi', 67)
# (u'surfac', 67)
# (u'hair', 67)
# (u'fit', 66)
# (u'certain', 66)
# (u'lo', 66)
# (u'5', 66)
# (u'effect', 66)
# (u'pollut', 66)
# (u'cup', 66)
# (u'complet', 66)
# (u'youd', 65)
# (u'clear', 65)
# (u'yep', 65)
# (u'gotta', 65)
# (u'fill', 65)
# (u'fun', 65)
# (u'pattern', 65)
# (u'week', 65)
# (u'hurt', 64)
# (u'molecul', 64)
# (u'continu', 64)
# (u'practic', 64)
# (u'blow', 64)
# (u'wrote', 64)
# (u'chees', 64)
# (u'hey', 63)
# (u'john', 63)
# (u'valu', 63)
# (u'fish', 63)
# (u'solid', 63)
# (u'scientist', 63)
# (u'weather', 63)
# (u'slow', 62)
# (u'where', 62)
# (u'un', 62)
# (u'rain', 62)
# (u'el', 62)
# (u'clean', 62)
# (u'millilit', 62)
# (u'usual', 62)
# (u'like', 62)
# (u'closer', 62)
# (u'past', 61)
# (u'vou', 61)
# (u'decreas', 61)
# (u'station', 61)
# (u'wow', 61)
# (u'skin', 61)
# (u'pure', 61)
# (u'15', 61)
# (u'ah', 61)
# (u'absolut', 61)
# (u'case', 61)
# (u'lower', 61)
# (u'team', 60)
# (u'd', 60)
# (u'issu', 60)
# (u'co2', 60)
# (u'jump', 60)
# (u'somewher', 60)
# (u'result', 59)
# (u'later', 59)
# (u'educ', 59)
# (u'system', 59)
# (u'drink', 59)
# (u'brown', 59)
# (u'orbit', 59)
# (u'grade', 59)
# (u'sad', 59)
# (u'charg', 59)
# (u'math', 59)
# (u'necessarili', 59)
# (u'relat', 58)
# (u'easi', 58)
# (u'along', 58)
# (u'fire', 58)
# (u'en', 58)
# (u'werent', 58)
# (u'0', 58)
# (u'comment', 58)
# (u'breath', 57)
# (u'movi', 57)
# (u'ramp', 57)
# (u'night', 57)
# (u'dig', 57)
# (u'mix', 57)
# (u'percent', 57)
# (u'decim', 56)
# (u'ce', 56)
# (u'em', 56)
# (u'game', 56)
# (u'mad', 56)
# (u'bunch', 56)
# (u'balanc', 56)
# (u'smaller', 56)
# (u'slave', 56)
# (u'fair', 55)
# (u'video', 55)
# (u'bat', 55)
# (u'nuclear', 55)
# (u'extra', 55)
# (u'benefit', 55)
# (u'gram', 55)
# (u'common', 55)
# (u'text', 55)
# (u'attent', 55)
# (u'pour', 54)
# (u'oxygen', 54)
# (u'soil', 54)
# (u'scienc', 54)
# (u'fli', 54)
# (u'children', 54)
# (u'protect', 54)
# (u'produc', 54)
# (u'chemic', 54)
# (u'salt', 53)
# (u'variabl', 53)
# (u'america', 53)
# (u'degre', 53)
# (u'scale', 53)
# (u'theyll', 53)
# (u'vapor', 53)
# (u'orang', 53)
# (u'stuck', 53)
# (u'combin', 53)
# (u'marbl', 53)
# (u'whether', 53)
# (u'clay', 52)
# (u'solut', 52)
# (u'materi', 52)
# (u'commun', 52)
# (u'safe', 52)
# (u'da', 52)
# (u'man', 52)
# (u'25', 52)
# (u'gave', 52)
# (u'hole', 51)
# (u'concentr', 51)
# (u'bond', 51)
# (u'worri', 51)
# (u'tobi', 51)
# (u'process', 51)
# (u'spread', 51)
# (u'human', 51)
# (u'switch', 51)
# (u'sink', 51)
# (u'flip', 51)
# (u'o', 50)
# (u'stretch', 50)
# (u'hundr', 50)
# (u'total', 50)
# (u'bounc', 50)
# (u'meet', 50)
# (u'weigh', 50)
# (u'convers', 50)
# (u'rise', 50)
# (u'describ', 50)
# (u'finger', 50)
# (u'kill', 50)
# (u'wall', 50)
# (u'lead', 50)
# (u'releas', 49)
# (u'support', 49)
# (u'neighbor', 49)
# (u'societi', 49)
# (u'gene', 49)
# (u'lost', 49)
# (u'loud', 49)
# (u'solar', 49)
# (u'design', 49)
# (u'king', 49)
# (u'oui', 49)
# (u'other', 49)
# (u'melt', 48)
# (u'frisbe', 48)
# (u'length', 48)
# (u'versu', 48)
# (u'block', 48)
# (u'anyway', 48)
# (u'realiz', 48)
# (u'mr', 48)
# (u'catch', 48)
# (u'densiti', 48)
# (u'besid', 48)
# (u'tree', 47)
# (u'respons', 47)
# (u'snail', 47)
# (u'function', 47)
# (u'7', 47)
# (u'18', 47)
# (u'train', 47)
# (u'nobodi', 47)
# (u'shoot', 47)
# (u'hang', 47)
# (u'cross', 47)
# (u'mouth', 46)
# (u'winter', 46)
# (u'citi', 46)
# (u'itd', 46)
# (u'relationship', 46)
# (u'atom', 46)
# (u'slide', 46)
# (u'qualiti', 46)
# (u'felt', 46)
# (u'similar', 46)
# (u'rang', 46)
# (u'characterist', 45)
# (u'kinet', 45)
# (u'save', 45)
# (u'structur', 45)
# (u'clone', 45)
# (u'collect', 45)
# (u'determin', 45)
# (u'transfer', 45)
# (u'et', 45)
# (u're', 44)
# (u'knew', 44)
# (u'research', 44)
# (u'allow', 44)
# (u'war', 44)
# (u'mostli', 44)
# (u'shoe', 44)
# (u'across', 44)
# (u'hola', 44)
# (u'motion', 44)
# (u'rubber', 44)
# (u'arm', 44)
# (u'yesterday', 43)
# (u'se', 43)
# (u'thumb', 43)
# (u'section', 43)
# (u'focu', 43)
# (u'super', 43)
# (u'meter', 43)
# (u'est', 43)
# (u'religi', 43)
# (u'symbol', 43)
# (u'sourc', 43)
# (u'short', 43)
# (u'pi', 43)
# (u'brought', 42)
# (u'act', 42)
# (u'plan', 42)
# (u'respir', 42)
# (u'odd', 42)
# (u'law', 42)
# (u'es', 42)
# (u'sign', 42)
# (u'hemispher', 42)
# (u'except', 42)
# (u'g', 42)
# (u'wast', 41)
# (u'child', 41)
# (u'exact', 41)
# (u'leg', 41)
# (u'scare', 41)
# (u'ya', 41)
# (u'ooh', 41)
# (u'seat', 41)
# (u'euh', 41)
# (u'mention', 41)
# (u'charact', 41)
# (u'muy', 41)
# (u'apart', 41)
# (u'consid', 41)
# (u'reaction', 41)
# (u'mixtur', 41)
# (u'appli', 41)
# (u'beauti', 40)
# (u'fix', 40)
# (u'letter', 40)
# (u'industri', 40)
# (u'challeng', 40)
# (u'bird', 40)
# (u'indic', 40)
# (u'earlier', 40)
# (u'heavi', 40)
# (u'danger', 40)
# (u'shake', 40)
# (u'treat', 40)
# (u'harder', 40)
# (u'lose', 40)
# (u'16', 40)
# (u'field', 40)
# (u'movement', 40)
# (u'spell', 40)
# (u'sunlight', 40)
# (u'tip', 40)
# (u'wood', 40)
# (u'list', 40)
# (u'cloth', 40)
# (u'dna', 39)
# (u'carbon', 39)
# (u'electr', 39)
# (u'spot', 39)
# (u'su', 39)
# (u'full', 39)
# (u'babi', 39)
# (u'hors', 39)
# (u'song', 39)
# (u'lab', 39)
# (u'band', 39)
# (u'beetl', 39)
# (u'northern', 39)
# (u'voic', 39)
# (u'met', 39)
# (u'tall', 39)
# (u'pair', 39)
# (u'forward', 39)
# (u'must', 39)
# (u'mi', 39)
# (u'environ', 39)
# (u'river', 39)
# (u'travel', 38)
# (u'remind', 38)
# (u'smell', 38)
# (u'boat', 38)
# (u'6', 38)
# (u'fait', 38)
# (u'phase', 38)
# (u'con', 38)
# (u'marker', 38)
# (u'non', 38)
# (u'ladi', 38)
# (u'carpet', 38)
# (u'bee', 38)
# (u'star', 38)
# (u'obvious', 38)
# (u'risk', 38)
# (u'quickli', 38)
# (u'appl', 38)
# (u'music', 37)
# (u'strike', 37)
# (u'formula', 37)
# (u'contrast', 37)
# (u'age', 37)
# (u'expand', 37)
# (u'kept', 37)
# (u'final', 37)
# (u'textur', 37)
# (u'grab', 37)
# (u'skill', 37)
# (u'futur', 37)
# (u'situat', 37)
# (u'earthquak', 37)
# (u'whatd', 37)
# (u'forget', 37)
# (u'larg', 37)
# (u'south', 37)
# (u'toy', 37)
# (u'ell', 37)
# (u'given', 37)
# (u'quit', 37)
# (u'taylor', 37)
# (u'fat', 37)
# (u'flat', 37)
# (u'reach', 37)
# (u'fossil', 36)
# (u'summer', 36)
# (u'bar', 36)
# (u'favorit', 36)
# (u'smart', 36)
# (u'wave', 36)
# (u'forgot', 36)
# (u'dot', 36)
# (u'glove', 36)
# (u'attract', 36)
# (u'n', 36)
# (u'rose', 36)
# (u'highest', 36)
# (u'v', 36)
# (u'rather', 36)
# (u'solv', 36)
# (u'tax', 36)
# (u'cake', 36)
# (u'confus', 35)
# (u'thermomet', 35)
# (u'ration', 35)
# (u'conclus', 35)
# (u'emot', 35)
# (u'wet', 35)
# (u'h', 35)
# (u'sarah', 35)
# (u'pizza', 35)
# (u'involv', 35)
# (u'shouldnt', 35)
# (u'evid', 35)
# (u'wax', 35)
# (u'ryan', 35)
# (u'calcul', 35)
# (u'dri', 35)
# (u'13', 35)
# (u'u', 35)
# (u'27', 35)
# (u'aliv', 35)
# (u'beat', 35)
# (u'anymor', 35)
# (u'mess', 35)
# (u'suggest', 35)
# (u'classroom', 35)
# (u'hasnt', 35)
# (u'store', 35)
# (u'view', 35)
# (u'troubl', 35)
# (u'assum', 34)
# (u'separ', 34)
# (u'gone', 34)
# (u'ta', 34)
# (u'morn', 34)
# (u'termin', 34)
# (u'hope', 34)
# (u'va', 34)
# (u'lay', 34)
# (u'quarter', 34)
# (u'drew', 34)
# (u'sticki', 34)
# (u'faith', 34)
# (u'4', 34)
# (u'spend', 34)
# (u'constant', 34)
# (u'hedgehog', 34)
# (u'infinit', 34)
# (u'compani', 34)
# (u'busi', 33)
# (u'si', 33)
# (u'te', 33)
# (u'machin', 33)
# (u'ink', 33)
# (u'target', 33)
# (u'properti', 33)
# (u'wheel', 33)
# (u'especi', 33)
# (u'strong', 33)
# (u'american', 33)
# (u'titl', 33)
# (u'sever', 33)
# (u'background', 33)
# (u'potato', 33)
# (u'track', 33)
# (u'cancer', 33)
# (u'filter', 33)
# (u'individu', 33)
# (u'swing', 33)
# (u'chose', 33)
# (u'entir', 33)
# (u'artist', 32)
# (u'evapor', 32)
# (u'social', 32)
# (u'rough', 32)
# (u'stage', 32)
# (u'theyv', 32)
# (u'studi', 32)
# (u'grew', 32)
# (u'bridg', 32)
# (u'technolog', 32)
# (u'una', 32)
# (u'burn', 32)
# (u'round', 32)
# (u'shot', 32)
# (u'moment', 32)
# (u'nail', 32)
# (u'theori', 32)
# (u'origin', 32)
# (u'colder', 32)
# (u'edg', 32)
# (u'frog', 32)
# (u'shell', 32)
# (u'clip', 32)
# (u'english', 32)
# (u'spin', 31)
# (u'hcl', 31)
# (u'axi', 31)
# (u'exercis', 31)
# (u'major', 31)
# (u'quest', 31)
# (u'jacob', 31)
# (u'near', 31)
# (u'paperclip', 31)
# (u'presid', 31)
# (u'father', 31)
# (u'doctor', 31)
# (u'hour', 31)
# (u'rotat', 31)
# (u'recess', 31)
# (u'ms', 31)
# (u'god', 31)
# (u'free', 31)
# (u'wear', 31)
# (u'tie', 31)
# (u'healthi', 31)
# (u'dioxid', 31)
# (u'review', 31)
# (u'freez', 31)
# (u'whenev', 31)
# (u'martha', 31)
# (u'dens', 31)
# (u'locat', 31)
# (u'leader', 31)
# (u'right', 30)
# (u'floor', 30)
# (u'screen', 30)
# (u'muscl', 30)
# (u'comput', 30)
# (u'equival', 30)
# (u'ago', 30)
# (u'land', 30)
# (u'race', 30)
# (u'tien', 30)
# (u'cest', 30)
# (u'styrofoam', 30)
# (u'josh', 30)
# (u'hell', 30)
# (u'multipl', 30)
# (u'southern', 30)
# (u'brain', 30)
# (u'contain', 30)
# (u'written', 30)
# (u'homework', 30)
# (u'diagon', 30)
# (u'sugar', 30)
# (u'vitamin', 30)
# (u'dead', 30)
# (u'cultur', 30)
# (u'print', 30)
# (u'purpl', 30)
# (u'includ', 30)
# (u'36', 30)
# (u'greater', 30)
# (u'congruent', 30)
# (u'reflect', 30)
# (u'brother', 30)
# (u'option', 30)
# (u'bouncer', 30)
# (u'tablet', 30)
# (u'women', 30)
# (u'son', 29)
# (u'wrap', 29)
# (u'chair', 29)
# (u'current', 29)
# (u'simpl', 29)
# (u'p', 29)
# (u'develop', 29)
# (u'maam', 29)
# (u'dissolv', 29)
# (u'taller', 29)
# (u'deal', 29)
# (u'main', 29)
# (u'\xe0', 29)
# (u'swim', 29)
# (u'soft', 29)
# (u'snow', 29)
# (u'transform', 29)
# (u'andi', 29)
# (u'purpos', 29)
# (u'serv', 29)
# (u'500', 29)
# (u'helmet', 29)
# (u'pollen', 29)
# (u'patriot', 29)
# (u'est\xe1', 28)
# (u'project', 28)
# (u'prevent', 28)
# (u'refer', 28)
# (u'nope', 28)
# (u'young', 28)
# (u'therefor', 28)
# (u'vein', 28)
# (u'liter', 28)
# (u'rascal', 28)
# (u'product', 28)
# (u'soon', 28)
# (u'bass', 28)
# (u'veloc', 28)
# (u'imagin', 28)
# (u'triangl', 28)
# (u'skull', 28)
# (u'farm', 28)
# (u'north', 28)
# (u'honey', 28)
# (u'jesu', 28)
# (u'milk', 28)
# (u'carri', 28)
# (u'label', 28)
# (u'built', 28)
# (u'click', 28)
# (u'tap', 28)
# (u'unless', 28)
# (u'tool', 28)
# (u'focus', 28)
# (u'row', 28)
# (u'quiet', 28)
# (u'teach', 28)
# (u'nick', 28)
# (u'sir', 28)
# (u'80', 28)
# (u'ear', 28)
# (u'sod', 27)
# (u'million', 27)
# (u'darker', 27)
# (u'au', 27)
# (u'tricki', 27)
# (u'huge', 27)
# (u'wed', 27)
# (u'tini', 27)
# (u'cone', 27)
# (u'graphic', 27)
# (u'irrat', 27)
# (u'er', 27)
# (u'anywher', 27)
# (u'scum', 27)
# (u'yo', 27)
# (u'radiat', 27)
# (u'frost', 27)
# (u'button', 27)
# (u'interpret', 27)
# (u'bead', 27)
# (u'plagiar', 27)
# (u'lizard', 27)
# (u'chime', 27)
# (u'analysi', 27)
# (u'initi', 27)
# (u'diseas', 27)
# (u'emili', 27)
# (u'nelson', 27)
# (u'para', 27)
# (u'radiu', 27)
# (u'entonc', 27)
# (u'pyramid', 27)
# (u'reli', 27)
# (u'slower', 27)
# (u'ian', 27)
# (u'nathan', 27)
# (u'whoa', 27)
# (u'sick', 27)
# (u'stress', 26)
# (u'truck', 26)
# (u'bumpi', 26)
# (u'denomin', 26)
# (u'drive', 26)
# (u'accept', 26)
# (u'exponenti', 26)
# (u'error', 26)
# (u'shorter', 26)
# (u'sister', 26)
# (u'smooth', 26)
# (u'slaveri', 26)
# (u'cow', 26)
# (u'lowest', 26)
# (u'economi', 26)
# (u'window', 26)
# (u'concern', 26)
# (u'bucket', 26)
# (u'librari', 26)
# (u'il', 26)
# (u'languag', 26)
# (u'mile', 26)
# (u'string', 26)
# (u'african', 26)
# (u'200', 26)
# (u'acceler', 26)
# (u'mountain', 26)
# (u'debat', 26)
# (u'tast', 26)
# (u'messag', 26)
# (u'plug', 26)
# (u'colin', 26)
# (u'underneath', 26)
# (u'christian', 26)
# (u'layer', 26)
# (u'difficult', 26)
# (u'growth', 26)
# (u'leap', 26)
# (u'restaur', 25)
# (u'effici', 25)
# (u'door', 25)
# (u'religion', 25)
# (u'send', 25)
# (u'porqu', 25)
# (u'wire', 25)
# (u'theyd', 25)
# (u'steam', 25)
# (u'fight', 25)
# (u'prove', 25)
# (u'beaver', 25)
# (u'death', 25)
# (u'momentum', 25)
# (u'histori', 25)
# (u'cell', 25)
# (u'win', 25)
# (u'powerpoint', 25)
# (u'discov', 25)
# (u'key', 25)
# (u'welcom', 25)
# (u'regular', 25)
# (u'elli', 25)
# (u'igneou', 25)
# (u'physic', 25)
# (u'chicken', 25)
# (u'surreal', 25)
# (u'zach', 25)
# (u'phone', 25)
# (u'onto', 25)
# (u'shade', 25)
# (u'hill', 25)
# (u'feed', 25)
# (u'respect', 25)
# (u'whale', 25)
# (u'column', 25)
# (u'cylind', 24)
# (u'grandma', 24)
# (u'knee', 24)
# (u'bright', 24)
# (u'thatll', 24)
# (u'convinc', 24)
# (u'church', 24)
# (u'david', 24)
# (u'footbal', 24)
# (u'overal', 24)
# (u'adi\xf3', 24)
# (u'basebal', 24)
# (u'independ', 24)
# (u'aim', 24)
# (u'ring', 24)
# (u'treatment', 24)
# (u'gase', 24)
# (u'older', 24)
# (u'pero', 24)
# (u'oti', 24)
# (u'warmer', 24)
# (u'm', 24)
# (u'shift', 24)
# (u'bon', 24)
# (u'within', 24)
# (u'greenhous', 24)
# (u'19', 24)
# (u'gotten', 24)
# (u'8', 24)
# (u'planet', 24)
# (u'detail', 24)
# (u'tweet', 24)
# (u'mud', 24)
# (u'weird', 24)
# (u'season', 24)
# (u'copi', 24)
# (u'eventu', 24)
# (u'glad', 24)
# (u'resourc', 24)
# (u'surpris', 24)
# (u'sky', 23)
# (u'vamo', 23)
# (u'action', 23)
# (u'tenth', 23)
# (u'meant', 23)
# (u'recogn', 23)
# (u'contact', 23)
# (u'zone', 23)
# (u'rhythm', 23)
# (u'chip', 23)
# (u'batteri', 23)
# (u'frequenc', 23)
# (u'synonym', 23)
# (u'easili', 23)
# (u'matt', 23)
# (u'jessica', 23)
# (u'dylan', 23)
# (u'medium', 23)
# (u'sedimentari', 23)
# (u'stream', 23)
# (u'cycl', 23)
# (u'period', 23)
# (u'author', 23)
# (u'expect', 23)
# (u'rid', 23)
# (u'consist', 23)
# (u'larger', 23)
# (u'tyler', 23)
# (u'how', 22)
# (u'diagram', 22)
# (u'simplifi', 22)
# (u'lift', 22)
# (u's\xed', 22)
# (u'twelv', 22)
# (u'bottl', 22)
# (u'impact', 22)
# (u'shower', 22)
# (u'scene', 22)
# (u'stronger', 22)
# (u'jessi', 22)
# (u'forth', 22)
# (u'colorless', 22)
# (u'born', 22)
# (u'c\xf3mo', 22)
# (u'stain', 22)
# (u'poor', 22)
# (u'thermal', 22)
# (u'safeti', 22)
# (u'humid', 22)
# (u'000', 22)
# (u'michael', 22)
# (u'special', 22)
# (u'manipul', 22)
# (u'tire', 22)
# (u'gain', 22)
# (u'calf', 22)
# (u'sam', 22)
# (u'allel', 22)
# (u'teeth', 22)
# (u'nectar', 22)
# (u'basket', 22)
# (u'island', 22)
# (u'deep', 22)
# (u'express', 22)
# (u'alor', 22)
# (u'throughout', 22)
# (u'compost', 22)
# (u'fault', 22)
# (u'towel', 22)
# (u'pond', 22)
# (u'pa', 22)
# (u'boom', 22)
# (u'doin', 21)
# (u'swiss', 21)
# (u'respond', 21)
# (u'worker', 21)
# (u'role', 21)
# (u'visual', 21)
# (u'argument', 21)
# (u'prime', 21)
# (u'instrument', 21)
# (u'integ', 21)
# (u'tube', 21)
# (u'surviv', 21)
# (u'cartoon', 21)
# (u'photosynthesi', 21)
# (u'expens', 21)
# (u'seriou', 21)
# (u'demonstr', 21)
# (u'steal', 21)
# (u'concept', 21)
# (u'fifth', 21)
# (u'eras', 21)
# (u'medic', 21)
# (u'articl', 21)
# (u'scoot', 21)
# (u'influenc', 21)
# (u'ben', 21)
# (u'whose', 21)
# (u'adult', 21)
# (u'quot', 21)
# (u'ship', 21)
# (u'jacket', 21)
# (u'crazi', 21)
# (u'corner', 21)
# (u'gravit', 21)
# (u'harm', 21)
# (u'distribut', 21)
# (u'\xe7a', 21)
# (u'curv', 21)
# (u'35', 21)
# (u'everywher', 21)
# (u'qu\xe9', 21)
# (u'moniqu', 21)
# (u'alga', 21)
# (u'hydrogen', 21)
# (u'seri', 21)
# (u'shingl', 21)
# (u'cours', 21)
# (u'friday', 21)
# (u'knowledg', 21)
# (u'press', 21)
# (u'owl', 21)
# (u'glass', 20)
# (u'explan', 20)
# (u'pro', 20)
# (u'kilogram', 20)
# (u'male', 20)
# (u'plane', 20)
# (u'jealou', 20)
# (u'popcorn', 20)
# (u'palabra', 20)
# (u'particl', 20)
# (u'dilut', 20)
# (u'grandpa', 20)
# (u'opportun', 20)
# (u'hannah', 20)
# (u'racket', 20)
# (u'husband', 20)
# (u'stereotyp', 20)
# (u'ruler', 20)
# (u'month', 20)
# (u'cameron', 20)
# (u'taken', 20)
# (u'beyond', 20)
# (u'lifetim', 20)
# (u'joue', 20)
# (u'crayon', 20)
# (u'popular', 20)
# (u'drain', 20)
# (u'speaker', 20)
# (u'uno', 20)
# (u'quand', 20)
# (u'skip', 20)
# (u'elect', 20)
# (u'pain', 20)
# (u'excit', 20)
# (u'often', 20)
# (u'bear', 20)
# (u'farthest', 20)
# (u'beaker', 20)
# (u'louder', 20)
# (u'm\xe1', 20)
# (u'rank', 20)
# (u'brandon', 20)
# (u'wagon', 20)
# (u'tock', 20)
# (u'64', 20)
# (u'yay', 20)
# (u'racist', 20)
# (u'abil', 20)
# (u'health', 20)
# (u'remov', 20)
# (u'dun', 20)
# (u'kick', 20)
# (u'insect', 20)
# (u'contribut', 20)
# (u'cheeto', 19)
# (u'adapt', 19)
# (u'wash', 19)
# (u'summar', 19)
# (u'sampl', 19)
# (u'thousand', 19)
# (u'aw', 19)
# (u'method', 19)
# (u'natali', 19)
# (u'bump', 19)
# (u'lili', 19)
# (u'consequ', 19)
# (u'worm', 19)
# (u'newton', 19)
# (u'prepar', 19)
# (u'replac', 19)
# (u'directli', 19)
# (u'tomorrow', 19)
# (u'ratio', 19)
# (u'punish', 19)
# (u'event', 19)
# (u'dirt', 19)
# (u'jordan', 19)
# (u'pregunta', 19)
# (u'imag', 19)
# (u'camera', 19)
# (u'biggest', 19)
# (u'bet', 19)
# (u'fuel', 19)
# (u'freedom', 19)
# (u'twist', 19)
# (u'buddi', 19)
# (u'polit', 19)
# (u'deeper', 19)
# (u'pitch', 19)
# (u'woman', 19)
# (u'proport', 19)
# (u'24', 19)
# (u'mental', 19)
# (u'statement', 19)
# (u'qui', 19)
# (u'monkey', 19)
# (u'mechan', 19)
# (u'tide', 19)
# (u'bernard', 19)
# (u'joke', 19)
# (u'howev', 19)
# (u'report', 19)
# (u'thirti', 19)
# (u'birthday', 19)
# (u'ann', 19)
# (u'por', 19)
# (u'60', 19)
# (u'model', 19)
# (u'gilgamesh', 19)
# (u'style', 19)
# (u'melodi', 19)
# (u'highlight', 19)
# (u'disappear', 19)
# (u'boil', 19)
# (u'local', 19)
# (u'theseu', 19)
# (u'budget', 18)
# (u'spoke', 18)
# (u'90', 18)
# (u'childhood', 18)
# (u'men', 18)
# (u'split', 18)
# (u'decis', 18)
# (u'cooki', 18)
# (u'west', 18)
# (u'delet', 18)
# (u'sell', 18)
# (u'funni', 18)
# (u'bounci', 18)
# (u'element', 18)
# (u'shut', 18)
# (u'desk', 18)
# (u'worth', 18)
# (u'provid', 18)
# (u'scenario', 18)
# (u'dream', 18)
# (u'vet', 18)
# (u'bald', 18)
# (u'banana', 18)
# (u'anthoni', 18)
# (u'quadrat', 18)
# (u'attack', 18)
# (u'equip', 18)
# (u'furnitur', 18)
# (u'elimin', 18)
# (u'reader', 18)
# (u'conjectur', 18)
# (u'yea', 18)
# (u'somehow', 18)
# (u'simul', 18)
# (u'fell', 18)
# (u'ping', 18)
# (u'advantag', 18)
# (u'sudden', 18)
# (u'moi', 18)
# (u'chlorin', 18)
# (u'diamond', 18)
# (u'paragraph', 18)
# (u'needl', 18)
# (u'electron', 18)
# (u'curl', 18)
# (u'join', 18)
# (u'parallel', 18)
# (u'evil', 18)
# (u'fantast', 18)
# (u'twice', 18)
# (u'lighter', 18)
# (u'worksheet', 18)
# (u'flag', 18)
# (u'pong', 18)
# (u'wouldv', 18)
# (u'zachari', 18)
# (u'mistak', 18)
# (u'cinco', 18)
# (u'9', 18)
# (u'nasa', 18)
# (u'vibrat', 18)
# (u'bought', 18)
# (u'member', 18)
# (u'investig', 18)
# (u'militari', 17)
# (u'rich', 17)
# (u'fail', 17)
# (u'condit', 17)
# (u'width', 17)
# (u'flood', 17)
# (u'ver', 17)
# (u'milligram', 17)
# (u'quadrant', 17)
# (u'internet', 17)
# (u'destroy', 17)
# (u'magic', 17)
# (u'thatd', 17)
# (u'stomach', 17)
# (u'bother', 17)
# (u'tick', 17)
# (u'wors', 17)
# (u'cat', 17)
# (u'topic', 17)
# (u'devon', 17)
# (u'broke', 17)
# (u'numer', 17)
# (u'lie', 17)
# (u'shine', 17)
# (u'react', 17)
# (u'quell', 17)
# (u'bed', 17)
# (u'poem', 17)
# (u'accur', 17)
# (u'tradit', 17)
# (u'don', 17)
# (u'grown', 17)
# (u'athlet', 17)
# (u'brianna', 17)
# (u'mari', 17)
# (u'mot', 17)
# (u'descript', 17)
# (u'public', 17)
# (u'twenti', 17)
# (u'suppli', 17)
# (u'nose', 17)
# (u'metal', 17)
# (u'tenni', 17)
# (u'enjoy', 17)
# (u'flow', 17)
# (u'corn', 17)
# (u'trend', 17)
# (u'como', 17)
# (u'racism', 17)
# (u'fai', 17)
# (u'divis', 17)
# (u'eulet', 17)
# (u'windi', 17)
# (u'elast', 17)
# (u'regul', 16)
# (u'credit', 16)
# (u'slightli', 16)
# (u'butterfli', 16)
# (u'econom', 16)
# (u'supplementari', 16)
# (u'gosh', 16)
# (u'gold', 16)
# (u'theme', 16)
# (u'steep', 16)
# (u'soprano', 16)
# (u'glue', 16)
# (u'crack', 16)
# (u'innoc', 16)
# (u'daughter', 16)
# (u'arch', 16)
# (u'strength', 16)
# (u'excus', 16)
# (u'cooler', 16)
# (u'occur', 16)
# (u'bean', 16)
# (u'cuando', 16)
# (u'densest', 16)
# (u'pool', 16)
# (u'medicin', 16)
# (u'fa', 16)
# (u'dakota', 16)
# (u'citizen', 16)
# (u'subtract', 16)
# (u'70', 16)
# (u'magnesia', 16)
# (u'attach', 16)
# (u'ingredi', 16)
# (u'candi', 16)
# (u'limit', 16)
# (u'protest', 16)
# (u'altitud', 16)
# (u'jame', 16)
# (u'calm', 16)
# (u'earn', 16)
# (u'femal', 16)
# (u'tile', 16)
# (u'17', 16)
# (u'sean', 16)
# (u'audienc', 16)
# (u'margin', 16)
# (u'heavier', 16)
# (u'osteoporosi', 16)
# (u'africa', 16)
# (u'particular', 16)
# (u'town', 16)
# (u'sphere', 16)
# (u'comfort', 16)
# (u'21', 16)
# (u'pad', 16)
# (u'websit', 16)
# (u'immigr', 16)
# (u'nage', 16)
# (u'success', 16)
# (u'thoma', 16)
# (u'eli', 16)
# (u'andrew', 16)
# (u'grupo', 16)
# (u'folk', 16)
# (u'leaf', 16)
# (u'van', 16)
# (u'wednesday', 15)
# (u'china', 15)
# (u'yup', 15)
# (u'scream', 15)
# (u'blew', 15)
# (u'calcium', 15)
# (u'melanin', 15)
# (u'exist', 15)
# (u'date', 15)
# (u'fertil', 15)
# (u'saliva', 15)
# (u'isabella', 15)
# (u'clap', 15)
# (u'hed', 15)
# (u'dirti', 15)
# (u'adam', 15)
# (u'dinosaur', 15)
# (u'dress', 15)
# (u'vocab', 15)
# (u'matthew', 15)
# (u'paus', 15)
# (u'plot', 15)
# (u'offic', 15)
# (u'guid', 15)
# (u'post', 15)
# (u'couldv', 15)
# (u'sport', 15)
# (u'soldier', 15)
# (u'egg', 15)
# (u'pue', 15)
# (u'blend', 15)
# (u'poke', 15)
# (u'christoph', 15)
# (u'gray', 15)
# (u'peter', 15)
# (u'homeostasi', 15)
# (u'volunt', 15)
# (u'symptom', 15)
# (u'featur', 15)
# (u'asymptot', 15)
# (u'kevin', 15)
# (u'aspect', 15)
# (u'desdemona', 15)
# (u'del', 15)
# (u'emiss', 15)
# (u'thick', 15)
# (u'park', 15)
# (u'task', 15)
# (u'becam', 15)
# (u'olymp', 15)
# (u'lake', 15)
# (u'although', 15)
# (u'wise', 15)
# (u'pig', 15)
# (u'sleep', 15)
# (u'ran', 15)
# (u'random', 15)
# (u'younger', 15)
# (u'farmer', 15)
# (u'senior', 15)
# (u'hungri', 15)
# (u'aaron', 15)
# (u'bend', 15)
# (u'egypt', 15)
# (u'chri', 15)
# (u'wrist', 15)
# (u'trap', 15)
# (u'dictionari', 15)
# (u'trebuchet', 15)
# (u'panchito', 14)
# (u'peut', 14)
# (u'arrow', 14)
# (u'ate', 14)
# (u'technic', 14)
# (u'cheddar', 14)
# (u'joseph', 14)
# (u'nager', 14)
# (u'angri', 14)
# (u'envelop', 14)
# (u'reusabl', 14)
# (u'bite', 14)
# (u'requir', 14)
# (u'anti', 14)
# (u'al', 14)
# (u'tight', 14)
# (u'vocabulari', 14)
# (u'tail', 14)
# (u'pound', 14)
# (u'crescendo', 14)
# (u'prairi', 14)
# (u'jacki', 14)
# (u'tambi\xe9n', 14)
# (u'spill', 14)
# (u'segment', 14)
# (u'funnel', 14)
# (u'daniel', 14)
# (u'standard', 14)
# (u'maddi', 14)
# (u'kale', 14)
# (u'jose', 14)
# (u'market', 14)
# (u'reduc', 14)
# (u'catwalk', 14)
# (u'georg', 14)
# (u'tobacco', 14)
# (u'tend', 14)
# (u'slowli', 14)
# (u'grandfath', 14)
# (u'linear', 14)
# (u'gym', 14)
# (u'hacer', 14)
# (u'toss', 14)
# (u'addi', 14)
# (u'paid', 14)
# (u'pill', 14)
# (u'none', 14)
# (u'lesson', 14)
# (u'32', 14)
# (u'luggag', 14)
# (u'democraci', 14)
# (u'rel', 14)
# (u'accord', 14)
# (u'twelfth', 14)
# (u'alka', 14)
# (u'coaster', 14)
# (u'pued', 14)
# (u'hide', 14)
# (u'danni', 14)
# (u'civil', 14)
# (u'passag', 14)
# (u'plastic', 14)
# (u'grass', 14)
# (u'struggl', 14)
# (u'storm', 14)
# (u'postur', 14)
# (u'75', 14)
# (u'invis', 14)
# (u'ark', 14)
# (u'frozen', 14)
# (u'wherev', 14)
# (u'anna', 14)
# (u'perpendicular', 14)
# (u'brian', 14)
# (u'billi', 14)
# (u'favor', 14)
# (u'joe', 14)
# (u'wild', 14)
# (u'motiv', 14)
# (u'hop', 13)
# (u'pocket', 13)
# (u'roller', 13)
# (u'creek', 13)
# (u'emilia', 13)
# (u'creativ', 13)
# (u'jane', 13)
# (u'duel', 13)
# (u'confuciu', 13)
# (u'confid', 13)
# (u'madison', 13)
# (u'canon', 13)
# (u'claw', 13)
# (u'puppi', 13)
# (u'metamorph', 13)
# (u'tv', 13)
# (u'clock', 13)
# (u'olivia', 13)
# (u'achiev', 13)
# (u'signatur', 13)
# (u'tr\xe8', 13)
# (u'spring', 13)
# (u'poster', 13)
# (u'marri', 13)
# (u'drill', 13)
# (u'doze', 13)
# (u'termit', 13)
# (u'familiar', 13)
# (u'abbi', 13)
# (u'immedi', 13)
# (u'dude', 13)
# (u'counterweight', 13)
# (u'upon', 13)
# (u'iago', 13)
# (u'avoid', 13)
# (u'bread', 13)
# (u'l', 13)
# (u'seltzer', 13)
# (u'du', 13)
# (u'awar', 13)
# (u'drawn', 13)
# (u'encourag', 13)
# (u'rail', 13)
# (u'lewi', 13)
# (u'hotter', 13)
# (u'global', 13)
# (u'appear', 13)
# (u'wavelength', 13)
# (u'argu', 13)
# (u'blind', 13)
# (u'price', 13)
# (u'logan', 13)
# (u'blame', 13)
# (u'gentlemen', 13)
# (u'fruit', 13)
# (u'sling', 13)
# (u'hire', 13)
# (u'longest', 13)
# (u'as\xed', 13)
# (u'disagr', 13)
# (u'woo', 13)
# (u'nervou', 13)
# (u'rub', 13)
# (u'depth', 13)
# (u'friendli', 13)
# (u'ride', 13)
# (u'hip', 13)
# (u'blake', 13)
# (u'handl', 13)
# (u'autr', 13)
# (u'bare', 13)
# (u'neutral', 13)
# (u'display', 13)
# (u'luther', 13)
# (u'crew', 13)
# (u'une', 13)
# (u'allez', 13)
# (u'neat', 13)
# (u'identifi', 13)
# (u'billion', 13)
# (u'oop', 13)
# (u'max', 13)
# (u'cute', 13)
# (u'rachel', 13)
# (u'jake', 13)
# (u'broken', 13)
# (u'road', 13)
# (u'jonah', 13)
# (u'splash', 13)
# (u'explor', 13)
# (u'circumfer', 13)
# (u'fiction', 13)
# (u'howd', 13)
# (u'ladder', 13)
# (u'patient', 13)
# (u'surafel', 13)
# (u'tijera', 13)
# (u'puppet', 13)
# (u'gather', 13)
# (u'bicycl', 13)
# (u'equilibrium', 13)
# (u'conform', 13)
# (u'45', 13)
# (u'chuck', 13)
# (u'd\xf3nde', 13)
# (u'backward', 13)
# (u'celebr', 13)
# (u'uncl', 13)
# (u'suspend', 13)
# (u'hun', 13)
# (u'egyptian', 13)
# (u'popsicl', 13)
# (u'famou', 13)
# (u'construct', 13)
# (u'necklac', 13)
# (u'72', 13)
# (u'martin', 13)
# (u'alien', 13)
# (u'sin', 13)
# (u'crash', 13)
# (u'addit', 13)
# (u'absorpt', 13)
# (u'k', 12)
# (u'perspect', 12)
# (u'wing', 12)
# (u'instruct', 12)
# (u'cushioni', 12)
# (u'hospit', 12)
# (u'logic', 12)
# (u'tornado', 12)
# (u'colleg', 12)
# (u'tear', 12)
# (u'address', 12)
# (u'compress', 12)
# (u'anagelia', 12)
# (u'manag', 12)
# (u'leadership', 12)
# (u'strand', 12)
# (u'voltag', 12)
# (u'trade', 12)
# (u'belief', 12)
# (u'cri', 12)
# (u'pendulum', 12)
# (u'400', 12)
# (u'elev', 12)
# (u'sight', 12)
# (u'agreement', 12)
# (u'swirl', 12)
# (u'vehicl', 12)
# (u'vinegar', 12)
# (u'counter', 12)
# (u'decay', 12)
# (u'soak', 12)
# (u'cuatro', 12)
# (u'snake', 12)
# (u'varieti', 12)
# (u'monday', 12)
# (u'era', 12)
# (u'tourniquet', 12)
# (u'germani', 12)
# (u'volleybal', 12)
# (u'photo', 12)
# (u'carousel', 12)
# (u'trick', 12)
# (u'media', 12)
# (u'ding', 12)
# (u'eddi', 12)
# (u'particip', 12)
# (u'loop', 12)
# (u'belong', 12)
# (u'rug', 12)
# (u'stride', 12)
# (u'forev', 12)
# (u'aqu\xed', 12)
# (u'parti', 12)
# (u'ashley', 12)
# (u'lauren', 12)
# (u'necessari', 12)
# (u'twitter', 12)
# (u'overlap', 12)
# (u'restat', 12)
# (u'moral', 12)
# (u'maintain', 12)
# (u'taught', 12)
# (u'threw', 12)
# (u'afternoon', 12)
# (u'alto', 12)
# (u'extrem', 12)
# (u'alexi', 12)
# (u'prism', 12)
# (u'escap', 12)
# (u'vermicompost', 12)
# (u'suffer', 12)
# (u'28', 12)
# (u'alon', 12)
# (u'fur', 12)
# (u'300', 12)
# (u'cure', 12)
# (u'clipboard', 12)
# (u'dan', 12)
# (u'cu\xe1l', 12)
# (u'cabin', 12)
# (u'laugh', 12)
# (u'bulb', 12)
# (u'rectangular', 12)
# (u'cubic', 12)
# (u'toma', 12)
# (u'bug', 12)
# (u'47', 12)
# (u'basketbal', 12)
# (u'path', 12)
# (u'underhand', 12)
# (u'ray', 12)
# (u'reconstruct', 12)
# (u'weak', 12)
# (u'news', 12)
# (u'recharg', 12)
# (u'ne', 12)
# (u'tim', 12)
# (u'hormon', 12)
# (u'witch', 12)
# (u'chloe', 12)
# (u'ideal', 12)
# (u'proud', 12)
# (u'complic', 12)
# (u'procedur', 12)
# (u'runoff', 12)
# (u'soccer', 12)
# (u'atmospher', 12)
# (u'fastest', 12)
# (u'due', 12)
# (u'behavior', 12)
# (u'rip', 12)
# (u'stimul', 12)
# (u'squeez', 12)
# (u'fed', 12)
# (u'bisector', 12)
# (u'rabbit', 12)
# (u'angular', 12)
# (u'boot', 12)
# (u'accid', 11)
# (u'rectangl', 11)
# (u'interrupt', 11)
# (u'camp', 11)
# (u'score', 11)
# (u'tune', 11)
# (u'umm', 11)
# (u'chain', 11)
# (u'suck', 11)
# (u'woah', 11)
# (u'helmholtz', 11)
# (u'grandpar', 11)
# (u'\xe9t\xe9', 11)
# (u'llama', 11)
# (u'bell', 11)
# (u'input', 11)
# (u'colorado', 11)
# (u'hello', 11)
# (u'garden', 11)
# (u'eleven', 11)
# (u'tomato', 11)
# (u'robot', 11)
# (u'parabola', 11)
# (u'clearli', 11)
# (u'jaw', 11)
# (u'frame', 11)
# (u'site', 11)
# (u'captur', 11)
# (u'guarante', 11)
# (u'smoke', 11)
# (u'beach', 11)
# (u'salon', 11)
# (u'bank', 11)
# (u'tough', 11)
# (u'trunk', 11)
# (u'wider', 11)
# (u'ident', 11)
# (u'bunni', 11)
# (u'kyle', 11)
# (u'curiou', 11)
# (u'rubric', 11)
# (u'precipit', 11)
# (u'nitrogen', 11)
# (u'engin', 11)
# (u'damag', 11)
# (u'helium', 11)
# (u'nurs', 11)
# (u'held', 11)
# (u'estrogen', 11)
# (u'kidney', 11)
# (u'tongu', 11)
# (u'washo', 11)
# (u'enkidu', 11)
# (u'baleen', 11)
# (u'\xbd', 11)
# (u'nation', 11)
# (u'osteoblast', 11)
# (u'armi', 11)
# (u'privileg', 11)
# (u'meat', 11)
# (u'hook', 11)
# (u'somewhat', 11)
# (u'modern', 11)
# (u'receiv', 11)
# (u'shoulder', 11)
# (u'clair', 11)
# (u'mat', 11)
# (u'goug', 11)
# (u'channel', 11)
# (u'hab\xeda', 11)
# (u'trader', 11)
# (u'bryson', 11)
# (u'sunflow', 11)
# (u'shelter', 11)
# (u'establish', 11)
# (u'minimum', 11)
# (u'sharp', 11)
# (u'coal', 11)
# (u'pens', 11)
# (u'22', 11)
# (u'29', 11)
# (u'fue', 11)
# (u'pet', 11)
# (u'fluenci', 11)
# (u'molar', 11)
# (u'tab', 11)
# (u'labor', 11)
# (u'mmhm', 11)
# (u'heel', 11)
# (u'eso', 11)
# (u'panel', 11)
# (u'brand', 11)
# (u'49', 11)
# (u'nutrient', 11)
# (u'yell', 11)
# (u'jack', 11)
# (u'disney', 11)
# (u'r\xe9pons', 11)
# (u'gibbou', 11)
# (u'ton', 11)
# (u'murder', 11)
# (u'mother', 11)
# (u'expon', 11)
# (u'cooper', 11)
# (u'surround', 11)
# (u'algo', 11)
# (u'storag', 11)
# (u'factori', 11)
# (u'jakiah', 11)
# (u'holden', 11)
# (u'sandpap', 11)
# (u'esophagu', 11)
# (u'alcohol', 11)
# (u'fanci', 11)
# (u'rigo', 11)
# (u'momma', 11)
# (u'infer', 11)
# (u'proof', 11)
# (u'tension', 11)
# (u'tray', 11)
# (u'rare', 11)
# (u'sweat', 11)
# (u'injur', 11)
# (u'distract', 11)
# (u'experienc', 11)
# (u'tatum', 10)
# (u'golden', 10)
# (u'master', 10)
# (u'brawni', 10)
# (u'shall', 10)
# (u'extent', 10)
# (u'offer', 10)
# (u'wiffl', 10)
# (u'93', 10)
# (u'easiest', 10)
# (u'pretend', 10)
# (u'devito', 10)
# (u'loudli', 10)
# (u'dribbl', 10)
# (u'rush', 10)
# (u'googl', 10)
# (u'sank', 10)
# (u'isaac', 10)
# (u'avec', 10)
# (u'avez', 10)
# (u'obama', 10)
# (u'debajo', 10)
# (u'dehydr', 10)
# (u'golf', 10)
# (u'sunni', 10)
# (u'sea', 10)
# (u'fund', 10)
# (u'tribe', 10)
# (u'a\xf1o', 10)
# (u'format', 10)
# (u'carol', 10)
# (u'sock', 10)
# (u'isaiah', 10)
# (u'tre', 10)
# (u'vertic', 10)
# (u'marrow', 10)
# (u'nada', 10)
# (u'scari', 10)
# (u'scarf', 10)
# (u'aye', 10)
# (u'otherwis', 10)
# (u'petroglyph', 10)
# (u'upsid', 10)
# (u'indent', 10)
# (u'elbow', 10)
# (u'oppress', 10)
# (u'dr', 10)
# (u'mole', 10)
# (u'angel', 10)
# (u'sierra', 10)
# (u'comeback', 10)
# (u'foam', 10)
# (u'ami', 10)
# (u'heater', 10)
# (u'nerv', 10)
# (u'engrav', 10)
# (u'kurten', 10)
# (u'dire', 10)
# (u'caption', 10)
# (u'proton', 10)
# (u'empti', 10)
# (u'pack', 10)
# (u'gracia', 10)
# (u'vaccin', 10)
# (u'jonathan', 10)
# (u'globe', 10)
# (u'umbrella', 10)
# (u'ethan', 10)
# (u'120', 10)
# (u'correctli', 10)
# (u'tuesday', 10)
# (u'cent', 10)
# (u'whoo', 10)
# (u'hm', 10)
# (u'pardon', 10)
# (u'asid', 10)
# (u'net', 10)
# (u'subject', 10)
# (u'anchor', 10)
# (u'unfair', 10)
# (u'interv', 10)
# (u'invent', 10)
# (u'magnet', 10)
# (u'144', 10)
# (u'oppos', 10)
# (u'interior', 10)
# (u'trace', 10)
# (u'paig', 10)
# (u'sunglass', 10)
# (u'summari', 10)
# (u'improv', 10)
# (u'speech', 10)
# (u'assist', 10)
# (u'smithson', 10)
# (u'christina', 10)
# (u'chlorid', 10)
# (u'muchacho', 10)
# (u'sequenc', 10)
# (u'medicina', 10)
# (u'remain', 10)
# (u'biographi', 10)
# (u'dragon', 10)
# (u'mysteri', 10)
# (u'180', 10)
# (u'travail', 10)
# (u'previou', 10)
# (u'giant', 10)
# (u'cheaper', 10)
# (u'snap', 10)
# (u'strongest', 10)
# (u'passiv', 10)
# (u'lamp', 10)
# (u'whoop', 10)
# (u'throat', 10)
# (u'integr', 10)
# (u'progress', 10)
# (u'instanc', 10)
# (u'sunburn', 10)
# (u'shuttl', 10)
# (u'insert', 10)
# (u'j', 10)
# (u'goin', 10)
# (u'persuad', 10)
# (u'heatstrok', 10)
# (u'flame', 10)
# (u'drip', 10)
# (u'stephani', 10)
# (u'resist', 10)
# (u'51', 10)
# (u'indirect', 10)
# (u'signific', 10)
# (u'chapter', 10)
# (u'judg', 10)
# (u'patrick', 10)
# (u'ow', 10)
# (u'program', 10)
# (u'fan', 10)
# (u'cloudi', 10)
# (u'pablo', 10)
# (u'interact', 10)
# (u'poner', 10)
# (u'bibl', 10)
# (u'wherea', 10)
# (u'othello', 10)
# (u'fold', 10)
# (u'glucos', 10)
# (u'molli', 10)
# (u'adrian', 10)
# (u'dent', 10)
# (u'bisect', 10)
# (u'erin', 10)
# (u'113', 10)
# (u'automat', 10)
# (u'scientif', 10)
# (u'peux', 9)
# (u'vari', 9)
# (u'kayla', 9)
# (u'spent', 9)
# (u'sexism', 9)
# (u'clicker', 9)
# (u'cushion', 9)
# (u'parler', 9)
# (u'employ', 9)
# (u'chacko', 9)
# (u'fairli', 9)
# (u'fog', 9)
# (u'150', 9)
# (u'scholarship', 9)
# (u'verdad', 9)
# (u'stone', 9)
# (u'darken', 9)
# (u'collid', 9)
# (u'prior', 9)
# (u'grace', 9)
# (u'carlo', 9)
# (u'self', 9)
# (u'steerag', 9)
# (u'pouvez', 9)
# (u'histor', 9)
# (u'kelli', 9)
# (u'bb', 9)
# (u'sent', 9)
# (u'indian', 9)
# (u'scatter', 9)
# (u'steel', 9)
# (u'jai', 9)
# (u'drum', 9)
# (u'juan', 9)
# (u'profici', 9)
# (u'pesticid', 9)
# (u'newspap', 9)
# (u'butter', 9)
# (u'bore', 9)
# (u'dilemma', 9)
# (u'profession', 9)
# (u'deloc', 9)
# (u'blast', 9)
# (u'kendrel', 9)
# (u'seizur', 9)
# (u'clue', 9)
# (u'5x5x5', 9)
# (u'christma', 9)
# (u'snack', 9)
# (u'asleep', 9)
# (u'raul', 9)
# (u'central', 9)
# (u'blank', 9)
# (u'hayden', 9)
# (u'phenylthalen', 9)
# (u'colbi', 9)
# (u'sketch', 9)
# (u'jouez', 9)
# (u'\xeatre', 9)
# (u'kati', 9)
# (u'airplan', 9)
# (u'starter', 9)
# (u'kenni', 9)
# (u'brook', 9)
# (u'border', 9)
# (u'upset', 9)
# (u'chalk', 9)
# (u'shed', 9)
# (u'hi', 9)
# (u'ha', 9)
# (u'eric', 9)
# (u'entr', 9)
# (u'joann', 9)
# (u'intestin', 9)
# (u'workout', 9)
# (u'maria', 9)
# (u'simplest', 9)
# (u'servic', 9)
# (u'applic', 9)
# (u'item', 9)
# (u'kelsey', 9)
# (u'fenc', 9)
# (u'lorenzo', 9)
# (u'effort', 9)
# (u'claim', 9)
# (u'mai', 9)
# (u'tractor', 9)
# (u'shop', 9)
# (u'forecast', 9)
# (u'sideway', 9)
# (u'median', 9)
# (u'ultim', 9)
# (u'everyday', 9)
# (u'izaiah', 9)
# (u'quietli', 9)
# (u'brandi', 9)
# (u'buffalo', 9)
# (u'variat', 9)
# (u'associ', 9)
# (u'stabl', 9)
# (u'youth', 9)
# (u'mam\xe1', 9)
# (u'luke', 9)
# (u'popul', 9)
# (u'simpli', 9)
# (u'wage', 9)
# (u'cuz', 9)
# (u'princip', 9)
# (u'reproduc', 9)
# (u'pap\xe1', 9)
# (u'translat', 9)
# (u'peanut', 9)
# (u'mous', 9)
# (u'bueno', 9)
# (u'bye', 9)
# (u'plain', 9)
# (u'judgment', 9)
# (u'clinic', 9)
# (u'condens', 9)
# (u'esa', 9)
# (u'pheromon', 9)
# (u'whisper', 9)
# (u'41', 9)
# (u'oedipu', 9)
# (u'emma', 9)
# (u'lodg', 9)
# (u'd\xeda', 9)
# (u'straw', 9)
# (u'enter', 9)
# (u'depress', 9)
# (u'restrict', 9)
# (u'grader', 9)
# (u'spongi', 9)
# (u'turbin', 9)
# (u'environment', 9)
# (u'ramaji', 9)
# (u'memori', 9)
# (u'gusta', 9)
# (u'1000', 9)
# (u'analyz', 9)
# (u'spirit', 9)
# (u'pilot', 9)
# (u'ou', 9)
# (u'regard', 9)
# (u'calli', 9)
# (u'thursday', 9)
# (u'crush', 9)
# (u'voyag', 9)
# (u'known', 9)
# (u'myspac', 9)
# (u'perhap', 9)
# (u'amaz', 9)
# (u'dump', 9)
# (u'solo', 9)
# (u'genet', 9)
# (u'sweet', 9)
# (u'lexi', 9)
# (u'simon', 9)
# (u'duck', 9)
# (u'stroke', 9)
# (u'tack', 9)
# (u'categori', 9)
# (u'led', 9)
# (u'spur', 9)
# (u'own', 9)
# (u'ten\xeda', 8)
# (u'miller', 8)
# (u'clorox', 8)
# (u'wane', 8)
# (u'silent', 8)
# (u'layout', 8)
# (u'union', 8)
# (u'player', 8)
# (u'east', 8)
# (u'crowd', 8)
# (u'recommend', 8)
# (u'intens', 8)
# (u'meteorologist', 8)
# (u'98', 8)
# (u'whoever', 8)
# (u'franc', 8)
# (u'improvis', 8)
# (u'est\xe1n', 8)
# (u'titrat', 8)
# (u'sophia', 8)
# (u'borrow', 8)
# (u'extern', 8)
# (u'dimension', 8)
# (u'racial', 8)
# (u'homeless', 8)
# (u'rust', 8)
# (u'cream', 8)
# (u'quicker', 8)
# (u'morgan', 8)
# (u'penetr', 8)
# (u'abnorm', 8)
# (u'dandelion', 8)
# (u'outward', 8)
# (u'voy', 8)
# (u'sydney', 8)
# (u'span', 8)
# (u'disast', 8)
# (u'lock', 8)
# (u'chosen', 8)
# (u'nois', 8)
# (u'packet', 8)
# (u'criss', 8)
# (u'tina', 8)
# (u'highli', 8)
# (u'kiwi', 8)
# (u'aunt', 8)
# (u'do', 8)
# (u'aid', 8)
# (u'epa', 8)
# (u'shout', 8)
# (u'percentag', 8)
# (u'certainli', 8)
# (u'alana', 8)
# (u'upper', 8)
# (u'uniform', 8)
# (u'regardless', 8)
# (u'hall', 8)
# (u'accomplish', 8)
# (u'carp', 8)
# (u'dentro', 8)
# (u'stair', 8)
# (u'osteoclast', 8)
# (u'venu', 8)
# (u'elementari', 8)
# (u'starv', 8)
# (u'tengo', 8)
# (u'valid', 8)
# (u'juic', 8)
# (u'estaba', 8)
# (u'verb', 8)
# (u'dimens', 8)
# (u'excess', 8)
# (u'cave', 8)
# (u'won', 8)
# (u'stem', 8)
# (u'council', 8)
# (u'alicia', 8)
# (u'sweeti', 8)
# (u'waist', 8)
# (u'conduct', 8)
# (u'lui', 8)
# (u'career', 8)
# (u'quil', 8)
# (u'fireman', 8)
# (u'dajana', 8)
# (u'sofia', 8)
# (u'fernando', 8)
# (u'candl', 8)
# (u'evalu', 8)
# (u'jami', 8)
# (u'warn', 8)
# (u'worst', 8)
# (u'climat', 8)
# (u'promis', 8)
# (u'hoop', 8)
# (u'probe', 8)
# (u'watermelon', 8)
# (u'parachut', 8)
# (u'cerca', 8)
# (u'cousin', 8)
# (u'parsley', 8)
# (u'tank', 8)
# (u'tadpol', 8)
# (u'ella', 8)
# (u'bailey', 8)
# (u'ignor', 8)
# (u'dip', 8)
# (u'till', 8)
# (u'map', 8)
# (u'principl', 8)
# (u'sprout', 8)
# (u'boundari', 8)
# (u'kiara', 8)
# (u'jeffrey', 8)
# (u'pile', 8)
# (u'grip', 8)
# (u'gross', 8)
# (u'lejo', 8)
# (u'file', 8)
# (u'stood', 8)
# (u'transit', 8)
# (u'explod', 8)
# (u'awkward', 8)
# (u'26', 8)
# (u'late', 8)
# (u'particularli', 8)
# (u'ruin', 8)
# (u'wrinkl', 8)
# (u'adb', 8)
# (u'bill', 8)
# (u'parenthes', 8)
# (u'bin', 8)
# (u'knock', 8)
# (u'steven', 8)
# (u'shock', 8)
# (u'onlin', 8)
# (u'sixteenth', 8)
# (u'helper', 8)
# (u'samantha', 8)
# (u'weapon', 8)
# (u'diana', 8)
# (u'ocean', 8)
# (u'trust', 8)
# (u'bathroom', 8)
# (u'greatest', 8)
# (u'picasso', 8)
# (u'no', 8)
# (u'valentin', 8)
# (u'criteria', 8)
# (u'61', 8)
# (u'anytim', 8)
# (u'halfway', 8)
# (u'kimberli', 8)
# (u'concuss', 8)
# (u'cabinet', 8)
# (u'usted', 8)
# (u'lack', 8)
# (u'mmm', 8)
# (u'w', 8)
# (u'bout', 8)
# (u'dant', 8)
# (u'moist', 8)
# (u'statist', 8)
# (u'vincent', 8)
# (u'dvdt', 8)
# (u'ni\xf1o', 8)
# (u'whichev', 8)
# (u'typic', 8)
# (u'musician', 8)
# (u'carrot', 8)
# (u'tan', 8)
# (u'honestli', 8)
# (u'drdt', 8)
# (u'settl', 8)
# (u'jenni', 8)
# (u'pigment', 7)
# (u'holi', 7)
# (u'blade', 7)
# (u'corbin', 7)
# (u'hum', 7)
# (u'professor', 7)
# (u'sauc', 7)
# (u'canyon', 7)
# (u'thingi', 7)
# (u'geometr', 7)
# (u'teas', 7)
# (u'jim', 7)
# (u'mucho', 7)
# (u'russia', 7)
# (u'hockey', 7)
# (u'blah', 7)
# (u'216', 7)
# (u'62', 7)
# (u'payton', 7)
# (u'xylophon', 7)
# (u'illustr', 7)
# (u'andrea', 7)
# (u'strang', 7)
# (u'select', 7)
# (u'gravel', 7)
# (u'all\xe1', 7)
# (u'arrang', 7)
# (u'properli', 7)
# (u'sayin', 7)
# (u'devil', 7)
# (u'formal', 7)
# (u'ivan', 7)
# (u'custom', 7)
# (u'pastor', 7)
# (u'up', 7)
# (u'essay', 7)
# ...
# (u'pourquoi', 1)
# (u'deed', 1)
# (u'personnel', 1)
# (u'outfield', 1)
# (u'respuesta', 1)
# (u'teakettl', 1)
# (u'keepin', 1)
# (u'oxidada', 1)
# (u'volviera', 1)
# (u'escal', 1)
# (u'sewer', 1)
# (u'kavya', 1)
# (u'liar', 1)
# (u'phonolog', 1)
# (u'cpctc', 1)
# (u'zing', 1)
# (u'semest', 1)
# (u'wunder', 1)
# (u'respoir', 1)
# (u'puffi', 1)
# (u'steve', 1)
# (u'cont\xe9', 1)
# (u'magenet', 1)
# (u'strung', 1)
# (u'lawyer', 1)
# (u'ribbon', 1)
# (u'diag', 1)
# (u'pluse', 1)
# (u'quieto', 1)
# (u'miseri', 1)
# (u'spotlight', 1)
# (u'dicta', 1)
# (u'lawrenc', 1)
# (u'curar', 1)
# (u'bombin', 1)
# (u'levon', 1)
# (u'liber', 1)
# (u'lollipop', 1)
# (u'trist', 1)
# (u'desir', 1)
# (u'yolanda', 1)
# (u'expedit', 1)
# (u'dev', 1)
# (u'den', 1)
# (u'dee', 1)
# (u'rainstorm', 1)
# (u'mainstream', 1)
# (u'amistad', 1)
# (u'centimetr', 1)
# (u'levantado', 1)
# (u'bradi', 1)
# (u'ensembl', 1)
# (u'infant', 1)
# (u'dough', 1)
# (u'oxford', 1)
# (u'musiqu', 1)
# (u'drake', 1)
# (u'2a', 1)
# (u'harp', 1)
# (u'suprem', 1)
# (u'childish', 1)
# (u'suspici', 1)
# (u'faucet', 1)
# (u'intermingl', 1)
# (u'taho', 1)
# (u'hubiera', 1)
# (u'barbarian', 1)
# (u'cada', 1)
# (u'majorit\xe9', 1)
# (u'185', 1)
# (u'darkroom', 1)
# (u'ocho', 1)
# (u'dentist', 1)
# (u'pars', 1)
# (u'contrari', 1)
# (u'pudieran', 1)
# (u'savageri', 1)
# (u'blanca', 1)
# (u'becca', 1)
# (u'cameroon', 1)
# (u'kg', 1)
# (u'ki', 1)
# (u'2nd', 1)
# (u'mammoth', 1)
# (u'chester', 1)
# (u'ku', 1)
# (u'coli', 1)
# (u'luniversit\xe9', 1)
# (u'tempestu', 1)
# (u'epidem', 1)
# (u'kil', 1)
# (u'theft', 1)
# (u'silo', 1)
# (u'uncomfort', 1)
# (u'vino', 1)
# (u'vine', 1)
# (u'grupito', 1)
# (u'tender', 1)
# (u'11th', 1)
# (u'complement', 1)
# (u'po', 1)
# (u'marilyn', 1)
# (u'necesario', 1)
# (u'annual', 1)
# (u'alot', 1)
# (u'paran', 1)
# (u'screwi', 1)
# (u'v\xe9lo', 1)
# (u'silic', 1)
# (u'mikey', 1)
# (u'chattel', 1)
# (u'gentil', 1)
# (u'gay', 1)
# (u'demasiado', 1)
# (u'kathi', 1)
# (u'whitney', 1)
# (u'cruelti', 1)
# (u'crutch', 1)
# (u'quieter', 1)
# (u'ingrain', 1)
# (u'butcher', 1)
# (u'furia', 1)
# (u'impement', 1)
# (u'achek', 1)
# (u'ruth', 1)
# (u'memphi', 1)
# (u'development', 1)
# (u'itch', 1)
# (u'suficientement', 1)
# (u'vimo', 1)
# (u'luxuri', 1)
# (u'werewolf', 1)
# (u'rakif', 1)
# (u'chemistri', 1)
# (u'werewolv', 1)
# (u'suici', 1)
# (u'vacuum', 1)
# (u'1963', 1)
# (u'allhors', 1)
# (u'nuestro', 1)
# (u'respeto', 1)
# (u'trataba', 1)
# (u'forbid', 1)
# (u'bio', 1)
# (u'serv\xedan', 1)
# (u'redeem', 1)
# (u'thoroughli', 1)
# (u'extremist', 1)
# (u'mostrar', 1)
# (u'peu', 1)
# (u'impos', 1)
# (u'morri', 1)
# (u'bish', 1)
# (u'pertin', 1)
# (u'krayla', 1)
# (u'brass', 1)
# (u'trrr', 1)
# (u'implaus', 1)
# (u'poder', 1)
# (u'plut\xf4t', 1)
# (u'gauss', 1)
# (u'bioscan', 1)
# (u'jumbo', 1)
# (u'beldo', 1)
# (u'scarlet', 1)
# (u'cura', 1)
# (u'muestra', 1)
# (u'lena', 1)
# (u'ulyss', 1)
# (u'fisher', 1)
# (u'jaylynn', 1)
# (u'2006', 1)
# (u'2004', 1)
# (u'2009', 1)
# (u'stroller', 1)
# (u'zoey', 1)
# (u'golfer', 1)
# (u'sensit', 1)
# (u'cartier', 1)
# (u'surgeon', 1)
# (u'prefect', 1)
# (u'joel', 1)
# (u'geograph', 1)
# (u'sp\xe9cifiqu', 1)
# (u'belleza', 1)
# (u'append', 1)
# (u'3x', 1)
# (u'chicago', 1)
# (u'pipet', 1)
# (u'impuls', 1)
# (u'toast', 1)
# (u'extrema', 1)
# (u'implicit', 1)
# (u'mindset', 1)
# (u'39', 1)
# (u'entiendan', 1)
# (u'adem\xe1', 1)
# (u'foundat', 1)
# (u'cho', 1)
# (u'charcoal', 1)
# (u'dentistri', 1)
# (u'phospor', 1)
# (u'hailstorm', 1)
# (u'alik', 1)
# (u'tunnel', 1)
# (u'scribbl', 1)
# (u'estuv', 1)
# (u'downhil', 1)
# (u'bicarbon', 1)
# (u'tammi', 1)
# (u'nasti', 1)
# (u'likewis', 1)
# (u'fran', 1)
# (u'wateri', 1)
# (u'apprendr', 1)
# (u'klan', 1)
# (u'stepfath', 1)
# (u'philosophi', 1)
# (u'shonda', 1)
# (u'happiest', 1)
# (u'chihuahua', 1)
# (u'lu', 1)
# (u'twirli', 1)
# (u'preval', 1)
# (u'toppl', 1)
# (u'overkil', 1)
# (u'recuerda', 1)
# (u'republish', 1)
# (u'safeway', 1)
# (u'disregard', 1)
# (u'upris', 1)
# (u'einstein', 1)
# (u'expliquen', 1)
# (u'marley', 1)
# (u'mmmhmmm', 1)
# (u'yarn', 1)
# (u'g\xe9rant', 1)
# (u'taco', 1)
# (u'sach', 1)
# (u'obligacion', 1)
# (u'ancient', 1)
# (u'laps', 1)
# (u'pr\xf3xima', 1)
# (u'lisett', 1)
# (u'pakistani', 1)
# (u'hepetiah', 1)
# (u'negro', 1)
# (u'millilet', 1)
# (u'interposit', 1)
# (u'shampoo', 1)
# (u'lover', 1)
# (u'connoqu', 1)
# (u'tycoon', 1)
# (u'woudl', 1)
# (u'mia', 1)
# (u'b\xfascame', 1)
# (u'hydrochlor', 1)
# (u'capita', 1)
# (u'absurd', 1)
# (u'lydon', 1)
# (u'pastri', 1)
# (u'hamlet', 1)
# (u'empir', 1)
# (u'portfolio', 1)
# (u'velociraptor', 1)
# (u'prolong', 1)
# (u'controlo', 1)
# (u'congratul', 1)
# (u'sparkl', 1)
# (u'beau', 1)
# (u'tripl', 1)
# (u'132', 1)
# (u'attendiez', 1)
# (u'pouvait', 1)
# (u'apolog', 1)
# (u'deleteri', 1)
# (u'thumbnail', 1)
# (u'sorrow', 1)
# (u'ramif', 1)
# (u'conmigo', 1)
# (u'swallow', 1)
# (u'highland', 1)
# (u'hammurabi', 1)
# (u'vent', 1)
# (u'creas', 1)
# (u'reborn', 1)
# (u'fright', 1)
# (u'8100', 1)
# (u'catchup', 1)
# (u'dreamlik', 1)
# (u'undecid', 1)
# (u'cherchent', 1)
# (u'choisissez', 1)
# (u'quadrupl', 1)
# (u'tumbler', 1)
# (u'airspac', 1)
# (u'cosmet', 1)
# (u'pronon', 1)
# (u'feminin', 1)
# (u'flashlight', 1)
# (u'thanksgiv', 1)
# (u'onward', 1)
# (u'applianc', 1)
# (u'bosaladera', 1)
# (u'ada', 1)
# (u'ravel', 1)
# (u'raven', 1)
# (u'grandecita', 1)
# (u'sofa', 1)
# (u'tom\xf3', 1)
# (u'mustach', 1)
# (u'paulina', 1)
# (u'abolitionist', 1)
# (u'conver', 1)
# (u'betsi', 1)
# (u'levanta', 1)
# (u'garreti', 1)
# (u'slight', 1)
# (u'host', 1)
# (u'kristin', 1)
# (u'test\xe9', 1)
# (u'socket', 1)
# (u'comprenez', 1)
# (u'certainti', 1)
# (u'modo', 1)
# (u's\xedntoma', 1)
# (u'chronic', 1)
# (u'guard', 1)
# (u'diciendo', 1)
# (u'termino', 1)
# (u'respirar', 1)
# (u'termina', 1)
# (u'invad', 1)
# (u'1986', 1)
# (u'1988', 1)
# (u'joaquin', 1)
# (u'hassl', 1)
# (u'maze', 1)
# (u'l\xedquido', 1)
# (u'unexpect', 1)
# (u'bub', 1)
# (u'buf', 1)
# (u'kaleil', 1)
# (u'cpc', 1)
# (u'pit', 1)
# (u'autism', 1)
# (u'rosehip', 1)
# (u'48', 1)
# (u'encontr\xe9', 1)
# (u'encontr\xf3', 1)
# (u'out', 1)
# (u'thoreau', 1)
# (u'seismic', 1)
# (u'ning\xfan', 1)
# (u'veut', 1)
# (u'sleev', 1)
# (u'dalen', 1)
# (u'tween', 1)
# (u'thinnest', 1)
# (u'maderi', 1)
# (u'travaillai', 1)
# (u'decidir', 1)
# (u'sonroj\xf3', 1)
# (u'sedekia', 1)
# (u'beaten', 1)
# (u'kuh', 1)
# (u'asymmetri', 1)
# (u'hoard', 1)
# (u'ethanol', 1)
# (u'decidi\xf3', 1)
# (u'relacionada', 1)
# (u'mentor', 1)
# (u'scaveng', 1)
# (u'portabl', 1)
# (u'tremend', 1)
# (u'kieran', 1)
# (u'hablan', 1)
# (u'stray', 1)
# (u'veronica', 1)
# (u'juliu', 1)
# (u'nora', 1)
# (u'sticker', 1)
# (u'grief', 1)
# (u'mg', 1)
# (u'mc', 1)
# (u'telescop', 1)
# (u'machinist', 1)
# (u'mx', 1)
# (u'r\xe9pond', 1)
# (u'nitrou', 1)
# (u'gate', 1)
# (u'widespread', 1)
# (u'pokey', 1)
# (u'badli', 1)
# (u'copay', 1)
# (u'exclud', 1)
# (u'exclus', 1)
# (u'diera', 1)
# (u'composit', 1)
# (u'crumbl', 1)
# (u'adun', 1)
# (u'london', 1)
# (u'wilton', 1)
# (u'comprehend', 1)
# (u'condition', 1)
# (u'mistreat', 1)
# (u'sakura', 1)
# (u'tourist', 1)
# (u'pinkish', 1)
# (u'corrient', 1)
# (u'metaphys', 1)
# (u'crunchi', 1)
# (u'alea', 1)
# (u'fragil', 1)
# (u'unimagin', 1)
# (u'gov', 1)
# (u'arizona', 1)
# (u'soda', 1)
# (u'latan', 1)
# (u'fantasi', 1)
# (u'explicaci\xf3n', 1)
# (u'mercuri', 1)
# (u'unbroken', 1)
# (u'western', 1)
# (u'eyeshield', 1)
# (u'rebelli', 1)
# (u'viern', 1)
# (u'trampita', 1)
# (u'prong', 1)
# (u'latitud', 1)
# (u'handkerchief', 1)
# (u'substitut', 1)
# (u'ohhhh', 1)
# (u'seminar', 1)
# (u'1968', 1)
# (u'harper', 1)
# (u'1960', 1)
# (u'thorough', 1)
# (u'ouai', 1)
# (u'predominantli', 1)
# (u'insul', 1)
# (u'orderli', 1)
# (u'interject', 1)
# (u'pope', 1)
# (u'radic', 1)
# (u'bail', 1)
# (u'hacerla', 1)
# (u'disgust', 1)
# (u'boulot', 1)
# (u'changeabl', 1)
# (u's\xfaper', 1)
# (u'tation', 1)
# (u'nut', 1)
# (u'fragranc', 1)
# (u'databas', 1)
# (u'candidat', 1)
# (u'terrenc', 1)
# (u'periwinkl', 1)
# (u'karev', 1)
# (u'kwl', 1)
# (u'aback', 1)
# (u'cam', 1)
# (u'beef', 1)
# (u'occipit', 1)
# (u'craft', 1)
# (u'extracurricular', 1)
# (u'milki', 1)
# (u'weren', 1)
# (u'descans', 1)
# (u'exterior', 1)
# (u'wound', 1)
# (u'drawback', 1)
# (u'portay', 1)
# (u'podamo', 1)
# (u'suburb', 1)
# (u'rega\xf1aron', 1)
# (u'grigg', 1)
# (u'dado', 1)
# (u'inteligent', 1)
# (u'aisl', 1)
# (u'boxer', 1)
# (u'choisir', 1)
# (u'qued\xf3', 1)
# (u'devitto', 1)
# (u'5x', 1)
# (u'interfer', 1)
# (u'ela', 1)
# (u'conjug', 1)
# (u'mountian', 1)
# (u'gift', 1)
# (u'arbitrari', 1)
# (u'54', 1)
# (u'57', 1)
# (u'contradict', 1)
# (u'amor', 1)
# (u'rapidito', 1)
# (u'tempurped', 1)
# (u'proudli', 1)
# (u'intellect', 1)
# (u'brawl', 1)
# (u'hydrocapsin', 1)
# (u'choke', 1)
# (u'duke', 1)
# (u'aha', 1)
# (u'encor', 1)
# (u'dec\xedamo', 1)
# (u'gir', 1)
# (u'boutiqu', 1)
# (u'fought', 1)
# (u'starchi', 1)
# (u'supo', 1)
# (u'trim', 1)
# (u'backsid', 1)
# (u'furi', 1)
# (u'inde', 1)
# (u'nc', 1)
# (u'tin', 1)
# (u'stagnant', 1)
# (u'whew', 1)
# (u'implant', 1)
# (u'tia', 1)
# (u'lieuten', 1)
# (u'\xe9l\xe8ve', 1)
# (u'navez', 1)
# (u'rod', 1)
# (u'livelihood', 1)
# (u'snip', 1)
# (u'llamamo', 1)
# (u'dex', 1)
# (u'impend', 1)
# (u'unfamiliar', 1)
# (u'feasibl', 1)
# (u'cyan', 1)
# (u'hawaii', 1)
# (u'espanol', 1)
# (u'drier', 1)
# (u'pore', 1)
# (u'patriarch', 1)
# (u'ashani', 1)
# (u'jaymen', 1)
# (u'hymn', 1)
# (u'interraci', 1)
# (u'enfermedad', 1)
# (u'fraciton', 1)
# (u'fluke', 1)
# (u'entertain', 1)
# (u'madhura', 1)
# (u'jorj', 1)
# (u'salti', 1)
# (u'gallop', 1)
# (u'capit', 1)
# (u'kelson', 1)
# (u'j\xe9cout', 1)
# (u'cort\xe9', 1)
# (u'ferri', 1)
# (u'sandstorm', 1)
# (u'jetsam', 1)
# (u'dargent', 1)
# (u'differenti', 1)
# (u'sailboat', 1)
# (u'paramount', 1)
# (u'eighti', 1)
# (u'rollin', 1)
# (u'lagoon', 1)
# (u'animo', 1)
# (u'anticip', 1)
# (u'aerodynam', 1)
# (u'128', 1)
# (u'tele', 1)
# (u'offert', 1)
# (u'cachucha', 1)
# (u'caitlin', 1)
# (u'fern', 1)
# (u'daba', 1)
# (u'gape', 1)
# (u'whiplash', 1)
# (u'zebra', 1)
# (u'abel', 1)
# (u'abek', 1)
# (u'profil', 1)
# (u'flyer', 1)
# (u'costar', 1)
# (u'buckskin', 1)
# (u'flare', 1)
# (u'jayden', 1)
# (u'espalda', 1)
# (u'cristoph', 1)
# (u'hug', 1)
# (u'hub', 1)
# (u'cope', 1)
# (u'eagl', 1)
# (u'deuxi\xe8m', 1)
# (u'grueso', 1)
# (u'schooler', 1)
# (u'perd\xf3n', 1)
# (u'heirgonk', 1)
# (u'estresado', 1)
# (u'serf', 1)
# (u'serk', 1)
# (u'wobbl', 1)
# (u'ana', 1)
# (u'anu', 1)
# (u'nazarett', 1)
# (u'sect', 1)
# (u'aspen', 1)
# (u'clearer', 1)
# (u'suri', 1)
# (u'connot', 1)
# (u'icon', 1)
# (u'tendon', 1)
# (u'bateau', 1)
# (u'uncondit', 1)
# (u'discuta', 1)
# (u'constitu', 1)
# (u'reili', 1)
# (u'trop', 1)
# (u'pant', 1)
# (u'cassiu', 1)
# (u'summertim', 1)
# (u'viewpoint', 1)
# (u'lighten', 1)
# (u'jazz', 1)
# (u'theta', 1)
# (u'chirurgien', 1)
# (u'hoyl', 1)
# (u'dya', 1)
# (u'doabl', 1)
# (u'm\xe9dico', 1)
# (u'1920', 1)
# (u'probarla', 1)
# (u'stanley', 1)
# (u'dowri', 1)
# (u'dinero', 1)
# (u'harshli', 1)
# (u'coma', 1)
# (u'berri', 1)
# (u'contract', 1)
# (u'dariu', 1)
# (u'hobb', 1)
# (u'railway', 1)
# (u'pakistan', 1)
# (u'encargando', 1)
# (u'barrett', 1)
# (u'tiger', 1)
# (u'saison', 1)
# (u'amend', 1)
# (u'casi', 1)
# (u'terranc', 1)
# (u'kaitlin', 1)
# (u'mound', 1)
# (u'situaci\xf3n', 1)
# (u'projectil', 1)
# (u'chopstick', 1)
# (u'algorithm', 1)
# (u'hermit', 1)
# (u'statur', 1)
# (u'ness', 1)
# (u'driven', 1)
# (u'devoid', 1)
# (u'mayra', 1)
# (u'pennsylvania', 1)
# (u'hustl', 1)
# (u'paperm', 1)
# (u'when', 1)
# (u'comstock', 1)
# (u'rosi', 1)
# (u'blog', 1)
# (u'scrapbook', 1)
# (u'kingdom', 1)
# (u'jimena', 1)
# (u'mahud', 1)
# (u'observando', 1)
# (u'treyshawn', 1)
# (u'thomason', 1)
# (u'intact', 1)
# (u'purebr', 1)
# (u'slick', 1)
# (u'landscap', 1)
# (u'buddha', 1)
# (u'redid', 1)
# (u'dicen', 1)
# (u'inspect', 1)
# (u'calmer', 1)
# (u'naoh', 1)
# (u'ob', 1)
# (u'despidiendo', 1)
# (u'gart', 1)
# (u'appalchian', 1)
# (u'strictli', 1)
# (u'burro', 1)
# (u'cassidi', 1)
# (u'cbd', 1)
# (u'frighten', 1)
# (u'samedi', 1)
# (u'brutu', 1)
# (u'animoto', 1)
# (u'idiot', 1)
# (u'misspeak', 1)
# (u'heathen', 1)
# (u'wiff', 1)
# (u'tanner', 1)
# (u'treason', 1)
# (u'all', 1)
# (u'spacecraft', 1)
# (u'cornfield', 1)
# (u'disk', 1)
# (u'endroit', 1)
# (u'hemo', 1)
# (u'ouch', 1)
# (u'yasmin', 1)
# (u'escuchamo', 1)
# (u'leddi', 1)
# (u'sum', 1)
# (u'womb', 1)
# (u'shouldt', 1)
# (u'shouldv', 1)
# (u'themself', 1)
# (u'\xe9coutez', 1)
# (u'conseguido', 1)
# (u'myra', 1)
# (u'disneyland', 1)
# (u'jaylen', 1)
# (u'stickiest', 1)
# (u'1900', 1)
# (u'trabaja', 1)
# (u'spi', 1)
# (u'relacionast', 1)
# (u'policemen', 1)
# (u'bashir', 1)
# (u'niagara', 1)
# (u'pone', 1)
# (u'int\xe9ress\xe9', 1)
# (u'anxiou', 1)
# (u'divin', 1)
# (u'delaney', 1)
# (u'tinfoil', 1)
# (u'aashi', 1)
# (u'aaaaw', 1)
# (u'levantars', 1)
# (u'ambigu', 1)
# (u'shore', 1)
# (u'inward', 1)
# (u'abbey', 1)
# (u'resort', 1)
# (u'prac', 1)
# (u'woulda', 1)
# (u'administr', 1)
# (u'refresh', 1)
# (u'correctamundo', 1)
# (u'playstat', 1)
# (u'renaiss', 1)
# (u'tenido', 1)
# (u'dugout', 1)
# (u'tactician', 1)
# (u'gorgeou', 1)
# (u'bavel', 1)
# (u'thread', 1)
# (u'ooey', 1)
# (u'precal', 1)
# (u'sailor', 1)
# (u'plummet', 1)
# (u'bland', 1)
# (u'passer', 1)
# (u'moan', 1)
# (u'magician', 1)
# (u'regrew', 1)
# (u'183', 1)
# (u'passez', 1)
# (u'gpe', 1)
# (u'fidget', 1)
# (u'copi\xf3', 1)
# (u'windier', 1)
# (u'dano', 1)
# (u'dana', 1)
# (u'exert', 1)
# (u'strengthen', 1)
# (u'windmil', 1)
# (u'dedic', 1)
# (u'entireti', 1)
# (u'ponerlo', 1)
# (u'ponerla', 1)
# (u'buff', 1)
# (u'mandarno', 1)
# (u'spectral', 1)
# (u'prestigi', 1)
# (u'disrob', 1)
# (u'fond', 1)
# (u'gallbladd', 1)
# (u'jugar', 1)
# (u'hablando', 1)
# (u'm\xedo', 1)
# (u'hid', 1)
# (u'm\xeda', 1)
# (u'tourner', 1)
# (u'snowstorm', 1)
# (u'certif', 1)
# (u'pvc', 1)
# (u'otrisa', 1)
# (u'ingl', 1)
# (u'klux', 1)
# (u'vont', 1)
# (u'crisp', 1)
# (u'observatori', 1)
# (u'latin', 1)
# (u'outfit', 1)
# (u'uuh', 1)
# (u'immers', 1)
# (u'consideran', 1)
# (u'peg\xe1ndol', 1)
# (u'flier', 1)
# (u'distress', 1)
# (u'crispi', 1)
# (u'sweep', 1)
# (u'simpler', 1)
# (u'duh', 1)
# (u'cheapest', 1)
# (u'dum', 1)
# (u'dud', 1)
# (u'pe', 1)
# (u'whod', 1)
# (u'woke', 1)
# (u'maser', 1)
# (u'slideshow', 1)
# (u'softest', 1)
# (u'binomi', 1)
# (u'p2', 1)
# (u'pedestrian', 1)
# (u'reunit', 1)
# (u'batch', 1)
# (u'agarro', 1)
# (u'acuerdo', 1)
# (u'temperatura', 1)
# (u'leann', 1)
# (u'mostrando', 1)
# (u'rig', 1)
# (u'minim', 1)
# (u'fueron', 1)
# (u'33333', 1)
# (u'haga', 1)
# (u'cheer', 1)
# (u'lowel', 1)
# (u'samaya', 1)
# (u'facial', 1)
# (u'presionar', 1)
# (u'continent', 1)
# (u'shaina', 1)
# (u'volver', 1)
# (u'mejorars', 1)
# (u'habido', 1)
# (u'ni\xf1a', 1)
# (u'marlin', 1)
# (u'arthur', 1)
# (u'piglet', 1)
# (u'litter', 1)
# (u'undon', 1)
# (u'flute', 1)
# (u'raiden', 1)
# (u'aiyah', 1)
# (u'transpor', 1)
# (u'cece', 1)
# (u'emphasi', 1)
# (u'mommi', 1)
# (u'announc', 1)
# (u'undergound', 1)
# (u'smoosh', 1)
# (u'arithmet', 1)
# (u'baggi', 1)
# (u'repeatedli', 1)
# (u'prononc\xe9', 1)
# (u'msb', 1)
# (u'116', 1)
# (u'callen', 1)
# (u'derang', 1)
# (u'limit\xe1ndono', 1)
# (u'smoothli', 1)
# (u'bicep', 1)
# (u'ivre', 1)
# (u'gri', 1)
# (u'tyshon', 1)
# (u'happier', 1)
# (u'prononci', 1)
# (u'selzter', 1)
# (u'hypochlor', 1)
# (u'pongo', 1)
# (u'ay\xfadenm', 1)
# (u'outgo', 1)
# (u'meyb', 1)
# (u'ponga', 1)
# (u'gina', 1)
# (u'wanda', 1)
# (u'dandi', 1)
# (u'relev', 1)
# (u'bryant', 1)
# (u'miran', 1)
# (u'cfl', 1)
# (u'jc', 1)
# (u'naomi', 1)
# (u'kangaroo', 1)
# (u'miser', 1)
# (u'pajama', 1)
# (u'pesar', 1)
# (u'fee', 1)
# (u'uso', 1)
# (u'feo', 1)
# (u'fet', 1)
# (u'85cm', 1)
# (u'dejan', 1)
# (u'dash', 1)
# (u'hein', 1)
# (u'perder', 1)
# (u'midterm', 1)
# (u'patrol', 1)
# (u'tay', 1)
# (u'tad', 1)
# (u'thirsti', 1)
# (u'dexprim', 1)
# (u'cardin', 1)
# (u'unskil', 1)
# (u'toddler', 1)
# (u'panic', 1)
# (u'sil', 1)
# (u'outlier', 1)
# (u'opuesto', 1)
# (u'opuesta', 1)
# (u'whilst', 1)
# (u'spank', 1)
# (u'tyrant', 1)
# (u'badger', 1)
# (u'middleston', 1)
# (u'glee', 1)
# (u'turban', 1)
# (u'neali', 1)
# (u'asprin', 1)
# (u'fingerprint', 1)
# (u'dispuesto', 1)
# (u'fled', 1)
# (u'grievanc', 1)
# (u'edit', 1)
# (u'nfl', 1)
# (u'freckl', 1)
# (u'randel', 1)
# (u'grito', 1)
# (u'burl\xf3', 1)
# (u'archimed', 1)
# (u'utensil', 1)
# (u'ipod', 1)
# (u'ionic', 1)
# (u'footag', 1)
# (u'renni', 1)
# (u'corri\xe9ndos', 1)
# (u'salient', 1)
# (u'glisten', 1)
# (u'jumbl', 1)
# (u'jule', 1)
# (u'shallow', 1)
# (u'f\xe9minin', 1)
# (u'clemson', 1)
# (u'podrida', 1)
# (u'splatter', 1)
# (u'smellin', 1)
# (u'rout', 1)
# (u'ahold', 1)
# (u'divers', 1)
# (u'shana', 1)
# (u'multitud', 1)
# (u'noggin', 1)
# (u'guinea', 1)
# (u'syring', 1)
# (u'xavier', 1)
# (u'offenc', 1)
# (u'inexpens', 1)
# (u'ho', 1)
# (u'tariq', 1)
# (u'dorothi', 1)
# (u'dije', 1)
# (u'gino', 1)
# (u'reign', 1)
# (u'kayani', 1)
# (u'999', 1)
# (u'awww', 1)
# (u'qr', 1)
# (u'qu', 1)
# (u'15th', 1)
# (u'naud', 1)
# (u'grrrrr', 1)
# (u'workbench', 1)
# (u'expel', 1)
# (u'violet', 1)
# (u'entranc', 1)
# (u'relgiou', 1)
# (u'entic', 1)
# (u'joy', 1)
# (u'ignesia', 1)
# (u'canopi', 1)
# (u'april', 1)
# (u'articul', 1)
# (u'walt', 1)
# (u'hindu', 1)
# (u'compos', 1)
# (u'decend', 1)
# (u'treasur', 1)
# (u'miremo', 1)
# (u'ewan', 1)
# (u'corset', 1)
# (u'align', 1)
# (u'vicki', 1)
# (u'cutter', 1)
# (u'esencialment', 1)
# (u'antibiot', 1)
# (u'collag', 1)
# (u'firstli', 1)
# (u'deion', 1)
# (u'obtain', 1)
# (u'replenish', 1)
# (u'clyde', 1)
# (u'nicki', 1)
# (u'enact', 1)
# (u'lawson', 1)
# (u'sindi', 1)
# (u'am\xe9ricain', 1)
# (u'112', 1)
# (u'119', 1)
# (u'inish', 1)
# (u'tanisha', 1)
# (u'swear', 1)
# (u'emperor', 1)
# (u'deerbro', 1)
# (u'preform', 1)
# (u'owe', 1)
# (u'lenght', 1)
# (u'tag', 1)
# (u'bridgeway', 1)
# (u'oswel', 1)
# (u'spiral', 1)
# (u'explico', 1)
# (u'endrel', 1)
# (u'quedaba', 1)
# (u'vat', 1)
# (u'contradictori', 1)
# (u'situaiton', 1)
# (u'kany', 1)
# (u'boop', 1)
# (u'toasti', 1)
# (u'junk', 1)
# (u'june', 1)
# (u'margaret', 1)
# (u'squeak', 1)
# (u'humbl', 1)
# (u'sentado', 1)

# %%
print(len(ldamodel[corpus]))
print(len(ldamodel[bow]))
[i for i in ldamodel[bow]]
# Out:
# 242
# 1
# [[(0, 0.024819393), (2, 0.10701441), (4, 0.86718845)]]

# %%
#visualize_lda_model(ldamodel, corpus, dictionary)

# %%
visualize_lda_model(ldamodel, bow, dictionary)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-624147e1059f> in <module>()
# ----> 1 visualize_lda_model(ldamodel, bow, dictionary)
#
# <ipython-input-9-46f81d07bf99> in visualize_lda_model(ldamodel, corpus, dictionary)
#       1 def visualize_lda_model(ldamodel, corpus, dictionary):
# ----> 2     vis_data = gensimvis.prepare(ldamodel, corpus, dictionary)
#       3     #pyLDAvis.display(vis_data)
#       4     pyLDAvis.show(vis_data)
#       5
#
# /Users/fjgreco/Virtual-Environments/py2-venv/lib/python2.7/site-packages/pyLDAvis/gensim.pyc in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     109     See `pyLDAvis.prepare` for **kwargs.
#     110     """
# --> 111     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
#     112     return vis_prepare(**opts)
#
# /Users/fjgreco/Virtual-Environments/py2-venv/lib/python2.7/site-packages/pyLDAvis/gensim.pyc in _extract_data(topic_model, corpus, dictionary, doc_topic_dists)
#      57        topic = topic_model.state.get_lambda()
#      58    topic = topic / topic.sum(axis=1)[:, None]
# ---> 59    topic_term_dists = topic[:, fnames_argsort]
#      60
#      61    assert topic_term_dists.shape[0] == doc_topic_dists.shape[1]
#
# IndexError: index 2922 is out of bounds for axis 1 with size 2006
