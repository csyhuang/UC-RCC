# %%
#!/usr/bin/env python
# coding: utf-8
from __future__ import print_function

__doc__="""
Added jaccard similarity function
Settable list of tags and list of document numbers
doc0 set to 0 set to a given input file
Compute cosine similarity between all pairs of documents that share a given tag or is doc 0, and cos_sim of corresponding (tag set pairs)
Graph cos_sim(target doc, doc_no) vs doc no  and  cos_sim(tag label set(target doc), tagset(doc_no)) vs doc_no for each target tag / target doc graph pair
Graph corresponding cos(doc(x)) vs cos(tagset(x))
Output directory set to ..SIMILARITY_PLOTS/CC_PLOTS6_2
Computes mean and variance of cosine similarity for each target document/target tag graph pair.
Produces cc_statlog6_2_{start time}.csv & console log
"""

print(__doc__)

__source__ = 'cc_combined6_3.py'
__author__ = "Frank J. Greco"
__copyright__ = "Copyright 2015-2018, Frank J. Greco"
__credits__ = []
__license__ = "Apache"
__version__ = "1.0.1"
__email__ = ""
__status__ = "Development"

# %%
# %load_ext autoreload
# %autoreload 2
#%reload_ext autoreload
import sys
sys.path.append('/Users/fjgreco/Dev-Atlas')

# %%
import os
import sys
import collections

import re

import logging
import datetime

from bokeh.plotting import figure, output_file, show
from bokeh.layouts import row
from bokeh.io import save
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label

import statistics

from scipy.stats.stats import pearsonr
from scipy.stats.stats import spearmanr

import numpy as numpy

import pandas as pd

from cc_metrics import calculate_similarities

from preprocess import create_tag_dict
from preprocess import create_tag_sub_dict
from preprocess import create_text_dict_l

from bkcharts import HeatMap, show, output_file
from bokeh.palettes import RdGy11 as palette  # @UnresolvedImport
from bokeh.models import HoverTool
from bokeh.models import CrosshairTool

#
# Plot Results
#
def heatmap3(c3,title="Cosine Similarity",output_filename='cossim_heatmap.html'):


    crosshair = CrosshairTool()

    hover = HoverTool(tooltips=[
        ("index", "$index"),
        ("(x,y)", "(@x,@y)"),
        ("score", "@values")
    ])

    score = []

    nba = pd.DataFrame(c3)

    for x in nba.apply(tuple):
        score.extend(x)

    #print("\nscore({}):{}".format(title,score))

    data = {
        'transcript-x': list(nba.index) * len(nba.columns),
        'transcript-y': [item for item in list(nba.columns) for i in range(len(nba.index))],
        'score': score
    }

    output_file(output_filename)

    hm = HeatMap(data, x='transcript-x', y='transcript-y', values='score', title=title, stat=None, tools=[hover,crosshair], palette=palette)

    #show(hm)
    return hm

def heatmap4(title="Test pattern",output_filename='test_heatmap2.html'):

    crosshair = CrosshairTool()

    hover = HoverTool(tooltips=[
        ("index", "$index"),
        ("(x,y)", "(@x,@y)"),
        ("score", "@values")
    ])

    score = []

    c3=[[1,0,0],[0,1,0],[0,0,1]]

    nba = pd.DataFrame(c3)

    for x in nba.apply(tuple):
        score.extend(x)

    #print("\nscore({}):{}".format(title,score))

    data = {
        'Index': list(nba.index) * len(nba.columns),
        'Cosine': [item for item in list(nba.columns) for i in range(len(nba.index))],
        'score': score
    }

    output_file(output_filename)
    hm = HeatMap(data, x='Index', y='Cosine', values='score', title=title, stat=None, tools=[hover,crosshair], palette=palette)

    #show(hm)
    return hm

#
# Stat Results
#
def stat_results(doc_ids,
                 doc_no,
                 target_tag,
                 cosine_scores_text,
                 cosine_scores_tags,
                 jaccard_scores_text,
                 jaccard_scores_tags,
                 statlog,
                 cos_means,
                 jaccard_means):


    print("doc_no:", doc_no)
    doc_key = doc_ids[doc_no]
    print("doc_key:", doc_key)

    # Plot p1
    x1 = range(len(doc_ids))
    y1 = cosine_scores_text[doc_no]

    x2 = range(len(doc_ids))
    # y2 = cosine_scores_tags[doc_no]
    y2 = jaccard_scores_tags[doc_no]

    # Plot p2
    x3 = cosine_scores_text[doc_no]
    y3 = jaccard_scores_text[doc_no]

    # Plot p3
    x4 = doc_ids
    y4 = jaccard_scores_tags[doc_no]

    a = []

    index = 0

    for item in y1:
        index += 1
        if index != doc_no + 1:
            a.append(item)

    statlog.write(','.join(['doc-' + str(doc_key), target_tag, str(statistics.mean(a)), str(statistics.variance(a))]))

    cos_means[target_tag].append(statistics.mean(a))

    a2 = []
    index = 0

    for item in y4:
        index += 1
        if index != doc_no + 1:
            a2.append(item)

    statlog.write(',')

    statlog.write(','.join([str(statistics.mean(a2)), str(statistics.variance(a2))]))

    jaccard_means[target_tag].append(statistics.mean(a2))

    try:
        pearson=pearsonr(x3, y2)
        spearman=spearmanr(x3, y2)
        print("Pearsonr Result: ", pearson)
        print(spearman)
        statlog.write(','.join(["pearson:", str(pearson[0]), str(pearson[1]), str(spearmanr(x3, y2))]))

    except:
        print("Error Summary Stats(1)", sys.exc_info())
        pass

    try:
        print("Correlation Coefficients:\n", numpy.corrcoef(x3, y3))
    except:
        print("Error: correlation coefficients:", sys.exc_info())
        pass

    statlog.write('\n')

    return

#
# Plot Results
#
def plot_results(doc_ids,
                 doc_no,
                 target_tag,
                 cosine_scores_text,
                 cosine_scores_tags,
                 jaccard_scores_text,
                 jaccard_scores_tags,
                 plot_dir):

    print("doc_no:",doc_no)
    doc_key=doc_ids[doc_no]
    print("doc_key:",doc_key)

    # Plot p1
    x1 = range(len(doc_ids))
    y1 = cosine_scores_text[doc_no]

    x2 = range(len(doc_ids))
    #y2 = cosine_scores_tags[doc_no]
    y2 = jaccard_scores_tags[doc_no]

    # Plot p2
    x3 = cosine_scores_text[doc_no]
    y3 = jaccard_scores_text[doc_no]

    # Plot p3
    x4 = doc_ids
    y4 = jaccard_scores_tags[doc_no]

    #########################################
    # create  plot 1
    #########################################
    a=[]

    index=0

    for item in y1:
        index += 1
        if index != doc_no+1:
            a.append(item)

    stats= "n: " + str(len(a)) + " mean: " + str(statistics.mean(a)) +  ' variance: ' + str(statistics.variance(a))

    citation = Label(x=100, y=400, x_units='screen', y_units='screen',
                     text=stats, render_mode='css',
                     border_line_color='black', border_line_alpha=1.0,
                     background_fill_color='white', background_fill_alpha=1.0)

    p1 = figure(title="Cosine Similarity between Doc Index: " + str(doc_no)+' CaseId: '+ str(doc_key) + " and each case tagged with:" + target_tag,
                x_axis_label='Doc Index', y_axis_label='Cosine(Blue)/Jaccard(Red)')

    p1.add_layout(citation)

    p1.circle(x1, y1, color="blue", size=5, legend="text")

    p1.circle(x2, y2, color="red", size=2, legend="tags")

    #########################################
    # create  plot 2
    #########################################

    p2 = figure(title="COS similarity vs Jaccard similarity; CaseId " + str(doc_key), x_axis_label='COS metric', y_axis_label='Jaccard metric')

    p2.circle(x3, y3, color="green")

    #########################################
    # create  plot 3
    #########################################

    a3=[]
    index=0

    for item in y4:
        index += 1
        if index != doc_no+1:
            a3.append(item)

    stats3= "n: " + str(len(a3)) + " mean: " + str(statistics.mean(a3)) +  ' variance: ' + str(statistics.variance(a3))

    citation = Label(x=100, y=400, x_units='screen', y_units='screen',
                     text=stats3, render_mode='css',
                     border_line_color='black', border_line_alpha=1.0,
                     background_fill_color='white', background_fill_alpha=1.0)


    p3 = figure(title="Jaccard similarity between Doc Index: " + str(doc_no)+' CaseId: '+ str(doc_key) + " and each case tagged with:" + target_tag,
                x_axis_label='Case ID', y_axis_label='Jaccard Metric')
    p3.add_layout(citation)

    p3.circle(x4, y4, color="blue")

    ##########################################################################
    # output to HTML file
    ##########################################################################
    output_file(plot_dir+"/cc_cluster_"+target_tag+"_doc_"+str(doc_key)+".html")

    save(row(p1,p2,p3))

    return
# Out:
# Added jaccard similarity function
# Settable list of tags and list of document numbers
# doc0 set to 0 set to a given input file
# Compute cosine similarity between all pairs of documents that share a given tag or is doc 0, and cos_sim of corresponding (tag set pairs)
# Graph cos_sim(target doc, doc_no) vs doc no  and  cos_sim(tag label set(target doc), tagset(doc_no)) vs doc_no for each target tag / target doc graph pair
# Graph corresponding cos(doc(x)) vs cos(tagset(x))
# Output directory set to ..SIMILARITY_PLOTS/CC_PLOTS6_2
# Computes mean and variance of cosine similarity for each target document/target tag graph pair.
# Produces cc_statlog6_2_{start time}.csv & console log

# %%
def main():

    global transcript_dir

    cos_means = dict()

    jaccard_means = dict()

    statlog = open(statlog_filename, 'w')
    statlog.write(','.join(
        ['doc_key', 'target_tag', 'cs-mean', 'cs-variance', "js_mean", "js_variance"]))
    statlog.write('\n')

    tag_dict=create_tag_dict(xls_pathname,v=True)


    #
    # Analyze tags and text
    #

    for target_tag in target_tags:

        cos_means[target_tag]=[]

        jaccard_means[target_tag]=[]

        tag_sub_dict = create_tag_sub_dict(tag_dict, target_tag)

        train_sub_dict= create_text_dict_l(transcript_dir, tag_sub_dict=tag_sub_dict)

        tag_train_set=[]

        text_train_set=[]

        for x in train_sub_dict.keys():
            tag_train_set.append(train_sub_dict[x][1])
            text_train_set.append(train_sub_dict[x][0])

        #print ('\ntag_train_set',tag_train_set)
        #print('\ntext_train_set', text_train_set)

        print ("\nCalculate tag_train_set similarities:")
        cosine_scores_tags, jaccard_scores_tags = calculate_similarities(tag_train_set)

        print("\nCalculate text_train_set similarities:")
        cosine_scores_text, jaccard_scores_text = calculate_similarities(text_train_set)


        heatmap_fn='heatmap_'+target_tag+'.html'
        
        print (heatmap_fn)

        h1=heatmap3(cosine_scores_text,title='cosine_scores_text: '+ target_tag)

        h2=heatmap3(jaccard_scores_tags,title='jaccard_scores_tags: '+ target_tag)

        #h3=heatmap4()

        save(row(h1,h2))

        #save(row(h3))

        print("\ndoc_ids:",train_sub_dict.keys())

        for doc_no in range(len(train_sub_dict.keys())):

            print('\nmain: doc_no:', doc_no, 'target_tag', target_tag)

            try:

                stat_results(train_sub_dict.keys(),
                             doc_no,
                             target_tag,
                             cosine_scores_text,
                             cosine_scores_tags,
                             jaccard_scores_text,
                             jaccard_scores_tags,
                             statlog,
                             cos_means,
                             jaccard_means)

            except:
                print("main: stat_results error:", "target_tag", target_tag, "doc_no", doc_no,sys.exc_info())
                pass


            try:

                plot_results(train_sub_dict.keys(),
                             doc_no,
                             target_tag,
                             cosine_scores_text,
                             cosine_scores_tags,
                             jaccard_scores_text,
                             jaccard_scores_tags,
                             plot_dir)

            except:
                print("main: plot_results error:", "target_tag", target_tag, "doc_no", doc_no,sys.exc_info())
                pass

    #
    # Test for correlation
    #
    sim_js=[]

    sim_cs=[]

    for item in sorted(cos_means.keys()):
        try:
            statlog.write(','.join(["Target tag:",item, "n:",str(len(cos_means[item]))]))
            statlog.write(',')
            mean_cos_means=statistics.mean(cos_means[item])
            statlog.write(
                ','.join(["Mean of Cosine Similarity means:  ", str(mean_cos_means), ' variance: ',
                             str(statistics.variance(cos_means[item]))]))
            statlog.write(',')
            mean_jaccard_means=statistics.mean(jaccard_means[item])
            statlog.write(
                ','.join(["Mean of Jaccard Similarity means: ", str(mean_jaccard_means), ' variance: ',
                          str(statistics.variance(jaccard_means[item]))]))

            statlog.write('\n')
            sim_cs.append(mean_cos_means)
            sim_js.append(mean_jaccard_means)

        except:
            print ("main:", "error printing summary stats", "item:", item, sys.exc_info())
            statlog.write('\n')
            pass

    #
    # Print Correlation Statistics for full run
    #
    if (len(sim_cs)>1):

        print ("\nsim_cs:",sim_cs)
        statlog.write(','.join(["sim_cs:",str(sim_cs)]))
        statlog.write('\n')

        print("\nsim_js",sim_js)
        statlog.write(','.join(["sim_js:", str(sim_js)]))
        statlog.write('\n')

        print  ("\nPearsonr RESULT: ", pearsonr(sim_cs, sim_js))
        statlog.write(','.join(["Pearsonr RESULT:", str(pearsonr(sim_cs, sim_js))]))
        statlog.write('\n')

        print ("\nSpearmanr RESULT:",spearmanr(sim_cs, sim_js))
        statlog.write(','.join(["Spearmanr RESULT:",str(spearmanr(sim_cs, sim_js))]))
        statlog.write('\n')

        print ("\nCorrelation Coefficients\n",numpy.corrcoef(sim_cs, sim_js))


    et = 'End time: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())
    print (et)

    statlog.close()

# %%
if __name__ == "__main__":

    st = '{:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now())

    print("cc_combined6_3: Start time:", st)

    statlog_filename = "../SIMILARITY_PLOTS/cc_combined6_3_statlog_" + st + '.csv'
    print ('statlog:',statlog_filename)

    xls_pathname = '../CC_FILES_TAGLIST/TW Case List.xlsx'
    print ('Case List',xls_pathname)

    transcript_dir = '../CC_TRANSCRIPTS3'
    print ('transcript_dir',transcript_dir)

    #target_tags = ['TW01', 'TW02', 'TW03', 'TW04', 'TW05', 'TW06', 'TW07', 'TW08', 'TW09', 'TW10', 'TW11', 'TW12',
    # 'TW13', 'TW14', 'TW15', 'TW16', 'TW17', 'TW18', 'TW19', 'TW20', 'TW21', 'TW22', 'TW23', 'TW24']
    #target_tags = ['all']
    target_tags = ['TW02','TW05']
    print ("target tags:", target_tags)

    plot_dir = '../SIMILARITY_PLOTS/CC_PLOTS6_3_'+st
    print ("plot_dir",plot_dir)

    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)

    main()
# Out:
# cc_combined6_3: Start time: 2018-03-24 09:26:02
# statlog: ../SIMILARITY_PLOTS/cc_combined6_3_statlog_2018-03-24 09:26:02.csv
# Case List ../CC_FILES_TAGLIST/TW Case List.xlsx
# transcript_dir ../CC_TRANSCRIPTS3
# target tags: ['TW02', 'TW05']
# plot_dir ../SIMILARITY_PLOTS/CC_PLOTS6_3_2018-03-24 09:26:02
#
# *** Begin process_worksheet ***
#
# [u'CASE IDS', u'Sheet1', u'caseannotation-20170613T220819']
#
# preprocess_worksheet: len(tag_dict.keys()):225
# 1 TW08,TW24,TW06,TW15
# 2 TW05,TW13,TW10,TW09,TW02
# 3 TW24TW06,TW13,TW01,TW17,TW15,TW08
# 4 TW24,TW13,TW01,TW17,TW13,TW01
# 5 TW24,TW24,TW24,TW15,TW16,TW01
# 6 TW24,TW06,TW08,TW05,TW16,TW03
# 9 TW24,TW24,TW15,TW19,TW11,TW05,TW02,TW18,TW11,TW13,TW19,TW16,TW19,TW17,TW11,TW01,TW04
# 10 TW16,TW17,TW13,TW01,TW11,TW18,TW02
# 12 TW24TW06,TW05,TW02,TW06,TW17,TW01
# 14 TW05,TW24,TW24,TW06,TW16,TW16,TW19,TW02,TW02,TW01
# 20 TW08
# 21 TW24,TW05,TW09,TW02
# 22 TW11,TW08,TW02
# 24 TW24,TW17,TW04,TW03,TW06,TW11,TW06,TW06,TW01
# 26 TW24,TW24,TW09,TW02,TW09,TW02
# 27 TW24,TW05,TW08,TW02
# 28 TW24TW17,TW04,TW05,TW10,TW03,TW11,TW17,TW20,TW01
# 29 TW24,TW05,TW16,TW16,TW03,TW01,TW01,TW02,TW01
# 31 TW06,TW06,TW08,TW01
# 32 TW06,TW17,TW03,TW06,TW03
# 33 TW06,TW21,TW04,TW09,TW06,TW21,TW24,TW04,TW09,TW02
# 34 TW24,TW07,TW09,TW02
# 40 TW24,TW15,TW15,TW15,TW06,TW07,TW13,TW01
# 41 TW10
# 42 TW02
# 43 TW09,TW08,TW09,TW02,TW08,TW09,TW02
# 45 TW24,TW24TW09,TW24,TW24,TW22,TW08,TW15,TW08,TW05,TW09,TW02
# 46 TW13,TW03,TW04,TW01,TW11,TW13,TW03,TW04,TW06,TW16,TW01
# 48 TW17,TW01,TW11,TW19,TW02
# 50 TW13
# 51 TW19,TW24TW09,TW24TW12,TW24,TW19,TW17,TW02,TW09
# 52 TW16,TW24TW08,TW24TW07,TW15,TW13,TW06,TW17,TW08,TW08
# 53 TW11,TW15,TW17,TW10,TW17,TW02,TW02,TW18,TW11,TW02,TW17,TW11,TW09,TW10,TW07,TW11,TW02
# 55 TW13,TW11,TW13,TW04,TW06,TW17,TW01
# 60 TW24,TW24TW08,TW18,TW08,TW01
# 61 TW01,TW24TW08,TW24,TW21,TW08,TW18,TW05,TW15,TW02
# 64 TW06,TW04,TW19,TW16,TW16,TW01,TW02,TW11,TW06,TW04,TW19,TW16,TW16,TW01,TW02,TW01
# 65 TW15,TW04,TW15,TW01,TW13,TW06,TW13,TW20,TW07,TW01
# 66 TW02,TW06,TW02
# 68 TW09,TW16,TW24,TW24,TW05,TW02,TW17,TW01,TW09,TW09,TW13,TW05,TW02,TW01,TW04
# 70 TW15,TW07,TW01
# 73 TW24,TW13,TW06,TW08,TW08,TW15,TW06,TW13,TW06,TW01
# 74 TW09,TW02
# 75 TW24,TW08,TW17,TW01,TW06,TW05,TW10,TW02,TW06,TW17,TW01
# 76 TW17,TW09s,TW09s,TW18,TW08,TW17,TW01,TW09,TW02,TW13,TW08,TW01,TW09,TW02,TW13,TW08,TW01
# 77 TW06,TW08,TW06,TW17,TW06,TW01
# 79 TW13,TW06,TW01,TW16,TW24,TW14,TW12
# 81 TW24,TW15,TW10,TW03,TW19,TW08,TW19,TW20,TW16,TW01
# 82 TW08,TW17
# 85 TW13,TW16,TW01,TW22,TW17,TW16,TW01,TW01
# 86 TW24,TW13,TW16,TW18,TW01,TW17,TW05,TW02
# 87 TW24,TW13,TW11,TW11,TW13,TW01,TW03
# 90 TW02,TW02,TW01,TW23,TW24TW08,TW24,TW22,TW05,TW02,TW08,TW02,TW01,TW02,TW01,TW23,TW24TW08,TW24,TW22,TW02,TW05,TW02,TW08
# 93 TW06,TW08,TW17,TW09,TW06
# 94 TW06,TW07,TW19,TW18,TW09,TW09,TW02,TW07,TW06,TW06,TW19,TW18,TW09,TW09,TW05,TW02
# 96 TW06s,TW24TW06,TW01,TW02,TW18,TW06,TW13,TW01,TW18,TW05,TW02,TW01,TW24TW06,TW24,TW01,TW13,TW05,TW02,TW06s,TW06s,TW13,TW01,TW18,TW05,TW02,TW01
# 98 TW11,TW03,TW05,TW18,TW17,TW15,TW01,TW24TW01,TW13
# 99 TW08,TW02
# 101 TW08,TW01
# 102 TW05,TW01,TW01,TW01,TW10,TW02,TW09,TW06,TW01,TW17
# 104 TW05,TW09,TW08,TW02
# 106 TW06,TW16,TW01,TW05,TW02,TW18,TW16,TW06,TW01,TW22,TW06,TW16,TW01,TW05,TW02,TW18,TW16,TW06,TW01
# 107 TW24,TW16,TW10,TW15,TW09,TW13,TW02,TW05,TW18,TW01,TW06,TW06
# 108 TW17,TW20,TW01
# 111 TW24,TW17,TW06,TW11,TW08,TW01
# 112 TW24,TW23,TW22,TW13,TW06,TW01,TW02,TW07,TW13,TW20,TW01
# 113 TW08,TW10,TW01
# 114 TW07,TW24TW16,TW06,TW08
# 115 TW24,TW17,TW09,TW09,TW04,TW09,TW02,TW24,TW13,TW17,TW09,TW09,TW04,TW09,TW02
# 116 TW24,TW24,TW13,TW10,TW10,TW15,TW03,TW17,TW01
# 118 TW24,TW09,TW02
# 120 TW02,TW24,TW16,TW02,TW16,TW01,TW02,TW08,TW01,TW05,TW24,TW16,TW16,TW02,TW16,TW08,TW01,TW02,TW08,TW01,TW05,TW02
# 122 TW06,TW13,TW07,TW06,TW06,TW06,TW02
# 123 TW17,TW01,TW02,TW02,TW01
# 126 TW05,TW09,TW09,TW02,TW09s,TW09s,TW02
# 128 TW05,TW16,TW02,TW16
# 129 TW02,TW19,TW19,TW15,TW16,TW07,TW01,TW05,TW02,TW04,TW07,TW01,TW07,TW16,TW16,TW01,TW19,TW15,TW01,TW02,TW07,TW01,TW05,TW02,TW04,TW07,TW16,TW01
# 131 TW15,TW24TW08,TW15,TW15,TW15,TW08
# 132 TW08,TW06,TW08,TW16,TW01
# 134 TW24TW17,TW24TW17,TW15,TW23,TW22,TW09,TW05,TW02,TW24TW17,TW24,TW15,TW23,TW22,TW09,TW05,TW02
# 135 TW10,TW13
# 137 TW24TW06,TW13,TW02,TW05,TW17,TW02,TW01,TW13,TW21,TW18,TW05,TW18,TW11,TW02,TW17,TW06,TW20,TW01
# 142 TW15,TW15,TW09s,TW09s,TW09s,TW02
# 146 TW24TW09,TW21,TW01,TW09,TW08,TW05,TW02
# 148 TW19,TW05,TW02
# 150 TW24,TW19,TW17,TW17,TW07,TW17,TW06,TW17,TW05,TW03,TW18,TW08,TW01,TW18,TW05,TW02,TW18,TW01
# 151 TW11,TW13,TW11,TW11,TW13,TW13,TW09,TW05,TW02,TW04,TW01
# 153 TW21,TW06c,TW02
# 154 TW03,TW03,TW13,TW06,TW01,TW04
# 156 TW24,TW22,TW10m
# 157 TW06,TW16,TW02,TW09,TW06,TW16,TW02,TW09
# 158 TW24,TW05,TW17,TW09,TW02
# 160 TW24,TW01,TW01,TW02,TW02,TW01
# 161 TW06s,TW24,TW04,TW20,TW11,TW01,TW02,TW01,TW02,TW01,TW02,TW01
# 163 TW24TW08,TW24,TW02,TW05,TW07,TW07,TW17,TW06,TW18,TW11,TW08,TW01
# 164 TW09s,TW02,TW24,TW24,TW09s,TW09s,TW09s
# 165 TW09,TW05,TW02,TW11,TW04,TW20,TW01
# 166 TW24TW09,TW13,TW15,TW05,TW03,TW19,TW04,TW09,TW04,TW09,TW24TW09,TW24,TW13,TW15,TW05,TW03,TW19,TW02,TW09
# 167 TW24TW17,TW11,TW02,TW18,TW17,TW11,TW13,TW02,TW17,TW06,TW04,TW06,TW11,TW17,TW18,TW11,TW02,TW01,TW05,TW03
# 171 TW24,TW10,TW10,TW24,TW09,TW06,TW02,TW02,TW24,TW09,TW06,TW02
# 173 TW15,TW09s,TW09s,TW09s,TW02,TW09,TW09,TW09,TW02
# 176 TW24TW08,TW07,TW06,TW08
# 177 TW05,TW02,TW17,TW01,TW16
# 181 TW01,TW08
# 183 TW24,TW24TW10,TW15,TW01,TW17,TW06,TW10
# 188 TW24TW02,TW05,TW08,TW02
# 190 TW06,TW16,TW16,TW01
# 191 TW24TW14,TW16,TW04,TW01,TW01,TW17,TW02,TW19,TW01,TW24TW14,TW16,TW04,TW16,TW02,TW01,TW02,TW17,TW02,TW19,TW01
# 192 TW06,TW06,TW17,TW02,TW02
# 194 TW24,TW05,TW17,TW08,TW17,TW08,TW02,TW05,TW17,TW08,TW08,TW17,TW08,TW02
# 195 TW24,TW08,TW09,TW02
# 196 TW24,TW24,TW16,TW16,TW08,TW01
# 198 TW24TW07,TW24TW08,TW24,TW07,TW14,TW08,TW01
# 201 TW24TW19,TW24TW19,TW08,TW01,TW24TW19,TW08
# 202 TW07,TW13,TW15,TW11,TW18,TW17,TW08,TW01
# 203 TW08,TW01
# 204 TW16,TW15,TW07,TW03,TW16,TW15,TW15,TW01,TW07,TW03
# 205 TW24TW08,TW16,TW19,TW24TW08,TW16,TW19
# 206 TW06,TW08,TW08
# 207 TW02,TW16,TW13,TW05,TW02,TW18,TW06,TW01,TW16,TW16,TW13,TW05,TW02,TW18,TW06,TW01
# 212 TW24,TW11,TW05
# 213 TW05,TW02
# 214 TW19,TW14,TW09,TW05,TW02,TW01,TW04
# 216 TW24,TW02,TW17,TW01,TW02,TW17,TW02
# 217 TW08m,TW24TW08,TW18,TW01,TW02,TW01
# 218 TW06,TW15,TW13,TW15,TW02,TW06,TW15,TW09,TW08,TW13,TW15,TW02
# 221 TW02,TW02,TW05,TW15,TW08,TW15,TW08,TW02
# 238 TW24,TW08m,TW06m,TW06m,TW20,TW16,TW08m,TW01
# 243 TW24TW08,TW24,TW08,TW05,TW04,TW02,TW01
# 244 TW24,TW22,TW16,TW13,TW06s,TW02,TW01
# 245 TW18,TW17,TW01,TW15,TW09s,TW04
# 261 TW24TW02,TW09m,TW09m,TW15,TW13,TW15,TW09m,TW13,TW02,TW02
# 262 TW23,TW16,TW22,TW22,TW24,TW24TW08,TW08,TW01
# 265 TW23,TW13,TW08m,TW08m,TW08m,TW08m,TW08m,TW08m,TW07,TW13,TW08m,TW06m,TW13,TW08m,TW01
# 268 TW24TW09,TW13,TW15,TW09m,TW15,TW09m,TW15,TW13,TW15,TW13,TW09m,TW02
# 269 TW15,TW09s,TW13,TW15
# 274 TW24,TW23,TW22,TW05,TW19,TW09,TW17,TW08,TW08,TW01,TW02
# 280 TW24TW02,TW09m,TW15,TW09m,TW13,TW02,TW09m,TW02
# 285 TW24TW08,TW23,TW22,TW08,TW18,TW09s,TW15,TW05,TW02,TW15
# 289 TW06,TW02,TW05,TW01
# 293 TW23,TW22,TW24,TW16,TW06,TW01,TW05,TW09s,TW02
# 297 TW24,TW13,TW09m,TW13,TW13,TW02
# 302 TW24TW08,TW24,TW24TW06,TW23,TW22,TW06,TW13,TW02,TW03,TW01,TW05,TW17,TW20
# 310 TW13,TW08m,TW01
# 340 TW11,TW08m,TW13,TW07,TW06m,TW06m,TW01
# 448 TW24TW09,TW24TW05,TW05,TW09s,TW02
# 459 TW24TW09,TW02,TW09s,TW05
# 460 TW02
# 590 TW05,TW24TW09,TW02,TW09s
# 595 TW09s,TW05,TW02
# 596 TW09s
# 597 TW05,TW02
# 603 TW05,TW02,TW09s,TW07,TW09s,TW08
# 606 TW24TW11,TW08,TW06s,TW01,TW18,TW19,TW06s,TW02
# 608 TW06s,TW05,TW02,TW23
# 610 TW08,TW17,TW02
# 611 TW02,TW24TW11,TW09m
# 616 TW24TW07,TW10,TW08,TW02
# 618 TW06s,TW05
# 621 TW08,TW02
# 796 TW24TW13,TW24TW15,TW24TW08,TW23,TW07,TW08m,TW13,TW17m,TW06m,TW08m,TW13,TW01,TW11,TW02
# 797 TW24TW01,TW16,TW13,TW08m,TW02,TW01
# 804 TW24TW07,TW23,TW11,TW08m,TW08m,TW01
# 806 TW06m,TW06m,TW06m,TW08m,TW01
# 812 TW09m,TW17m,TW05,TW02
# 813 TW24TW02,TW23,TW13,TW02
# 825 TW24,TW23,TW22,TW13,TW08,TW01,TW17,TW02
# 826 TW16,TW02,TW06s,TW18,TW13,TW01
# 828 TW24,TW22,TW17,TW08,TW01,TW13,TW02,TW05,TW19
# 837 TW08,TW23,TW22,TW17,TW01,TW02
# 838 TW16,TW23,TW22,TW13,TW01,TW06
# 839 TW24,TW23,TW22,TW17,TW06s,TW13,TW02,TW16,TW01,TW05
# 840 TW24TW01,TW24,TW23,TW22,TW01,TW05,TW06s,TW02
# 841 TW24TW08,TW23,TW22,TW01,TW08
# 842 TW16,TW24TW08,TW23,TW22,TW13,TW06s,TW08
# 845 TW23,TW22,TW05,TW15,TW02,TW17,TW01
# 846 TW22,TW02,TW08,TW01
# 981 TW24TW13,TW24TW16,TW06m,TW08m,TW06m,TW07,TW02,TW07,TW07,TW13,TW13,TW13,TW07,TW04,TW20,TW01
# 990 TW23,TW22,TW13,TW02,TW07,TW06m,TW13,TW13,TW06m,TW01
# 994 TW24TW07,TW24TW06,TW15,TW13,TW06m,TW13,TW16,TW13,TW06m,TW16,TW01
# 996 TW13,TW09m,TW02
# 1008 TW15,TW09m,TW17,TW01,TW13,TW05,TW09m,TW02
# 1015 TW24TW02,TW13,TW16,TW02
# 1022 TW06s,TW01,TW09s
# 1026 TW24TW08,TW15,TW01,TW09s
# 1030 TW09,TW08
# 1031 TW09s
# 1033 TW17,TW24TW08,TW08,TW06s,TW04,TW05
# 1042 TW24TW08,TW08
# 1046 TW01,TW08
# 1047 TW18,TW08,TW04
# 1049 TW08
# 1053 TW16
# 1054 TW01,TW08
# 1057 TW08,TW06s,TW11
# 1060 TW08,TW15
# 1062 TW08,TW13
# 1064 TW24TW08,TW08,TW06s
# 1069 TW24TW08,TW08,TW20
# 1071 TW19,TW08
# 1072 TW24TW08,TW08,TW07
# 1073 TW24TW08,TW08
# 1078 TW06s,TW08,TW01,TW15
# 1080 TW24TW08,TW02,TW07,TW11,TW11,TW18
# 1082 TW24TW08,TW24TW14,TW06s,TW08,TW01
# 1360 TW09s,TW05,TW02
# 1362 TW23,TW22,TW09s,TW02
# 1363 TW01,TW08,TW09s,TW24,TW02,TW17
# 1364 TW05,TW09s,TW02
# 1365 TW17,TW01
# 1366 TW16,TW24TW17,TW02,TW17,TW01
# 1372 TW02,TW17
# 1373 TW09s,TW01,TW02,TW02
# 1375 TW23,TW09s,TW16,TW06s
# 1377 TW09,TW24TW16
# 1378 TW02
# 1379 TW02,TW09s
# 1380 TW24,TW08,TW23
# 1382 TW06s,TW09s,TW05
# 1835 TW24TW08,TW23,TW22,TW02,TW01,TW08
# 1837 TW23,TW22,TW17,TW05,TW16,TW13,TW02,TW01
# 1838 TW24TW08,TW22,TW13,TW16,TW08,TW16,TW17,TW05,TW02,TW03,TW01
# 1839 TW23,TW22,TW06s,TW03,TW02,TW16,TW01
# 1846 TW06s,TW02,TW01,TW16,TW05,TW03,TW17
# 1857 TW03,TW02,TW09s,TW01
#
# *** End process_worksheet ***
#
# analyze_tags: len(tag_sub_dict) 132
# [2, 9, 10, 12, 14, 21, 22, 26, 27, 29, 33, 34, 42, 43, 45, 48, 51, 53, 61, 64, 66, 68, 74, 75, 76, 86, 90, 94, 96, 99, 102, 104, 106, 107, 112, 115, 118, 120, 122, 123, 126, 128, 129, 134, 137, 142, 146, 148, 150, 151, 153, 157, 158, 160, 161, 163, 164, 165, 166, 167, 171, 173, 177, 188, 191, 192, 194, 195, 207, 213, 214, 216, 217, 218, 221, 243, 244, 261, 268, 274, 280, 285, 289, 293, 297, 302, 448, 459, 460, 590, 595, 597, 603, 606, 608, 610, 611, 616, 621, 796, 797, 812, 813, 825, 826, 828, 837, 839, 840, 845, 846, 981, 990, 996, 1008, 1015, 1080, 1360, 1362, 1363, 1364, 1366, 1372, 1373, 1378, 1379, 1835, 1837, 1838, 1839, 1846, 1857]
# analyze_text: #keys: 131
# ['2', '9', '10', '12', '14', '21', '22', '26', '27', '29', '33', '34', '42', '43', '45', '48', '51', '53', '61', '64', '66', '68', '74', '75', '76', '86', '90', '94', '96', '99', '102', '104', '106', '107', '112', '115', '118', '120', '122', '123', '128', '129', '134', '137', '142', '146', '148', '150', '151', '153', '157', '158', '160', '161', '163', '164', '165', '166', '167', '171', '173', '177', '188', '191', '192', '194', '195', '207', '213', '214', '216', '217', '218', '221', '243', '244', '261', '268', '274', '280', '285', '289', '293', '297', '302', '448', '459', '460', '590', '595', '597', '603', '606', '608', '610', '611', '616', '621', '796', '797', '812', '813', '825', '826', '828', '837', '839', '840', '845', '846', '981', '990', '996', '1008', '1015', '1080', '1360', '1362', '1363', '1364', '1366', '1372', '1373', '1378', '1379', '1835', '1837', '1838', '1839', '1846', '1857']
#
# Calculate tag_train_set similarities:
#
# jaccard: len(m): 131
#
# Calculate text_train_set similarities:
#
# jaccard: len(m): 131
# heatmap_TW02.html
#
# doc_ids: ['2', '9', '10', '12', '14', '21', '22', '26', '27', '29', '33', '34', '42', '43', '45', '48', '51', '53', '61', '64', '66', '68', '74', '75', '76', '86', '90', '94', '96', '99', '102', '104', '106', '107', '112', '115', '118', '120', '122', '123', '128', '129', '134', '137', '142', '146', '148', '150', '151', '153', '157', '158', '160', '161', '163', '164', '165', '166', '167', '171', '173', '177', '188', '191', '192', '194', '195', '207', '213', '214', '216', '217', '218', '221', '243', '244', '261', '268', '274', '280', '285', '289', '293', '297', '302', '448', '459', '460', '590', '595', '597', '603', '606', '608', '610', '611', '616', '621', '796', '797', '812', '813', '825', '826', '828', '837', '839', '840', '845', '846', '981', '990', '996', '1008', '1015', '1080', '1360', '1362', '1363', '1364', '1366', '1372', '1373', '1378', '1379', '1835', '1837', '1838', '1839', '1846', '1857']
#
# main: doc_no: 0 target_tag TW02
# doc_no: 0
# doc_key: 2
# Pearsonr Result:  (0.19252162549671498, 0.027591641085797133)
# SpearmanrResult(correlation=0.07007464289920103, pvalue=0.42642015797644894)
# Correlation Coefficients:
#  [[1.         0.32713862]
#  [0.32713862 1.        ]]
# doc_no: 0
# doc_key: 2
#
# main: doc_no: 1 target_tag TW02
# doc_no: 1
# doc_key: 9
# Pearsonr Result:  (0.22204771620538968, 0.010803260711921675)
# SpearmanrResult(correlation=0.13138815734770165, pvalue=0.1346833017564738)
# Correlation Coefficients:
#  [[1.         0.22848118]
#  [0.22848118 1.        ]]
# doc_no: 1
# doc_key: 9
#
# main: doc_no: 2 target_tag TW02
# doc_no: 2
# doc_key: 10
# Pearsonr Result:  (0.11258272457162938, 0.2004421403499527)
# SpearmanrResult(correlation=0.021118911319953842, pvalue=0.8107744635234809)
# Correlation Coefficients:
#  [[1.         0.32065559]
#  [0.32065559 1.        ]]
# doc_no: 2
# doc_key: 10
#
# main: doc_no: 3 target_tag TW02
# doc_no: 3
# doc_key: 12
# Pearsonr Result:  (0.1105185347540822, 0.20887221349668186)
# SpearmanrResult(correlation=-0.0004522055760385169, pvalue=0.995909962381113)
# Correlation Coefficients:
#  [[1.         0.30938914]
#  [0.30938914 1.        ]]
# doc_no: 3
# doc_key: 12
#
# main: doc_no: 4 target_tag TW02
# doc_no: 4
# doc_key: 14
# Pearsonr Result:  (0.09189902895386194, 0.2965027145332403)
# SpearmanrResult(correlation=0.02598783602183034, pvalue=0.7682663029928949)
# Correlation Coefficients:
#  [[1.         0.38504846]
#  [0.38504846 1.        ]]
# doc_no: 4
# doc_key: 14
#
# main: doc_no: 5 target_tag TW02
# doc_no: 5
# doc_key: 21
# Pearsonr Result:  (0.19050282736153246, 0.029293964827435695)
# SpearmanrResult(correlation=0.1102191259512045, pvalue=0.21011576419110203)
# Correlation Coefficients:
#  [[1.         0.44983709]
#  [0.44983709 1.        ]]
# doc_no: 5
# doc_key: 21
#
# main: doc_no: 6 target_tag TW02
# doc_no: 6
# doc_key: 22
# Pearsonr Result:  (0.21128163772055908, 0.015415604422874051)
# SpearmanrResult(correlation=0.1075381146578661, pvalue=0.2214874730038321)
# Correlation Coefficients:
#  [[1.         0.57947246]
#  [0.57947246 1.        ]]
# doc_no: 6
# doc_key: 22
#
# main: doc_no: 7 target_tag TW02
# doc_no: 7
# doc_key: 26
# Pearsonr Result:  (0.12317449154369772, 0.1610262831594939)
# SpearmanrResult(correlation=0.04008453657876286, pvalue=0.6494156185909825)
# Correlation Coefficients:
#  [[1.         0.52809688]
#  [0.52809688 1.        ]]
# doc_no: 7
# doc_key: 26
#
# main: doc_no: 8 target_tag TW02
# doc_no: 8
# doc_key: 27
# Pearsonr Result:  (0.23147643112233773, 0.007809240150735444)
# SpearmanrResult(correlation=0.20929173869152215, pvalue=0.016434160094072517)
# Correlation Coefficients:
#  [[1.         0.27882124]
#  [0.27882124 1.        ]]
# doc_no: 8
# doc_key: 27
#
# main: doc_no: 9 target_tag TW02
# doc_no: 9
# doc_key: 29
# Pearsonr Result:  (0.10427847004048697, 0.23589199557838147)
# SpearmanrResult(correlation=-0.015698987332856344, pvalue=0.8587449832402148)
# Correlation Coefficients:
#  [[1.         0.37525062]
#  [0.37525062 1.        ]]
# doc_no: 9
# doc_key: 29
#
# main: doc_no: 10 target_tag TW02
# doc_no: 10
# doc_key: 33
# Pearsonr Result:  (0.2500967520508897, 0.003964357656997826)
# SpearmanrResult(correlation=0.10714740359243843, pvalue=0.22318041114532464)
# Correlation Coefficients:
#  [[1.        0.3041878]
#  [0.3041878 1.       ]]
# doc_no: 10
# doc_key: 33
#
# main: doc_no: 11 target_tag TW02
# doc_no: 11
# doc_key: 34
# Pearsonr Result:  (0.17561434288631037, 0.044818428636910976)
# SpearmanrResult(correlation=0.02523690036831422, pvalue=0.7747810578439724)
# Correlation Coefficients:
#  [[1.         0.19186017]
#  [0.19186017 1.        ]]
# doc_no: 11
# doc_key: 34
#
# main: doc_no: 12 target_tag TW02
# doc_no: 12
# doc_key: 42
# Pearsonr Result:  (0.1483044501595046, 0.09092939933521976)
# SpearmanrResult(correlation=0.02793932257783058, pvalue=0.7514126659436831)
# Correlation Coefficients:
#  [[1.         0.47416628]
#  [0.47416628 1.        ]]
# doc_no: 12
# doc_key: 42
#
# main: doc_no: 13 target_tag TW02
# doc_no: 13
# doc_key: 43
# Pearsonr Result:  (0.27711380862783813, 0.0013538719566444926)
# SpearmanrResult(correlation=0.17721408845607434, pvalue=0.04287508011332885)
# Correlation Coefficients:
#  [[1.         0.26806204]
#  [0.26806204 1.        ]]
# doc_no: 13
# doc_key: 43
#
# main: doc_no: 14 target_tag TW02
# doc_no: 14
# doc_key: 45
# Pearsonr Result:  (0.1611503574585676, 0.06594309563668528)
# SpearmanrResult(correlation=0.08172311911920337, pvalue=0.35343218692469636)
# Correlation Coefficients:
#  [[1.         0.53677382]
#  [0.53677382 1.        ]]
# doc_no: 14
# doc_key: 45
#
# main: doc_no: 15 target_tag TW02
# doc_no: 15
# doc_key: 48
# Pearsonr Result:  (0.1904237477592684, 0.029362426117900107)
# SpearmanrResult(correlation=0.1310887840611216, pvalue=0.1355817291972523)
# Correlation Coefficients:
#  [[1.         0.19420615]
#  [0.19420615 1.        ]]
# doc_no: 15
# doc_key: 48
#
# main: doc_no: 16 target_tag TW02
# doc_no: 16
# doc_key: 51
# Pearsonr Result:  (0.20157759288214702, 0.020954574038101095)
# SpearmanrResult(correlation=0.10099559190251932, pvalue=0.25104859849087363)
# Correlation Coefficients:
#  [[1.         0.28815284]
#  [0.28815284 1.        ]]
# doc_no: 16
# doc_key: 51
#
# main: doc_no: 17 target_tag TW02
# doc_no: 17
# doc_key: 53
# Pearsonr Result:  (0.13854936438545476, 0.11452125042624133)
# SpearmanrResult(correlation=0.0606506259778445, pvalue=0.49135269765453005)
# Correlation Coefficients:
#  [[1.         0.43854769]
#  [0.43854769 1.        ]]
# doc_no: 17
# doc_key: 53
#
# main: doc_no: 18 target_tag TW02
# doc_no: 18
# doc_key: 61
# Pearsonr Result:  (0.2332156066460376, 0.007345456182807222)
# SpearmanrResult(correlation=-0.10810393940601663, pvalue=0.21905192683907104)
# Correlation Coefficients:
#  [[1.         0.55460234]
#  [0.55460234 1.        ]]
# doc_no: 18
# doc_key: 61
#
# main: doc_no: 19 target_tag TW02
# doc_no: 19
# doc_key: 64
# Pearsonr Result:  (0.15240775031272133, 0.0822398275393773)
# SpearmanrResult(correlation=0.07653577319888905, pvalue=0.3849173153197226)
# Correlation Coefficients:
#  [[1.         0.51677331]
#  [0.51677331 1.        ]]
# doc_no: 19
# doc_key: 64
#
# main: doc_no: 20 target_tag TW02
# doc_no: 20
# doc_key: 66
# Pearsonr Result:  (0.26664260535562434, 0.002080102337045827)
# SpearmanrResult(correlation=-0.00973542963907826, pvalue=0.9121224769753877)
# Correlation Coefficients:
#  [[1.         0.25421107]
#  [0.25421107 1.        ]]
# doc_no: 20
# doc_key: 66
#
# main: doc_no: 21 target_tag TW02
# doc_no: 21
# doc_key: 68
# Pearsonr Result:  (0.03886538917450705, 0.6594027241542859)
# SpearmanrResult(correlation=-0.09753198206332736, pvalue=0.267753738056187)
# Correlation Coefficients:
#  [[1.         0.43070441]
#  [0.43070441 1.        ]]
# doc_no: 21
# doc_key: 68
# main: doc_no: 22 target_tag TW02
# doc_no: 22
# doc_key: 74
# Pearsonr Result:  (0.27018296702529115, 0.0018023500558797885)
# SpearmanrResult(correlation=0.06843817021347953, pvalue=0.43732718213295296)
# Correlation Coefficients:
#  [[1.         0.29549792]
#  [0.29549792 1.        ]]
# doc_no: 22
# doc_key: 74
#
# main: doc_no: 23 target_tag TW02
# doc_no: 23
# doc_key: 75
# Pearsonr Result:  (0.18279811194645795, 0.036634846251779825)
# SpearmanrResult(correlation=0.11349329907556957, pvalue=0.19680246434514787)
# Correlation Coefficients:
#  [[1.         0.55926309]
#  [0.55926309 1.        ]]
# doc_no: 23
# doc_key: 75
#
# main: doc_no: 24 target_tag TW02
# doc_no: 24
# doc_key: 76
# Pearsonr Result:  (0.26936153360157783, 0.001863609749263582)
# SpearmanrResult(correlation=0.14057123106082445, pvalue=0.10927647131940525)
# Correlation Coefficients:
#  [[1.         0.56010353]
#  [0.56010353 1.        ]]
# doc_no: 24
# doc_key: 76
#
# main: doc_no: 25 target_tag TW02
# doc_no: 25
# doc_key: 86
# Pearsonr Result:  (0.13642214860271193, 0.1202485139348735)
# SpearmanrResult(correlation=0.05149215429268433, pvalue=0.5591571558555348)
# Correlation Coefficients:
#  [[1.         0.52338493]
#  [0.52338493 1.        ]]
# doc_no: 25
# doc_key: 86
#
# main: doc_no: 26 target_tag TW02
# doc_no: 26
# doc_key: 90
# Pearsonr Result:  (0.05439781391912639, 0.5371678349130049)
# SpearmanrResult(correlation=-0.05237777713376666, pvalue=0.5524094414532528)
# Correlation Coefficients:
#  [[1.         0.21005688]
#  [0.21005688 1.        ]]
# doc_no: 26
# doc_key: 90
#
# main: doc_no: 27 target_tag TW02
# doc_no: 27
# doc_key: 94
# Pearsonr Result:  (0.12532949108462965, 0.15376906499859025)
# SpearmanrResult(correlation=-0.019879942233156846, pvalue=0.8216853259557154)
# Correlation Coefficients:
#  [[1.         0.48425302]
#  [0.48425302 1.        ]]
# doc_no: 27
# doc_key: 94
#
# main: doc_no: 28 target_tag TW02
# doc_no: 28
# doc_key: 96
# Pearsonr Result:  (0.2899948088597054, 0.0007799017239180857)
# SpearmanrResult(correlation=0.1772200360185402, pvalue=0.04286798861225824)
# Correlation Coefficients:
#  [[1.         0.31073082]
#  [0.31073082 1.        ]]
# doc_no: 28
# doc_key: 96
#
# main: doc_no: 29 target_tag TW02
# doc_no: 29
# doc_key: 99
# Pearsonr Result:  (0.19146227397325716, 0.02847410231984876)
# SpearmanrResult(correlation=0.0904748498448061, pvalue=0.304083064474074)
# Correlation Coefficients:
#  [[1.         0.49699481]
#  [0.49699481 1.        ]]
# doc_no: 29
# doc_key: 99
#
# main: doc_no: 30 target_tag TW02
# doc_no: 30
# doc_key: 102
# Pearsonr Result:  (0.2690394269865427, 0.0018881429217333704)
# SpearmanrResult(correlation=0.05731778637474109, pvalue=0.5155117206934392)
# Correlation Coefficients:
#  [[1.         0.45365188]
#  [0.45365188 1.        ]]
# doc_no: 30
# doc_key: 102
#
# main: doc_no: 31 target_tag TW02
# doc_no: 31
# doc_key: 104
# Pearsonr Result:  (0.26838761535052647, 0.0019386869871177363)
# SpearmanrResult(correlation=0.15552717660179766, pvalue=0.07608969367966467)
# Correlation Coefficients:
#  [[1.         0.46715242]
#  [0.46715242 1.        ]]
# doc_no: 31
# doc_key: 104
#
# main: doc_no: 32 target_tag TW02
# doc_no: 32
# doc_key: 106
# Pearsonr Result:  (0.08449551720124979, 0.3372848059879029)
# SpearmanrResult(correlation=-0.005026330091184373, pvalue=0.9545627454247025)
# Correlation Coefficients:
#  [[1.         0.51579907]
#  [0.51579907 1.        ]]
# doc_no: 32
# doc_key: 106
#
# main: doc_no: 33 target_tag TW02
# doc_no: 33
# doc_key: 107
# Pearsonr Result:  (0.06223977110876412, 0.4800485774220843)
# SpearmanrResult(correlation=-0.08455959902995376, pvalue=0.3369172015478511)
# Correlation Coefficients:
#  [[1.         0.44139438]
#  [0.44139438 1.        ]]
# doc_no: 33
# doc_key: 107
#
# main: doc_no: 34 target_tag TW02
# doc_no: 34
# doc_key: 112
# Pearsonr Result:  (0.13734394668276925, 0.1177400544297381)
# SpearmanrResult(correlation=0.029002880793308435, pvalue=0.7422759831112518)
# Correlation Coefficients:
#  [[1.        0.5702651]
#  [0.5702651 1.       ]]
# doc_no: 34
# doc_key: 112
#
# main: doc_no: 35 target_tag TW02
# doc_no: 35
# doc_key: 115
# Pearsonr Result:  (0.25360252212441026, 0.0034697520614451758)
# SpearmanrResult(correlation=0.16326067093299612, pvalue=0.06243183967274267)
# Correlation Coefficients:
#  [[1.         0.24501571]
#  [0.24501571 1.        ]]
# doc_no: 35
# doc_key: 115
#
# main: doc_no: 36 target_tag TW02
# doc_no: 36
# doc_key: 118
# Pearsonr Result:  (0.1803396470271328, 0.03928102378959702)
# SpearmanrResult(correlation=0.074585344055469, pvalue=0.39718090764945657)
# Correlation Coefficients:
#  [[1.         0.27948413]
#  [0.27948413 1.        ]]
# doc_no: 36
# doc_key: 118
#
# main: doc_no: 37 target_tag TW02
# doc_no: 37
# doc_key: 120
# Pearsonr Result:  (0.031274834158993146, 0.7228796090745164)
# SpearmanrResult(correlation=-0.20124251120041406, pvalue=0.02117310048197546)
# Correlation Coefficients:
#  [[1.         0.51766703]
#  [0.51766703 1.        ]]
# doc_no: 37
# doc_key: 120
#
# main: doc_no: 38 target_tag TW02
# doc_no: 38
# doc_key: 122
# Pearsonr Result:  (0.058430076717422216, 0.5073818016561983)
# SpearmanrResult(correlation=-0.08646147353634422, pvalue=0.3261231610247174)
# Correlation Coefficients:
#  [[1.         0.59494861]
#  [0.59494861 1.        ]]
# doc_no: 38
# doc_key: 122
#
# main: doc_no: 39 target_tag TW02
# doc_no: 39
# doc_key: 123
# Pearsonr Result:  (0.30813739310562044, 0.0003429091147042267)
# SpearmanrResult(correlation=0.09151642461006751, pvalue=0.29852678406748173)
# Correlation Coefficients:
#  [[1.         0.54097734]
#  [0.54097734 1.        ]]
# doc_no: 39
# doc_key: 123
#
# main: doc_no: 40 target_tag TW02
# doc_no: 40
# doc_key: 128
# Pearsonr Result:  (0.12652790435311917, 0.14984107460627352)
# SpearmanrResult(correlation=-0.056254115831489294, pvalue=0.5233483063952885)
# Correlation Coefficients:
#  [[1.         0.43198685]
#  [0.43198685 1.        ]]
# doc_no: 40
# doc_key: 128
#
# main: doc_no: 41 target_tag TW02
# doc_no: 41
# doc_key: 129
# Pearsonr Result:  (0.12075449403648746, 0.16947733929510303)
# SpearmanrResult(correlation=0.015702549485611915, pvalue=0.8587132651757282)
# Correlation Coefficients:
#  [[1.         0.46647417]
#  [0.46647417 1.        ]]
# doc_no: 41
# doc_key: 129
#
# main: doc_no: 42 target_tag TW02
# doc_no: 42
# doc_key: 134
# Pearsonr Result:  (0.21123390624059302, 0.015439378256275277)
# SpearmanrResult(correlation=0.11194828838867005, pvalue=0.20300660131292542)
# Correlation Coefficients:
#  [[1.         0.46428008]
#  [0.46428008 1.        ]]
# doc_no: 42
# doc_key: 134
#
# main: doc_no: 43 target_tag TW02
# doc_no: 43
# doc_key: 137
# Pearsonr Result:  (0.18071361873914948, 0.038868443691943706)
# SpearmanrResult(correlation=0.09110129792158718, pvalue=0.3007331946475163)
# Correlation Coefficients:
#  [[1.        0.2791781]
#  [0.2791781 1.       ]]
# doc_no: 43
# doc_key: 137
#
# main: doc_no: 44 target_tag TW02
# doc_no: 44
# doc_key: 142
# Pearsonr Result:  (0.2246724833779363, 0.009882331107468686)
# SpearmanrResult(correlation=0.14063562237443994, pvalue=0.1091125758445613)
# Correlation Coefficients:
#  [[1.         0.58356184]
#  [0.58356184 1.        ]]
# doc_no: 44
# doc_key: 142
#
# main: doc_no: 45 target_tag TW02
# doc_no: 45
# doc_key: 146
# Pearsonr Result:  (0.18335584217808623, 0.0360558873575562)
# SpearmanrResult(correlation=0.15503899443405414, pvalue=0.07702693471704211)
# Correlation Coefficients:
#  [[1.         0.50651031]
#  [0.50651031 1.        ]]
# doc_no: 45
# doc_key: 146
#
# main: doc_no: 46 target_tag TW02
# doc_no: 46
# doc_key: 148
# Pearsonr Result:  (0.11375960296026669, 0.195747111880322)
# SpearmanrResult(correlation=0.008757296954307554, pvalue=0.9209214300645067)
# Correlation Coefficients:
#  [[1.         0.55375055]
#  [0.55375055 1.        ]]
# doc_no: 46
# doc_key: 148
#
# main: doc_no: 47 target_tag TW02
# doc_no: 47
# doc_key: 150
# Pearsonr Result:  (0.200536844069867, 0.021639731779726466)
# SpearmanrResult(correlation=0.1295768507241349, pvalue=0.14018912167243086)
# Correlation Coefficients:
#  [[1.         0.18821522]
#  [0.18821522 1.        ]]
# doc_no: 47
# doc_key: 150
#
# main: doc_no: 48 target_tag TW02
# doc_no: 48
# doc_key: 151
# Pearsonr Result:  (0.16356497875029208, 0.06193836194919313)
# SpearmanrResult(correlation=0.04319626419261107, pvalue=0.6242087857313997)
# Correlation Coefficients:
#  [[1.         0.38888952]
#  [0.38888952 1.        ]]
# doc_no: 48
# doc_key: 151
#
# main: doc_no: 49 target_tag TW02
# doc_no: 49
# doc_key: 153
# Pearsonr Result:  (0.09444969458826166, 0.28324135052838767)
# SpearmanrResult(correlation=-0.08360276567948827, pvalue=0.34243254240079857)
# Correlation Coefficients:
#  [[1.         0.34628526]
#  [0.34628526 1.        ]]
# doc_no: 49
# doc_key: 153
# main: doc_no: 50 target_tag TW02
# doc_no: 50
# doc_key: 157
# Pearsonr Result:  (0.1998486943162053, 0.022103272720330743)
# SpearmanrResult(correlation=0.08720984410393388, pvalue=0.32193740247882513)
# Correlation Coefficients:
#  [[1.         0.38899664]
#  [0.38899664 1.        ]]
# doc_no: 50
# doc_key: 157
#
# main: doc_no: 51 target_tag TW02
# doc_no: 51
# doc_key: 158
# Pearsonr Result:  (0.13526825317756, 0.12344662079615555)
# SpearmanrResult(correlation=0.022213640984961796, pvalue=0.8011639013756218)
# Correlation Coefficients:
#  [[1.         0.37847621]
#  [0.37847621 1.        ]]
# doc_no: 51
# doc_key: 158
#
# main: doc_no: 52 target_tag TW02
# doc_no: 52
# doc_key: 160
# Pearsonr Result:  (0.011635546135330382, 0.8950610117295443)
# SpearmanrResult(correlation=-0.06083338001189952, pvalue=0.4900455591799826)
# Correlation Coefficients:
#  [[1.        0.5407323]
#  [0.5407323 1.       ]]
# doc_no: 52
# doc_key: 160
#
# main: doc_no: 53 target_tag TW02
# doc_no: 53
# doc_key: 161
# Pearsonr Result:  (0.09166914941446293, 0.2977177421286346)
# SpearmanrResult(correlation=-0.064390263903318, pvalue=0.4649772839687578)
# Correlation Coefficients:
#  [[1.         0.49130725]
#  [0.49130725 1.        ]]
# doc_no: 53
# doc_key: 161
#
# main: doc_no: 54 target_tag TW02
# doc_no: 54
# doc_key: 163
# Pearsonr Result:  (0.05600882790829235, 0.5251639974697901)
# SpearmanrResult(correlation=-0.027815018507975103, pvalue=0.7524828010522767)
# Correlation Coefficients:
#  [[1.         0.35737499]
#  [0.35737499 1.        ]]
# doc_no: 54
# doc_key: 163
#
# main: doc_no: 55 target_tag TW02
# doc_no: 55
# doc_key: 164
# Pearsonr Result:  (0.26990888006642044, 0.001822584135026233)
# SpearmanrResult(correlation=0.1819214624177713, pvalue=0.037560674704259986)
# Correlation Coefficients:
#  [[1.         0.51845391]
#  [0.51845391 1.        ]]
# doc_no: 55
# doc_key: 164
#
# main: doc_no: 56 target_tag TW02
# doc_no: 56
# doc_key: 165
# Pearsonr Result:  (0.12302835345541333, 0.16152752406969567)
# SpearmanrResult(correlation=0.0639153693070285, pvalue=0.46828294037676876)
# Correlation Coefficients:
#  [[1.         0.12113788]
#  [0.12113788 1.        ]]
# doc_no: 56
# doc_key: 165
#
# main: doc_no: 57 target_tag TW02
# doc_no: 57
# doc_key: 166
# Pearsonr Result:  (0.23361793077667778, 0.007241712019220176)
# SpearmanrResult(correlation=0.11055619185762944, pvalue=0.20871618413441878)
# Correlation Coefficients:
#  [[1.         0.24704327]
#  [0.24704327 1.        ]]
# doc_no: 57
# doc_key: 166
#
# main: doc_no: 58 target_tag TW02
# doc_no: 58
# doc_key: 167
# Pearsonr Result:  (0.17245191720365208, 0.04887642517037716)
# SpearmanrResult(correlation=0.076242852027424, pvalue=0.38674435391614026)
# Correlation Coefficients:
#  [[1.         0.19933928]
#  [0.19933928 1.        ]]
# doc_no: 58
# doc_key: 167
#
# main: doc_no: 59 target_tag TW02
# doc_no: 59
# doc_key: 171
# Pearsonr Result:  (0.32057011232830745, 0.00018925799289714354)
# SpearmanrResult(correlation=0.10433993105787644, pvalue=0.23561447700774343)
# Correlation Coefficients:
#  [[1.         0.42050758]
#  [0.42050758 1.        ]]
# doc_no: 59
# doc_key: 171
#
# main: doc_no: 60 target_tag TW02
# doc_no: 60
# doc_key: 173
# Pearsonr Result:  (0.24369602742522034, 0.005033016128076863)
# SpearmanrResult(correlation=0.18364415429355524, pvalue=0.03575963657677819)
# Correlation Coefficients:
#  [[1.         0.57938254]
#  [0.57938254 1.        ]]
# doc_no: 60
# doc_key: 173
#
# main: doc_no: 61 target_tag TW02
# doc_no: 61
# doc_key: 177
# Pearsonr Result:  (0.0992178665235403, 0.25953062852640296)
# SpearmanrResult(correlation=-0.018109497596746873, pvalue=0.8373354190830382)
# Correlation Coefficients:
#  [[1.         0.20708431]
#  [0.20708431 1.        ]]
# doc_no: 61
# doc_key: 177
#
# main: doc_no: 62 target_tag TW02
# doc_no: 62
# doc_key: 188
# Pearsonr Result:  (0.28326234704460207, 0.001043867508609013)
# SpearmanrResult(correlation=0.2181113547152356, pvalue=0.012325668547969511)
# Correlation Coefficients:
#  [[1.         0.25182139]
#  [0.25182139 1.        ]]
# doc_no: 62
# doc_key: 188
#
# main: doc_no: 63 target_tag TW02
# doc_no: 63
# doc_key: 191
# Pearsonr Result:  (0.08112052141399202, 0.35700479332993207)
# SpearmanrResult(correlation=-0.05090731918696265, pvalue=0.5636346879991202)
# Correlation Coefficients:
#  [[1.         0.43935601]
#  [0.43935601 1.        ]]
# doc_no: 63
# doc_key: 191
#
# main: doc_no: 64 target_tag TW02
# doc_no: 64
# doc_key: 192
# Pearsonr Result:  (0.030927134326394313, 0.72583700507844)
# SpearmanrResult(correlation=-0.08592058907408946, pvalue=0.3291700817305958)
# Correlation Coefficients:
#  [[1.         0.48463417]
#  [0.48463417 1.        ]]
# doc_no: 64
# doc_key: 192
#
# main: doc_no: 65 target_tag TW02
# doc_no: 65
# doc_key: 194
# Pearsonr Result:  (0.21531004239797968, 0.013520501107551573)
# SpearmanrResult(correlation=0.16601842492994595, pvalue=0.05807522544693715)
# Correlation Coefficients:
#  [[1.         0.39078717]
#  [0.39078717 1.        ]]
# doc_no: 65
# doc_key: 194
#
# main: doc_no: 66 target_tag TW02
# doc_no: 66
# doc_key: 195
# Pearsonr Result:  (0.30204349217760035, 0.00045460203777246286)
# SpearmanrResult(correlation=0.18752077108135315, pvalue=0.031971471146843664)
# Correlation Coefficients:
#  [[1.         0.45369647]
#  [0.45369647 1.        ]]
# doc_no: 66
# doc_key: 195
#
# main: doc_no: 67 target_tag TW02
# doc_no: 67
# doc_key: 207
# Pearsonr Result:  (0.11300144396306602, 0.198762482761955)
# SpearmanrResult(correlation=-0.05078481294738889, pvalue=0.5645747616648318)
# Correlation Coefficients:
#  [[1.         0.20572234]
#  [0.20572234 1.        ]]
# doc_no: 67
# doc_key: 207
#
# main: doc_no: 68 target_tag TW02
# doc_no: 68
# doc_key: 213
# Pearsonr Result:  (0.22545864035556792, 0.009620299535621307)
# SpearmanrResult(correlation=0.07832624149470077, pvalue=0.37386338687634113)
# Correlation Coefficients:
#  [[1.        0.3361459]
#  [0.3361459 1.       ]]
# doc_no: 68
# doc_key: 213
#
# main: doc_no: 69 target_tag TW02
# doc_no: 69
# doc_key: 214
# Pearsonr Result:  (0.1746205220280865, 0.0460622810407475)
# SpearmanrResult(correlation=0.03465484631118257, pvalue=0.6943494381626929)
# Correlation Coefficients:
#  [[1.         0.69649584]
#  [0.69649584 1.        ]]
# doc_no: 69
# doc_key: 214
#
# main: doc_no: 70 target_tag TW02
# doc_no: 70
# doc_key: 216
# Pearsonr Result:  (0.07581471953703312, 0.3894241352245641)
# SpearmanrResult(correlation=-0.0009991680657533825, pvalue=0.9909630342344222)
# Correlation Coefficients:
#  [[1.         0.42421275]
#  [0.42421275 1.        ]]
# doc_no: 70
# doc_key: 216
#
# main: doc_no: 71 target_tag TW02
# doc_no: 71
# doc_key: 217
# Pearsonr Result:  (0.09886388714918445, 0.26124270646778486)
# SpearmanrResult(correlation=-0.037448953008588394, pvalue=0.6710817050081923)
# Correlation Coefficients:
#  [[1.         0.53364888]
#  [0.53364888 1.        ]]
# doc_no: 71
# doc_key: 217
#
# main: doc_no: 72 target_tag TW02
# doc_no: 72
# doc_key: 218
# Pearsonr Result:  (0.27849982173600335, 0.0012774468530958145)
# SpearmanrResult(correlation=0.11463690302716205, pvalue=0.19229941196388428)
# Correlation Coefficients:
#  [[1.         0.29317728]
#  [0.29317728 1.        ]]
# doc_no: 72
# doc_key: 218
#
# main: doc_no: 73 target_tag TW02
# doc_no: 73
# doc_key: 221
# Pearsonr Result:  (0.15294274879901212, 0.08115762688320596)
# SpearmanrResult(correlation=0.091148779852591, pvalue=0.30048028428822077)
# Correlation Coefficients:
#  [[1.         0.41185055]
#  [0.41185055 1.        ]]
# doc_no: 73
# doc_key: 221
#
# main: doc_no: 74 target_tag TW02
# doc_no: 74
# doc_key: 243
# Pearsonr Result:  (0.08939214543555507, 0.3099302509715758)
# SpearmanrResult(correlation=0.08102105774429878, pvalue=0.35759663534731867)
# Correlation Coefficients:
#  [[1.       0.551185]
#  [0.551185 1.      ]]
# doc_no: 74
# doc_key: 243
#
# main: doc_no: 75 target_tag TW02
# doc_no: 75
# doc_key: 244
# Pearsonr Result:  (0.20074125317731126, 0.0215036620883325)
# SpearmanrResult(correlation=0.08924249316323794, pvalue=0.31074418825035044)
# Correlation Coefficients:
#  [[1.         0.51433065]
#  [0.51433065 1.        ]]
# doc_no: 75
# doc_key: 244
#
# main: doc_no: 76 target_tag TW02
# doc_no: 76
# doc_key: 261
# Pearsonr Result:  (0.21801325147432504, 0.012365895927755586)
# SpearmanrResult(correlation=0.08307681803233109, pvalue=0.3454883495473716)
# Correlation Coefficients:
#  [[1.         0.57222412]
#  [0.57222412 1.        ]]
# doc_no: 76
# doc_key: 261
#
# main: doc_no: 77 target_tag TW02
# doc_no: 77
# doc_key: 268
# Pearsonr Result:  (0.22062305076174493, 0.01133402835328738)
# SpearmanrResult(correlation=0.12336744141054569, pvalue=0.1603662619232564)
# Correlation Coefficients:
#  [[1.         0.55215911]
#  [0.55215911 1.        ]]
# doc_no: 77
# doc_key: 268
# main: doc_no: 78 target_tag TW02
# doc_no: 78
# doc_key: 274
# Pearsonr Result:  (0.17051504390185826, 0.05150905856915706)
# SpearmanrResult(correlation=0.004239434276258965, pvalue=0.9616702502368987)
# Correlation Coefficients:
#  [[1.         0.40380529]
#  [0.40380529 1.        ]]
# doc_no: 78
# doc_key: 274
#
# main: doc_no: 79 target_tag TW02
# doc_no: 79
# doc_key: 280
# Pearsonr Result:  (0.2982475456936069, 0.0005402286731802025)
# SpearmanrResult(correlation=0.12024529966408473, pvalue=0.17129665184399442)
# Correlation Coefficients:
#  [[1.       0.558432]
#  [0.558432 1.      ]]
# doc_no: 79
# doc_key: 280
#
# main: doc_no: 80 target_tag TW02
# doc_no: 80
# doc_key: 285
# Pearsonr Result:  (0.19339806609625823, 0.026879273182183146)
# SpearmanrResult(correlation=0.08191779801970885, pvalue=0.3522827899098071)
# Correlation Coefficients:
#  [[1.         0.15579745]
#  [0.15579745 1.        ]]
# doc_no: 80
# doc_key: 285
#
# main: doc_no: 81 target_tag TW02
# doc_no: 81
# doc_key: 289
# Pearsonr Result:  (0.07808212829766563, 0.3753589485273129)
# SpearmanrResult(correlation=-0.05161562326233253, pvalue=0.5582140566298466)
# Correlation Coefficients:
#  [[1.         0.53953777]
#  [0.53953777 1.        ]]
# doc_no: 81
# doc_key: 289
#
# main: doc_no: 82 target_tag TW02
# doc_no: 82
# doc_key: 293
# Pearsonr Result:  (0.24655037048136852, 0.0045281778050863175)
# SpearmanrResult(correlation=0.06276400953352228, pvalue=0.4763504751792279)
# Correlation Coefficients:
#  [[1.         0.38202131]
#  [0.38202131 1.        ]]
# doc_no: 82
# doc_key: 293
#
# main: doc_no: 83 target_tag TW02
# doc_no: 83
# doc_key: 297
# Pearsonr Result:  (0.38547537095425094, 5.450371657302011e-06)
# SpearmanrResult(correlation=0.2640155170427766, pvalue=0.002310686883301648)
# Correlation Coefficients:
#  [[1.         0.60522407]
#  [0.60522407 1.        ]]
# doc_no: 83
# doc_key: 297
#
# main: doc_no: 84 target_tag TW02
# doc_no: 84
# doc_key: 302
# Pearsonr Result:  (0.13691014082457803, 0.11891545397779628)
# SpearmanrResult(correlation=0.048535449320047865, pvalue=0.5819668098371321)
# Correlation Coefficients:
#  [[1.         0.35314393]
#  [0.35314393 1.        ]]
# doc_no: 84
# doc_key: 302
#
# main: doc_no: 85 target_tag TW02
# doc_no: 85
# doc_key: 448
# Pearsonr Result:  (0.2974080476080401, 0.0005610681867893721)
# SpearmanrResult(correlation=0.19064824771824887, pvalue=0.02916842487124506)
# Correlation Coefficients:
#  [[1.         0.16091204]
#  [0.16091204 1.        ]]
# doc_no: 85
# doc_key: 448
#
# main: doc_no: 86 target_tag TW02
# doc_no: 86
# doc_key: 459
# Pearsonr Result:  (0.17562943238225365, 0.044799760784944846)
# SpearmanrResult(correlation=0.10242507839219547, pvalue=0.24436827080728282)
# Correlation Coefficients:
#  [[1.         0.50790107]
#  [0.50790107 1.        ]]
# doc_no: 86
# doc_key: 459
#
# main: doc_no: 87 target_tag TW02
# doc_no: 87
# doc_key: 460
# Pearsonr Result:  (0.23869428529601708, 0.006040017985583694)
# SpearmanrResult(correlation=0.1285534029531646, pvalue=0.14337484825391794)
# Correlation Coefficients:
#  [[1.         0.36049647]
#  [0.36049647 1.        ]]
# doc_no: 87
# doc_key: 460
#
# main: doc_no: 88 target_tag TW02
# doc_no: 88
# doc_key: 590
# Pearsonr Result:  (0.251064399493179, 0.0038218779561244773)
# SpearmanrResult(correlation=0.19746409323802222, pvalue=0.02377617819080033)
# Correlation Coefficients:
#  [[1.         0.23067193]
#  [0.23067193 1.        ]]
# doc_no: 88
# doc_key: 590
#
# main: doc_no: 89 target_tag TW02
# doc_no: 89
# doc_key: 595
# Pearsonr Result:  (0.2749814362156234, 0.0014796177912919063)
# SpearmanrResult(correlation=0.13108706220845154, pvalue=0.1355869097235408)
# Correlation Coefficients:
#  [[1.         0.61140103]
#  [0.61140103 1.        ]]
# doc_no: 89
# doc_key: 595
#
# main: doc_no: 90 target_tag TW02
# doc_no: 90
# doc_key: 597
# Pearsonr Result:  (0.055054134479433775, 0.5322611136430355)
# SpearmanrResult(correlation=-0.07019258024737575, pvalue=0.42564021503203353)
# Correlation Coefficients:
#  [[1.         0.16268948]
#  [0.16268948 1.        ]]
# doc_no: 90
# doc_key: 597
#
# main: doc_no: 91 target_tag TW02
# doc_no: 91
# doc_key: 603
# Pearsonr Result:  (0.2959858693588281, 0.0005980677350466331)
# SpearmanrResult(correlation=0.1521012356520605, pvalue=0.08286504060939628)
# Correlation Coefficients:
#  [[1.         0.31743196]
#  [0.31743196 1.        ]]
# doc_no: 91
# doc_key: 603
#
# main: doc_no: 92 target_tag TW02
# doc_no: 92
# doc_key: 606
# Pearsonr Result:  (0.20400826321174678, 0.019426766588970266)
# SpearmanrResult(correlation=0.020668406647228115, pvalue=0.814737705534562)
# Correlation Coefficients:
#  [[1.         0.61388559]
#  [0.61388559 1.        ]]
# doc_no: 92
# doc_key: 606
#
# main: doc_no: 93 target_tag TW02
# doc_no: 93
# doc_key: 608
# Pearsonr Result:  (0.23169403024615995, 0.007749828410590034)
# SpearmanrResult(correlation=0.08481535384839696, pvalue=0.3354526049763914)
# Correlation Coefficients:
#  [[1.         0.59282518]
#  [0.59282518 1.        ]]
# doc_no: 93
# doc_key: 608
#
# main: doc_no: 94 target_tag TW02
# doc_no: 94
# doc_key: 610
# Pearsonr Result:  (0.021629656564423762, 0.8062870612040102)
# SpearmanrResult(correlation=-0.10110568520192571, pvalue=0.2505296738753356)
# Correlation Coefficients:
#  [[1.         0.49746875]
#  [0.49746875 1.        ]]
# doc_no: 94
# doc_key: 610
#
# main: doc_no: 95 target_tag TW02
# doc_no: 95
# doc_key: 611
# Pearsonr Result:  (0.1976202967923692, 0.023663364494347732)
# SpearmanrResult(correlation=0.09383415673300564, pvalue=0.28640468912109457)
# Correlation Coefficients:
#  [[1.         0.60607726]
#  [0.60607726 1.        ]]
# doc_no: 95
# doc_key: 611
#
# main: doc_no: 96 target_tag TW02
# doc_no: 96
# doc_key: 616
# Pearsonr Result:  (0.02241342538731877, 0.7994131657154708)
# SpearmanrResult(correlation=-0.07962917239013265, pvalue=0.365942755649746)
# Correlation Coefficients:
#  [[1.         0.52177454]
#  [0.52177454 1.        ]]
# doc_no: 96
# doc_key: 616
#
# main: doc_no: 97 target_tag TW02
# doc_no: 97
# doc_key: 621
# Pearsonr Result:  (0.03612745702209587, 0.6820492042646193)
# SpearmanrResult(correlation=-0.10304492672967619, pvalue=0.24151026059697991)
# Correlation Coefficients:
#  [[1.         0.54679793]
#  [0.54679793 1.        ]]
# doc_no: 97
# doc_key: 621
#
# main: doc_no: 98 target_tag TW02
# doc_no: 98
# doc_key: 796
# Pearsonr Result:  (0.03916585481593606, 0.6569356815868871)
# SpearmanrResult(correlation=-0.10577373779412587, pvalue=0.2292050344171942)
# Correlation Coefficients:
#  [[1.        0.5009382]
#  [0.5009382 1.       ]]
# doc_no: 98
# doc_key: 796
#
# main: doc_no: 99 target_tag TW02
# doc_no: 99
# doc_key: 797
# Pearsonr Result:  (0.2318505167250767, 0.007707350225605813)
# SpearmanrResult(correlation=0.035466011375503224, pvalue=0.6875639525060551)
# Correlation Coefficients:
#  [[1.         0.60677471]
#  [0.60677471 1.        ]]
# doc_no: 99
# doc_key: 797
#
# main: doc_no: 100 target_tag TW02
# doc_no: 100
# doc_key: 812
# Pearsonr Result:  (0.19056211776620022, 0.029242724641602956)
# SpearmanrResult(correlation=0.03737416106257398, pvalue=0.6717006080655764)
# Correlation Coefficients:
#  [[1.         0.58745557]
#  [0.58745557 1.        ]]
# doc_no: 100
# doc_key: 812
#
# main: doc_no: 101 target_tag TW02
# doc_no: 101
# doc_key: 813
# Pearsonr Result:  (0.23149251781325283, 0.007804834188866892)
# SpearmanrResult(correlation=0.12355874578806235, pvalue=0.15971386661746306)
# Correlation Coefficients:
#  [[1.         0.26573274]
#  [0.26573274 1.        ]]
# doc_no: 101
# doc_key: 813
#
# main: doc_no: 102 target_tag TW02
# doc_no: 102
# doc_key: 825
# Pearsonr Result:  (0.05553247254601648, 0.528699194382278)
# SpearmanrResult(correlation=-0.010254984954852778, pvalue=0.9074529898291819)
# Correlation Coefficients:
#  [[1.         0.06830191]
#  [0.06830191 1.        ]]
# doc_no: 102
# doc_key: 825
#
# main: doc_no: 103 target_tag TW02
# doc_no: 103
# doc_key: 826
# Pearsonr Result:  (0.2656006418871918, 0.002168938137217053)
# SpearmanrResult(correlation=0.08678943518162811, pvalue=0.32428453353417297)
# Correlation Coefficients:
#  [[1.         0.45785778]
#  [0.45785778 1.        ]]
# doc_no: 103
# doc_key: 826
#
# main: doc_no: 104 target_tag TW02
# doc_no: 104
# doc_key: 828
# Pearsonr Result:  (0.14282438276335116, 0.10365492889264913)
# SpearmanrResult(correlation=0.0035966899766366324, pvalue=0.9674779907065085)
# Correlation Coefficients:
#  [[1.         0.15888902]
#  [0.15888902 1.        ]]
# doc_no: 104
# doc_key: 828
#
# main: doc_no: 105 target_tag TW02
# doc_no: 105
# doc_key: 837
# Pearsonr Result:  (0.1612764110299594, 0.06572893860444577)
# SpearmanrResult(correlation=0.030336088887876197, pvalue=0.7308734634364582)
# Correlation Coefficients:
#  [[1.         0.12660124]
#  [0.12660124 1.        ]]
# doc_no: 105
# doc_key: 837
# main: doc_no: 106 target_tag TW02
# doc_no: 106
# doc_key: 839
# Pearsonr Result:  (0.07784649202554009, 0.37680603548475844)
# SpearmanrResult(correlation=-0.08561941223225025, pvalue=0.3308745533302363)
# Correlation Coefficients:
#  [[1.         0.15836832]
#  [0.15836832 1.        ]]
# doc_no: 106
# doc_key: 839
#
# main: doc_no: 107 target_tag TW02
# doc_no: 107
# doc_key: 840
# Pearsonr Result:  (0.1692298599385454, 0.05331982030419483)
# SpearmanrResult(correlation=0.044088371473937564, pvalue=0.6170599889051985)
# Correlation Coefficients:
#  [[1.         0.25534129]
#  [0.25534129 1.        ]]
# doc_no: 107
# doc_key: 840
#
# main: doc_no: 108 target_tag TW02
# doc_no: 108
# doc_key: 845
# Pearsonr Result:  (0.09160616025782489, 0.2980512442563379)
# SpearmanrResult(correlation=-0.03670105498977951, pvalue=0.6772804164409756)
# Correlation Coefficients:
#  [[1.         0.18285968]
#  [0.18285968 1.        ]]
# doc_no: 108
# doc_key: 845
#
# main: doc_no: 109 target_tag TW02
# doc_no: 109
# doc_key: 846
# Pearsonr Result:  (0.1351254051335063, 0.12384705737400854)
# SpearmanrResult(correlation=0.03974928342321923, pvalue=0.6521558655011679)
# Correlation Coefficients:
#  [[1.         0.10141935]
#  [0.10141935 1.        ]]
# doc_no: 109
# doc_key: 846
#
# main: doc_no: 110 target_tag TW02
# doc_no: 110
# doc_key: 981
# Pearsonr Result:  (0.13757424189980813, 0.11711974006083109)
# SpearmanrResult(correlation=0.03316769767877089, pvalue=0.7068523564367533)
# Correlation Coefficients:
#  [[1.         0.55835191]
#  [0.55835191 1.        ]]
# doc_no: 110
# doc_key: 981
#
# main: doc_no: 111 target_tag TW02
# doc_no: 111
# doc_key: 990
# Pearsonr Result:  (0.18365415451802355, 0.03574939792430157)
# SpearmanrResult(correlation=0.039828492730870836, pvalue=0.6515080145687443)
# Correlation Coefficients:
#  [[1.         0.56606419]
#  [0.56606419 1.        ]]
# doc_no: 111
# doc_key: 990
#
# main: doc_no: 112 target_tag TW02
# doc_no: 112
# doc_key: 996
# Pearsonr Result:  (0.4320036983459257, 2.573805420841789e-07)
# SpearmanrResult(correlation=0.27322269152956863, pvalue=0.0015912353468271587)
# Correlation Coefficients:
#  [[1.         0.19348804]
#  [0.19348804 1.        ]]
# doc_no: 112
# doc_key: 996
#
# main: doc_no: 113 target_tag TW02
# doc_no: 113
# doc_key: 1008
# Pearsonr Result:  (0.27945596229926994, 0.001227041744068968)
# SpearmanrResult(correlation=0.1450589716428368, pvalue=0.09830658018763433)
# Correlation Coefficients:
#  [[1.         0.60141167]
#  [0.60141167 1.        ]]
# doc_no: 113
# doc_key: 1008
#
# main: doc_no: 114 target_tag TW02
# doc_no: 114
# doc_key: 1015
# Pearsonr Result:  (0.06736382593307366, 0.44457309934843314)
# SpearmanrResult(correlation=-0.07319680439870804, pvalue=0.406051780933092)
# Correlation Coefficients:
#  [[1.         0.24572664]
#  [0.24572664 1.        ]]
# doc_no: 114
# doc_key: 1015
#
# main: doc_no: 115 target_tag TW02
# doc_no: 115
# doc_key: 1080
# Pearsonr Result:  (0.10302398742230762, 0.2416064268890386)
# SpearmanrResult(correlation=0.033113041712688314, pvalue=0.7073133831013156)
# Correlation Coefficients:
#  [[1.         0.41326508]
#  [0.41326508 1.        ]]
# doc_no: 115
# doc_key: 1080
#
# main: doc_no: 116 target_tag TW02
# doc_no: 116
# doc_key: 1360
# Pearsonr Result:  (0.26033245725876514, 0.002672950549430905)
# SpearmanrResult(correlation=0.20944451108738266, pvalue=0.01635394177004218)
# Correlation Coefficients:
#  [[1.         0.52986464]
#  [0.52986464 1.        ]]
# doc_no: 116
# doc_key: 1360
#
# main: doc_no: 117 target_tag TW02
# doc_no: 117
# doc_key: 1362
# Pearsonr Result:  (0.3122286390337003, 0.00028279813183998284)
# SpearmanrResult(correlation=0.1992909894929949, pvalue=0.022485182822868065)
# Correlation Coefficients:
#  [[1.         0.18919121]
#  [0.18919121 1.        ]]
# doc_no: 117
# doc_key: 1362
#
# main: doc_no: 118 target_tag TW02
# doc_no: 118
# doc_key: 1363
# Pearsonr Result:  (0.19019464853817655, 0.02956153175101353)
# SpearmanrResult(correlation=0.026002151331166914, pvalue=0.7681422656768757)
# Correlation Coefficients:
#  [[1.         0.53518563]
#  [0.53518563 1.        ]]
# doc_no: 118
# doc_key: 1363
#
# main: doc_no: 119 target_tag TW02
# doc_no: 119
# doc_key: 1364
# Pearsonr Result:  (0.26499353361993155, 0.002222270184932695)
# SpearmanrResult(correlation=0.15534279153582953, pvalue=0.07644260072464301)
# Correlation Coefficients:
#  [[1.        0.5121992]
#  [0.5121992 1.       ]]
# doc_no: 119
# doc_key: 1364
#
# main: doc_no: 120 target_tag TW02
# doc_no: 120
# doc_key: 1366
# Pearsonr Result:  (0.15787963438414257, 0.0717014271084621)
# ...
# doc_no: 18
# doc_key: 102
# Pearsonr Result:  (0.4232385538525789, 0.0002356189040630553)
# SpearmanrResult(correlation=0.18485008153241453, pvalue=0.12276766296155649)
# Correlation Coefficients:
#  [[1.         0.61814289]
#  [0.61814289 1.        ]]
# doc_no: 18
# doc_key: 102
#
# main: doc_no: 19 target_tag TW05
# doc_no: 19
# doc_key: 104
# Pearsonr Result:  (0.29305553785737565, 0.013130326374868523)
# SpearmanrResult(correlation=0.15068775489820163, pvalue=0.20971236352886086)
# Correlation Coefficients:
#  [[1.         0.66478073]
#  [0.66478073 1.        ]]
# doc_no: 19
# doc_key: 104
#
# main: doc_no: 20 target_tag TW05
# doc_no: 20
# doc_key: 106
# Pearsonr Result:  (0.07857411744458286, 0.5148311928754021)
# SpearmanrResult(correlation=-0.05400160873891485, pvalue=0.6546761183675522)
# Correlation Coefficients:
#  [[1.         0.68520574]
#  [0.68520574 1.        ]]
# doc_no: 20
# doc_key: 106
#
# main: doc_no: 21 target_tag TW05
# doc_no: 21
# doc_key: 107
# Pearsonr Result:  (0.09028479523692699, 0.4539892197322801)
# SpearmanrResult(correlation=-0.03467566089081594, pvalue=0.7740492168575765)
# Correlation Coefficients:
#  [[1.         0.61378187]
#  [0.61378187 1.        ]]
# doc_no: 21
# doc_key: 107
#
# main: doc_no: 22 target_tag TW05
# doc_no: 22
# doc_key: 120
# Pearsonr Result:  (0.010695873411606901, 0.9294571754537357)
# SpearmanrResult(correlation=-0.21437678073675945, pvalue=0.07261511197858152)
# Correlation Coefficients:
#  [[1.         0.61953279]
#  [0.61953279 1.        ]]
# doc_no: 22
# doc_key: 120
#
# main: doc_no: 23 target_tag TW05
# doc_no: 23
# doc_key: 128
# Pearsonr Result:  (0.22398104409224306, 0.060417954968043336)
# SpearmanrResult(correlation=0.0667790544339873, pvalue=0.5800437528096647)
# Correlation Coefficients:
#  [[1.         0.61280775]
#  [0.61280775 1.        ]]
# doc_no: 23
# doc_key: 128
#
# main: doc_no: 24 target_tag TW05
# doc_no: 24
# doc_key: 129
# Pearsonr Result:  (0.22770471439631573, 0.05616052131356784)
# SpearmanrResult(correlation=0.11510744392965985, pvalue=0.33913348439407043)
# Correlation Coefficients:
#  [[1.        0.6802442]
#  [0.6802442 1.       ]]
# doc_no: 24
# doc_key: 129
#
# main: doc_no: 25 target_tag TW05
# doc_no: 25
# doc_key: 134
# Pearsonr Result:  (0.19664153777699858, 0.10025652703442672)
# SpearmanrResult(correlation=0.10348263839365486, pvalue=0.3904553983731075)
# Correlation Coefficients:
#  [[1.         0.62371652]
#  [0.62371652 1.        ]]
# doc_no: 25
# doc_key: 134
#
# main: doc_no: 26 target_tag TW05
# doc_no: 26
# doc_key: 137
# Pearsonr Result:  (0.12195898127535393, 0.3109683418756303)
# SpearmanrResult(correlation=0.03398595250519742, pvalue=0.7784274475036324)
# Correlation Coefficients:
#  [[1.         0.44017168]
#  [0.44017168 1.        ]]
# doc_no: 26
# doc_key: 137
# main: doc_no: 27 target_tag TW05
# doc_no: 27
# doc_key: 146
# Pearsonr Result:  (0.08037736427813033, 0.5052005302109757)
# SpearmanrResult(correlation=0.09457446682456329, pvalue=0.4327383408304175)
# Correlation Coefficients:
#  [[1.         0.67953789]
#  [0.67953789 1.        ]]
# doc_no: 27
# doc_key: 146
#
# main: doc_no: 28 target_tag TW05
# doc_no: 28
# doc_key: 148
# Pearsonr Result:  (0.20087664595922436, 0.09300754571805701)
# SpearmanrResult(correlation=0.08888209422652514, pvalue=0.461060965178531)
# Correlation Coefficients:
#  [[1.         0.65856769]
#  [0.65856769 1.        ]]
# doc_no: 28
# doc_key: 148
#
# main: doc_no: 29 target_tag TW05
# doc_no: 29
# doc_key: 150
# Pearsonr Result:  (0.15129980658410233, 0.20784581881766706)
# SpearmanrResult(correlation=0.05730039769746545, pvalue=0.6350422058637937)
# Correlation Coefficients:
#  [[1.         0.35757052]
#  [0.35757052 1.        ]]
# doc_no: 29
# doc_key: 150
#
# main: doc_no: 30 target_tag TW05
# doc_no: 30
# doc_key: 151
# Pearsonr Result:  (0.13488302117910875, 0.2620729297220874)
# SpearmanrResult(correlation=0.10343523689598341, pvalue=0.39067367956850585)
# Correlation Coefficients:
#  [[1.        0.6126007]
#  [0.6126007 1.       ]]
# doc_no: 30
# doc_key: 151
#
# main: doc_no: 31 target_tag TW05
# doc_no: 31
# doc_key: 158
# Pearsonr Result:  (0.16578131497438917, 0.1670684324745116)
# SpearmanrResult(correlation=0.0481091123839223, pvalue=0.6903279714288229)
# Correlation Coefficients:
#  [[1.         0.60260047]
#  [0.60260047 1.        ]]
# doc_no: 31
# doc_key: 158
#
# main: doc_no: 32 target_tag TW05
# doc_no: 32
# doc_key: 163
# Pearsonr Result:  (0.0073442466993530586, 0.9515295705032253)
# SpearmanrResult(correlation=-0.10582741530455905, pvalue=0.37974852388036173)
# Correlation Coefficients:
#  [[1.         0.57418336]
#  [0.57418336 1.        ]]
# doc_no: 32
# doc_key: 163
#
# main: doc_no: 33 target_tag TW05
# doc_no: 33
# doc_key: 165
# Pearsonr Result:  (0.08538360467916059, 0.4789581957242972)
# SpearmanrResult(correlation=0.11201606276909469, pvalue=0.35234934518695826)
# Correlation Coefficients:
#  [[1.        0.3383264]
#  [0.3383264 1.       ]]
# doc_no: 33
# doc_key: 165
#
# main: doc_no: 34 target_tag TW05
# doc_no: 34
# doc_key: 166
# Pearsonr Result:  (0.25775922163834375, 0.029993114244863228)
# SpearmanrResult(correlation=0.20056139541916365, pvalue=0.09353255415295587)
# Correlation Coefficients:
#  [[1.        0.4081242]
#  [0.4081242 1.       ]]
# doc_no: 34
# doc_key: 166
#
# main: doc_no: 35 target_tag TW05
# doc_no: 35
# doc_key: 167
# Pearsonr Result:  (0.13171523310643268, 0.2735468369436441)
# SpearmanrResult(correlation=0.07091477571223034, pvalue=0.5567519060170759)
# Correlation Coefficients:
#  [[1.         0.36527987]
#  [0.36527987 1.        ]]
# doc_no: 35
# doc_key: 167
#
# main: doc_no: 36 target_tag TW05
# doc_no: 36
# doc_key: 177
# Pearsonr Result:  (0.1528829471125529, 0.2030725318983671)
# SpearmanrResult(correlation=-0.020565433438292376, pvalue=0.8648296227135195)
# Correlation Coefficients:
#  [[1.         0.43066882]
#  [0.43066882 1.        ]]
# doc_no: 36
# doc_key: 177
#
# main: doc_no: 37 target_tag TW05
# doc_no: 37
# doc_key: 188
# Pearsonr Result:  (0.16431271089093943, 0.1709133004248348)
# SpearmanrResult(correlation=0.07542722862969403, pvalue=0.5318585271668783)
# Correlation Coefficients:
#  [[1.         0.45458226]
#  [0.45458226 1.        ]]
# doc_no: 37
# doc_key: 188
#
# main: doc_no: 38 target_tag TW05
# doc_no: 38
# doc_key: 194
# Pearsonr Result:  (0.1331250235385794, 0.26839968269912506)
# SpearmanrResult(correlation=0.021040337940322243, pvalue=0.8617386183256)
# Correlation Coefficients:
#  [[1.         0.49731887]
#  [0.49731887 1.        ]]
# doc_no: 38
# doc_key: 194
#
# main: doc_no: 39 target_tag TW05
# doc_no: 39
# doc_key: 207
# Pearsonr Result:  (0.1415822769727582, 0.23889159335701532)
# SpearmanrResult(correlation=-0.05612722741437929, pvalue=0.6419969258573691)
# Correlation Coefficients:
#  [[1.        0.3750341]
#  [0.3750341 1.       ]]
# doc_no: 39
# doc_key: 207
#
# main: doc_no: 40 target_tag TW05
# doc_no: 40
# doc_key: 212
# Pearsonr Result:  (0.38923789226057226, 0.0007938935279823261)
# SpearmanrResult(correlation=-0.1685790851371905, pvalue=0.15992031653938524)
# Correlation Coefficients:
#  [[1.        0.8321181]
#  [0.8321181 1.       ]]
# doc_no: 40
# doc_key: 212
#
# main: doc_no: 41 target_tag TW05
# doc_no: 41
# doc_key: 213
# Pearsonr Result:  (0.2460115684284061, 0.038636729087499586)
# SpearmanrResult(correlation=0.07672313210204361, pvalue=0.5248129377389539)
# Correlation Coefficients:
#  [[1.         0.54327906]
#  [0.54327906 1.        ]]
# doc_no: 41
# doc_key: 213
#
# main: doc_no: 42 target_tag TW05
# doc_no: 42
# doc_key: 214
# Pearsonr Result:  (0.20881422916324072, 0.08053504495852588)
# SpearmanrResult(correlation=0.16867251069500577, pvalue=0.15968558616709191)
# Correlation Coefficients:
#  [[1.         0.76659758]
#  [0.76659758 1.        ]]
# doc_no: 42
# doc_key: 214
#
# main: doc_no: 43 target_tag TW05
# doc_no: 43
# doc_key: 221
# Pearsonr Result:  (0.045571655513038885, 0.7058957807227293)
# SpearmanrResult(correlation=-0.013180807346403946, pvalue=0.913125721520899)
# Correlation Coefficients:
#  [[1.         0.59632536]
#  [0.59632536 1.        ]]
# doc_no: 43
# doc_key: 221
#
# main: doc_no: 44 target_tag TW05
# doc_no: 44
# doc_key: 243
# Pearsonr Result:  (-0.09449186710028165, 0.4331421433973206)
# SpearmanrResult(correlation=-0.09759290463050166, pvalue=0.4181290576933344)
# Correlation Coefficients:
#  [[1.         0.64454245]
#  [0.64454245 1.        ]]
# doc_no: 44
# doc_key: 243
#
# main: doc_no: 45 target_tag TW05
# doc_no: 45
# doc_key: 274
# Pearsonr Result:  (0.13938254842831058, 0.246341736702243)
# SpearmanrResult(correlation=-0.001430891367419416, pvalue=0.990550956126365)
# Correlation Coefficients:
#  [[1.         0.62670414]
#  [0.62670414 1.        ]]
# doc_no: 45
# doc_key: 274
#
# main: doc_no: 46 target_tag TW05
# doc_no: 46
# doc_key: 285
# Pearsonr Result:  (0.12009042026619932, 0.31849540115941144)
# SpearmanrResult(correlation=0.0059619124979903085, pvalue=0.9606445957712217)
# Correlation Coefficients:
#  [[1.         0.37288456]
#  [0.37288456 1.        ]]
# doc_no: 46
# doc_key: 285
#
# main: doc_no: 47 target_tag TW05
# doc_no: 47
# doc_key: 289
# Pearsonr Result:  (0.17270907566415816, 0.1497855102300949)
# SpearmanrResult(correlation=0.04969643268105065, pvalue=0.6806537035510974)
# Correlation Coefficients:
#  [[1.         0.61578668]
#  [0.61578668 1.        ]]
# doc_no: 47
# doc_key: 289
#
# main: doc_no: 48 target_tag TW05
# doc_no: 48
# doc_key: 293
# Pearsonr Result:  (0.3633350130221099, 0.0018435120692374667)
# SpearmanrResult(correlation=0.1855371974938392, pvalue=0.12135809294957531)
# Correlation Coefficients:
#  [[1.         0.57111242]
#  [0.57111242 1.        ]]
# doc_no: 48
# doc_key: 293
#
# main: doc_no: 49 target_tag TW05
# doc_no: 49
# doc_key: 302
# Pearsonr Result:  (0.08459755471779672, 0.4830298156601198)
# SpearmanrResult(correlation=0.008862244913527481, pvalue=0.9415271694881213)
# Correlation Coefficients:
#  [[1.         0.57063528]
#  [0.57063528 1.        ]]
# doc_no: 49
# doc_key: 302
#
# main: doc_no: 50 target_tag TW05
# doc_no: 50
# doc_key: 448
# Pearsonr Result:  (0.38020156542342437, 0.0010734991670103642)
# SpearmanrResult(correlation=0.3333270307882188, pvalue=0.004503873144250994)
# Correlation Coefficients:
#  [[1.         0.41447922]
#  [0.41447922 1.        ]]
# doc_no: 50
# doc_key: 448
#
# main: doc_no: 51 target_tag TW05
# doc_no: 51
# doc_key: 459
# Pearsonr Result:  (0.20445566567140822, 0.08720803600838735)
# SpearmanrResult(correlation=0.13315244558671185, pvalue=0.2683002141232866)
# Correlation Coefficients:
#  [[1.         0.62305367]
#  [0.62305367 1.        ]]
# doc_no: 51
# doc_key: 459
#
# main: doc_no: 52 target_tag TW05
# doc_no: 52
# doc_key: 590
# Pearsonr Result:  (0.29167904233319597, 0.01358591502774376)
# SpearmanrResult(correlation=0.2727833053716904, pvalue=0.02136056826153516)
# Correlation Coefficients:
#  [[1.        0.4441777]
#  [0.4441777 1.       ]]
# doc_no: 52
# doc_key: 590
#
# main: doc_no: 53 target_tag TW05
# doc_no: 53
# doc_key: 595
# Pearsonr Result:  (0.3704794127527138, 0.0014712725135930024)
# SpearmanrResult(correlation=0.19626140981459766, pvalue=0.10092812963835987)
# Correlation Coefficients:
#  [[1.         0.68532774]
#  [0.68532774 1.        ]]
# doc_no: 53
# doc_key: 595
#
# main: doc_no: 54 target_tag TW05
# doc_no: 54
# doc_key: 597
# Pearsonr Result:  (0.15800935225222199, 0.1881529955057964)
# SpearmanrResult(correlation=0.0765184461115535, pvalue=0.5259226613666308)
# Correlation Coefficients:
#  [[1.         0.39134811]
#  [0.39134811 1.        ]]
# doc_no: 54
# doc_key: 597
# main: doc_no: 55 target_tag TW05
# doc_no: 55
# doc_key: 603
# Pearsonr Result:  (0.388728086354962, 0.0008077079452066083)
# SpearmanrResult(correlation=0.0897713275366607, pvalue=0.45657091117017923)
# Correlation Coefficients:
#  [[1.        0.5642005]
#  [0.5642005 1.       ]]
# doc_no: 55
# doc_key: 603
#
# main: doc_no: 56 target_tag TW05
# doc_no: 56
# doc_key: 608
# Pearsonr Result:  (0.4128855681267478, 0.0003457786785989412)
# SpearmanrResult(correlation=0.22954207634301624, pvalue=0.05415164741376232)
# Correlation Coefficients:
#  [[1.         0.67232764]
#  [0.67232764 1.        ]]
# doc_no: 56
# doc_key: 608
#
# main: doc_no: 57 target_tag TW05
# doc_no: 57
# doc_key: 618
# Pearsonr Result:  (0.42801657624532086, 0.00019656355691307584)
# SpearmanrResult(correlation=0.186980774981326, pvalue=0.118437060498846)
# Correlation Coefficients:
#  [[1.         0.62331627]
#  [0.62331627 1.        ]]
# doc_no: 57
# doc_key: 618
#
# main: doc_no: 58 target_tag TW05
# doc_no: 58
# doc_key: 812
# Pearsonr Result:  (0.2963877130847304, 0.012081789166619753)
# SpearmanrResult(correlation=0.09137258649948568, pvalue=0.44854654696386065)
# Correlation Coefficients:
#  [[1.         0.67233126]
#  [0.67233126 1.        ]]
# doc_no: 58
# doc_key: 812
#
# main: doc_no: 59 target_tag TW05
# doc_no: 59
# doc_key: 828
# Pearsonr Result:  (0.10508395091132092, 0.38312410263345686)
# SpearmanrResult(correlation=-0.049273165087489766, pvalue=0.6832284579595022)
# Correlation Coefficients:
#  [[1.         0.38720453]
#  [0.38720453 1.        ]]
# doc_no: 59
# doc_key: 828
#
# main: doc_no: 60 target_tag TW05
# doc_no: 60
# doc_key: 839
# Pearsonr Result:  (0.07077376112076772, 0.5575386833943494)
# SpearmanrResult(correlation=-0.1472687888929176, pvalue=0.22035747865099936)
# Correlation Coefficients:
#  [[1.         0.39736967]
#  [0.39736967 1.        ]]
# doc_no: 60
# doc_key: 839
#
# main: doc_no: 61 target_tag TW05
# doc_no: 61
# doc_key: 840
# Pearsonr Result:  (0.1504693471450775, 0.21038129612785833)
# SpearmanrResult(correlation=0.04403076872010458, pvalue=0.7154090168582096)
# Correlation Coefficients:
#  [[1.         0.53153495]
#  [0.53153495 1.        ]]
# doc_no: 61
# doc_key: 840
#
# main: doc_no: 62 target_tag TW05
# doc_no: 62
# doc_key: 845
# Pearsonr Result:  (0.06166327607787489, 0.6094575271387532)
# SpearmanrResult(correlation=-0.13161331458009853, pvalue=0.27392148284934387)
# Correlation Coefficients:
#  [[1.        0.3584825]
#  [0.3584825 1.       ]]
# doc_no: 62
# doc_key: 845
#
# main: doc_no: 63 target_tag TW05
# doc_no: 63
# doc_key: 1008
# Pearsonr Result:  (0.31741742722109945, 0.006991088026122115)
# SpearmanrResult(correlation=0.09982153533248468, pvalue=0.407527230766607)
# Correlation Coefficients:
#  [[1.         0.64064789]
#  [0.64064789 1.        ]]
# doc_no: 63
# doc_key: 1008
#
# main: doc_no: 64 target_tag TW05
# doc_no: 64
# doc_key: 1033
# Pearsonr Result:  (0.08080111959349373, 0.50295091336472)
# SpearmanrResult(correlation=-0.08504412738786654, pvalue=0.4807143844310109)
# Correlation Coefficients:
#  [[1.         0.67002277]
#  [0.67002277 1.        ]]
# doc_no: 64
# doc_key: 1033
#
# main: doc_no: 65 target_tag TW05
# doc_no: 65
# doc_key: 1360
# Pearsonr Result:  (0.3612369468951861, 0.0019678552375610304)
# SpearmanrResult(correlation=0.31805794166866536, pvalue=0.00687142354348227)
# Correlation Coefficients:
#  [[1.         0.60819972]
#  [0.60819972 1.        ]]
# doc_no: 65
# doc_key: 1360
#
# main: doc_no: 66 target_tag TW05
# doc_no: 66
# doc_key: 1364
# Pearsonr Result:  (0.38193761675878357, 0.0010137104858803877)
# SpearmanrResult(correlation=0.2658113365173351, pvalue=0.025059633575066124)
# Correlation Coefficients:
#  [[1.         0.65451524]
#  [0.65451524 1.        ]]
# doc_no: 66
# doc_key: 1364
#
# main: doc_no: 67 target_tag TW05
# doc_no: 67
# doc_key: 1382
# Pearsonr Result:  (0.45010460063318924, 8.205406842341263e-05)
# SpearmanrResult(correlation=0.3303158695215449, pvalue=0.004903314525356457)
# Correlation Coefficients:
#  [[1.         0.56573051]
#  [0.56573051 1.        ]]
# doc_no: 67
# doc_key: 1382
#
# main: doc_no: 68 target_tag TW05
# doc_no: 68
# doc_key: 1837
# Pearsonr Result:  (0.2098247207771505, 0.0790474442323874)
# SpearmanrResult(correlation=0.03259564696378596, pvalue=0.787273837647515)
# Correlation Coefficients:
#  [[1.         0.43765753]
#  [0.43765753 1.        ]]
# doc_no: 68
# doc_key: 1837
#
# main: doc_no: 69 target_tag TW05
# doc_no: 69
# doc_key: 1838
# Pearsonr Result:  (0.10026549702283936, 0.4054341420615488)
# SpearmanrResult(correlation=0.0574280196958185, pvalue=0.6342875265357412)
# Correlation Coefficients:
#  [[1.         0.43877652]
#  [0.43877652 1.        ]]
# doc_no: 69
# doc_key: 1838
#
# main: doc_no: 70 target_tag TW05
# doc_no: 70
# doc_key: 1846
# Pearsonr Result:  (0.24273973284134787, 0.041383043851225446)
# SpearmanrResult(correlation=0.016869537452633566, pvalue=0.8889506987544322)
# Correlation Coefficients:
#  [[1.         0.67194394]
#  [0.67194394 1.        ]]
# doc_no: 70
# doc_key: 1846
#
# sim_cs: [0.3833048427177037, 0.3938071274051218]
#
# sim_js [0.8214975013585969, 0.8265900760887572]
#
# Pearsonr RESULT:  (1.0, 0.0)
#
# Spearmanr RESULT: SpearmanrResult(correlation=0.9999999999999999, pvalue=nan)
#
# Correlation Coefficients
#  [[1. 1.]
#  [1. 1.]]
# End time: 2018-03-24 09:27:27
